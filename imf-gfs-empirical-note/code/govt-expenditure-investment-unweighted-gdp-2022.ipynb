# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Currency Codes

# %%
country_currency_codes_table = {
    'Burundi': 'BIF',
    'Benin': 'XOF',
    'Burkina Faso': 'XOF',
    'Central African Republic': 'XAF',
    "Côte d'Ivoire": 'XOF',
    'Cameroon': 'XAF',
    'Democratic Republic of the Congo': 'CDF',
    'Republic of Congo': 'XAF',
    'Comoros': 'KMF',
    'Eritrea': 'ERN',
    'Ethiopia': 'ETB',
    'Ghana': 'GHS',
    'Guinea': 'GNF',
    'The Gambia': 'GMD',
    'Guinea-Bissau': 'XOF',
    'Liberia': 'LRD',
    'Madagascar': 'MGA',
    'Mali': 'XOF',
    'Mozambique': 'MZN',
    'Mauritania': 'MRU',
    'Malawi': 'MWK',
    'Niger': 'XOF',
    'Rwanda': 'RWF',
    'Sudan': 'SDG',
    'Senegal': 'XOF',
    'Sierra Leone': 'SLL',
    'Somalia': 'SOS',
    'Sao Tomee and Principe': 'STN',
    'Chad': 'XAF',
    'Togo': 'XOF',
    'Tanzania': 'TZS',
    'Uganda': 'UGX',
    'Zambia': 'ZMW'
}

# %% [markdown]
# Read Data

# %%
#read in stata dataset as dataframe "country_code_df"
country_code_df = pd.read_stata("codesffactors_Mar23_2019.dta") 
country_code_df.replace('--', np.nan, inplace=True) #replace all entries that are '--' with NaN data value

country_code_df.head()
# Out:
#    countryname       wbctry wbcode                   wbregion  \
# 0        Aruba        Aruba    ABW  Latin America & Caribbean
# 1  Afghanistan  Afghanistan    AFG                 South Asia
# 2       Angola       Angola    AGO         Sub-Saharan Africa
# 3     Anguilla          NaN    AIA  Latin America & Caribbean
# 4      Albania      Albania    ALB      Europe & Central Asia
#
#           wbigroup2017 wblcat2017  hipc  emu  cemac  waemu  imfcode  \
# 0          High income        NaN     0    0      0      0      NaN
# 1           Low income        IDA     1    0      0      0    512.0
# 2  Lower middle income       IBRD     0    0      0      0    614.0
# 3                  NaN        NaN     0    0      0      0    312.0
# 4  Upper middle income       IBRD     0    0      0      0    914.0
#
#    imfweocode imfweoiso   imfweoctry region
# 0       314.0       ABW        Aruba    LAC
# 1       512.0       AFG  Afghanistan    SAS
# 2       614.0       AGO       Angola    SSA
# 3         NaN       NaN          NaN    LAC
# 4       914.0       ALB      Albania    ECA

# %%
region_classification_ls = country_code_df['wbregion'].unique() #get a list of region classifications
income_classification_ls = country_code_df['wbigroup2017'].unique() #get a list of income classifications
income_classification_ls = [x for x in income_classification_ls if not pd.isna(x)] # remove '--' from income_classification_ls

print(f"The region classifications are: {', '.join(country for country in region_classification_ls)}")
print(f"The income classifications are: {', '.join(country for country in income_classification_ls)}")
# Out:
# The region classifications are: Latin America & Caribbean, South Asia, Sub-Saharan Africa, Europe & Central Asia, Middle East & North Africa, East Asia & Pacific, North America
# The income classifications are: High income, Low income, Lower middle income, Upper middle income

# %%
ssa_hipc_countries = country_code_df[(country_code_df['hipc'] == 1) & (country_code_df['wbregion'] == 'Sub-Saharan Africa')]
ssa_hipc_countries_ls = ssa_hipc_countries['imfweoctry'].to_list()

len(ssa_hipc_countries_ls)
# Out:
# 33

# %% [markdown]
# Read in IMF's Government Finance Statistics

# %%
master_table = {}
folder_path = "expenditure-investment-gdp-2022-data"

# Loop that goes through all files 'file_name' in the folder 'folder_path'
for file_name in os.listdir(folder_path):
  if file_name.endswith('.xlsx') and not file_name.startswith('~$'): #check to see if is spreadsheet .xlsx format
    raw_df = pd.read_excel(folder_path+ "/" + file_name) #read in .xlsx as dataframe
    master_table[file_name[:-5]] = raw_df #store dataframe as an entry in the master_table hash table

# master_table["Central African Republic"]
for key in master_table:
  print(master_table[key])
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                                      Country: Benin          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    18.782603
# 9                                               Taxes    15.534492
# 10                               Social contributions     0.474120
# 11                                             Grants     1.515431
# 12                                      Other revenue     1.258560
# 13                                            Expense    13.296972
# 14                          Compensation of employees     6.825031
# 15                          Use of goods and services     2.062502
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.513758
# 18                                          Subsidies     0.594599
# 19                                             Grants     2.948845
# 20                                    Social benefits     0.022451
# 21                                      Other expense     0.329786
# 22                            Gross operating balance     5.485631
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     3.542431
# 26                                        Expenditure    16.839404
# 27                Net lending (+) / Net borrowing (-)     1.943199
# 28                    Primary net lending / borrowing     2.456958
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     0.649968
# 31                      Net incurrence of liabilities     2.612751
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000
# 7           NaN          NaN          NaN
# 8     18.353960    16.852992    17.750171
# 9     14.823271    14.413153    15.384955
# 10     0.504528     0.497768     0.503990
# 11     2.184229     1.119362     1.014611
# 12     0.841933     0.822708     0.848825
# 13    12.412144    12.845846    12.765534
# 14     6.566421     6.436507     6.547448
# 15     1.863296     2.268908     2.345322
# 16          NaN          NaN          NaN
# 17     0.406104     0.556032     0.439886
# 18     0.909993     1.323608     1.094189
# 19     2.358863     1.934150     2.013749
# 20     0.026768     0.018812     0.019894
# 21     0.280699     0.307830     0.302836
# 22     5.941816     4.007146     4.984637
# 23          NaN          NaN          NaN
# 24          NaN          NaN          NaN
# 25     3.386330     2.430938     2.261323
# 26    15.798474    15.276784    15.026857
# 27     2.555486     1.576208     2.723314
# 28     2.961590     2.132240     3.163200
# 29          NaN          NaN          NaN
# 30    -0.024562    -0.402380    -0.125997
# 31     3.620820     1.941959     3.558876
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                                    Country: Senegal          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    17.530270
# 9                                               Taxes    14.977603
# 10                               Social contributions     0.000000
# 11                                             Grants     2.029289
# 12                                      Other revenue     0.523378
# 13                                            Expense    12.475389
# 14                          Compensation of employees     4.918174
# 15                          Use of goods and services     3.766441
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.753190
# 18                                          Subsidies          NaN
# 19                                             Grants          NaN
# 20                                    Social benefits          NaN
# 21                                      Other expense          NaN
# 22                            Gross operating balance     5.054881
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     9.222278
# 26                                        Expenditure    21.697668
# 27                Net lending (+) / Net borrowing (-)    -4.167398
# 28                    Primary net lending / borrowing    -3.414207
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets    -0.949867
# 31                      Net incurrence of liabilities     3.346860
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     18.172816    18.331196    17.754641    19.800047    19.921078
# 9     15.329442    15.254740          NaN    15.166439    15.835465
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     1.786787     2.283498     2.007080     3.189623     2.207866
# 12     1.056587     0.792958          NaN     1.443985     1.877747
# 13    14.204957    13.514669    13.514452    18.166822    18.614072
# 14     5.098299     5.121512     4.973286     5.012526     5.006581
# 15     4.076257          NaN     3.356620     3.690090     3.656849
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.223354     1.189992     1.211483     1.421594     1.520222
# 18          NaN          NaN          NaN     0.126781     0.481707
# 19          NaN          NaN          NaN     5.832791     6.350238
# 20          NaN          NaN          NaN     0.308303     0.573123
# 21          NaN          NaN          NaN     1.774739     1.025351
# 22     3.967858     4.816528     4.240189     1.633224     1.307006
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     8.962524     9.031960     8.575627     5.034184     4.989205
# 26    23.167481    22.546628    22.090080    23.201006    23.603277
# 27    -4.994665    -4.215432    -4.335438    -3.400959    -3.682199
# 28    -3.771312    -3.025440    -3.123956    -1.979366    -2.161976
# 29          NaN          NaN          NaN          NaN          NaN
# 30     2.470531     1.638041          NaN     1.249658    -0.880985
# 31     7.436608     4.827618          NaN     4.654922     2.844412
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     19.924607    20.270544    19.766581    21.181603    20.836875
# 9     16.438532    15.906452    16.378252    18.419094    17.471621
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     0.994807     2.172195     1.997217     1.635888     2.301420
# 12     2.491268     2.191898     1.391142     1.126621     1.063834
# 13    19.820979    18.995014    18.920708    20.090888    21.268777
# 14     5.072204     4.920987     5.311591     5.347317     6.050053
# 15     2.846121     2.483888     3.260009     4.328362     3.339264
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.663065     1.918410     2.049496     1.977584     2.053380
# 18     0.463477     0.348819     1.013752     1.546647     1.844678
# 19     7.774770     6.076453     5.068737     4.674209     5.922473
# 20     0.054897     0.057270     0.055343     0.112251     0.660715
# 21     1.946445     3.189187     2.161781     2.104519     1.398214
# 22     0.103628     1.275530     0.845873     1.090715    -0.431902
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     2.251176     4.009652     4.577054     4.952125     5.969720
# 26    22.072156    23.004666    23.497761    25.043014    27.238497
# 27    -2.147549    -2.734122    -3.731180    -3.861410    -6.401622
# 28    -0.484483    -0.815712    -1.681685    -1.883827    -4.348242
# 29          NaN          NaN          NaN          NaN          NaN
# 30     1.643146     1.598298     3.366903     2.023384     1.667467
# 31     3.933378     4.521819     7.088257     5.952821     8.125116
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     19.999262    21.259807
# 9     17.483822    18.850727
# 10     0.000000     0.000000
# 11     0.852603     0.908668
# 12     1.662837     1.500412
# 13    19.442807    22.553847
# 14     6.042248     6.800538
# 15     3.254581     3.739496
# 16          NaN          NaN
# 17     2.000981     2.261129
# 18     0.594214     0.819884
# 19     5.265102     7.153681
# 20     0.149400     0.203647
# 21     2.136281     1.575472
# 22     0.556455    -1.294040
# 23          NaN          NaN
# 24          NaN          NaN
# 25     6.857162     4.782500
# 26    26.299969    27.336347
# 27    -6.300707    -6.076540
# 28    -4.299725    -3.815411
# 29          NaN          NaN
# 30     2.823247     2.065401
# 31     9.109085     8.140850
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                              Country: Côte d'Ivoire          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    12.322894
# 9                                               Taxes    10.363661
# 10                               Social contributions     0.000000
# 11                                             Grants     0.896975
# 12                                      Other revenue     1.062240
# 13                                            Expense    10.781182
# 14                          Compensation of employees     4.698655
# 15                          Use of goods and services     2.180238
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     1.140685
# 18                                          Subsidies     0.996058
# 19                                             Grants     0.146992
# 20                                    Social benefits     0.000000
# 21                                      Other expense     1.618536
# 22                            Gross operating balance     1.541712
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     2.010852
# 26                                        Expenditure    12.792034
# 27                Net lending (+) / Net borrowing (-)    -0.469141
# 28                    Primary net lending / borrowing     0.671544
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     0.800199
# 31                      Net incurrence of liabilities     1.737259
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8      9.140566    12.302545    12.529780    11.938325    13.205969
# 9      7.819609    10.410651    10.520780    10.109100    11.175733
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     0.196265     0.429537     0.943588     1.302568     1.041852
# 12     1.124728     1.462346     1.065399     0.526656     0.988384
# 13     9.924767    11.099059     9.823088     9.208897    13.454591
# 14     4.299068     4.943815     4.865948     4.902624     4.493342
# 15     1.787111     2.055287     1.765666     1.967849     2.279677
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.309490     1.232000     1.005971     0.573835     1.098948
# 18     1.072927     1.228054     0.768453     0.530317     2.129577
# 19     0.396281     0.446042     0.392732     0.388916     2.693334
# 20     0.000000     0.000000     0.000000     0.000000     0.321714
# 21     1.059895     1.193880     1.024285     0.845356     0.438000
# 22    -0.784201     1.203485     2.706692     2.729428    -0.248622
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     1.683248     3.238350     4.342843     4.076060     2.178190
# 26    11.608015    14.337409    14.165931    13.284957    15.632781
# 27    -2.467449    -2.034865    -1.636151    -1.346632    -2.426812
# 28    -1.157959    -0.802865    -0.630180    -0.772798    -1.327865
# 29          NaN          NaN          NaN          NaN          NaN
# 30     1.086276    -0.255402     0.914985     0.662432     0.830613
# 31     4.175883     1.293758     2.577449     2.843236     3.204564
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     12.750583    12.827207    12.723996    12.842942    12.653805
# 9     11.460371    11.756371    11.665993    11.759837    11.795125
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     1.019350     0.872698     0.757335     0.783333     0.533125
# 12     0.270862     0.198138     0.300669     0.299772     0.325555
# 13    13.400193    14.947206    14.737042    13.737315    16.043544
# 14     4.459100     4.533632     4.564634     4.447619     4.608160
# 15     2.274556     2.432818     1.926634     1.631390     2.191146
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.255407     1.244469     1.335626     1.484349     1.831126
# 18     1.454490     1.812708     1.794232     1.349018     1.784527
# 19     3.038311     3.147622     3.598058     3.537828     3.920628
# 20     0.232521     0.219959     0.289001     0.256144     0.390858
# 21     0.685809     1.555998     1.228857     1.030966     1.317100
# 22    -0.649611    -2.119999    -2.013045    -0.894372    -3.389739
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     2.595836     1.363079     1.297070     1.731611     2.468939
# 26    15.996029    16.310285    16.034112    15.468926    18.512484
# 27    -3.245447    -3.483078    -3.310115    -2.625983    -5.858678
# 28    -1.990040    -2.238608    -1.974489    -1.141635    -4.027552
# 29          NaN          NaN          NaN          NaN          NaN
# 30    -0.386356     0.865759     0.228658     0.459906     1.633343
# 31     2.838014     4.340269     3.563261     3.114176     7.477570
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     13.301350    12.734173
# 9     12.559104    11.969190
# 10     0.000000     0.000000
# 11     0.463564     0.534902
# 12     0.278681     0.230081
# 13    16.601670    18.648547
# 14     4.254743     4.187615
# 15     2.895234     3.307318
# 16          NaN          NaN
# 17     1.970108     2.221338
# 18     1.118814     1.182276
# 19     4.825065     6.748375
# 20     0.073266     0.036628
# 21     1.464439     0.964997
# 22    -3.300320    -5.914374
# 23          NaN          NaN
# 24          NaN          NaN
# 25     2.222994     1.355954
# 26    18.824664    20.004501
# 27    -5.523314    -7.270329
# 28    -3.553206    -5.048991
# 29          NaN          NaN
# 30    -0.350859     0.240283
# 31     5.139722     7.525733
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                               Country: Burkina Faso          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    17.596701
# 9                                               Taxes    11.310065
# 10                               Social contributions     0.000000
# 11                                             Grants     3.977065
# 12                                      Other revenue     2.309572
# 13                                            Expense    10.594597
# 14                          Compensation of employees     4.914256
# 15                          Use of goods and services     1.814497
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.426899
# 18                                          Subsidies     0.361521
# 19                                             Grants     0.892689
# 20                                    Social benefits     0.000000
# 21                                      Other expense     2.184747
# 22                            Gross operating balance     7.002105
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets    11.042242
# 26                                        Expenditure    21.636838
# 27                Net lending (+) / Net borrowing (-)    -4.040137
# 28                    Primary net lending / borrowing    -3.613239
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     0.330109
# 31                      Net incurrence of liabilities     4.388445
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     18.396673    19.901589    21.710854    19.190140    18.264896
# 9     12.219491    13.889962    14.948642    13.663828    13.280201
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     4.455962     4.327092     4.884901     3.725007     3.288510
# 12     1.721149     1.684613     1.877387     1.801306     1.696186
# 13    11.035896    12.921446    12.333665    12.878735    13.197493
# 14     4.942820     5.182200     5.354168     6.351798     6.697767
# 15     1.706437     1.880072     1.786048     1.487031     1.564521
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.496969     0.651878     0.523412     0.639282     0.625450
# 18     0.556576     0.206216     0.166298     0.343249     0.169616
# 19     0.644866     0.952736     0.862815     1.299642     1.256843
# 20     0.000000     0.000000     0.000000     0.000000     0.000000
# 21     2.688227     4.048350     3.640920     2.757732     2.883297
# 22     7.360777     6.980144     9.377189     6.311404     5.067403
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     9.400134     9.746869    12.928081     8.048977     7.161249
# 26    20.436030    22.668314    25.261746    20.927712    20.358742
# 27    -2.039357    -2.766725    -3.550892    -1.737572    -2.093846
# 28    -1.542388    -2.114847    -3.027479    -1.098290    -1.468396
# 29          NaN          NaN          NaN          NaN          NaN
# 30     0.018845     1.292562    -1.017858     0.992328    -1.045780
# 31     2.058258     4.057722     2.531289     2.729732     1.048064
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     18.565581    18.880159    19.260908    19.855244    18.771161
# 9     14.153541    15.181570    15.293331    15.499548    13.275361
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     2.371866     2.169315     2.437140     1.416506     2.921908
# 12     2.040174     1.529275     1.530438     2.939190     2.573892
# 13    14.724789    18.393891    17.371785    18.053129    16.979428
# 14     7.298557     7.506491     7.982975     8.862230     8.632846
# 15     1.684789     4.201219     3.714089     2.429538     1.690031
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.859505     0.844244     1.101806     1.207881     1.355683
# 18     0.360650     0.676369     0.132118     0.179039     1.086709
# 19     1.626874     1.923536     2.007640     2.376371     2.149928
# 20     0.000000     1.008748     1.003164     1.063465     0.907065
# 21     2.894414     2.233284     1.429993     1.934605     1.157167
# 22     3.840792     0.486268     1.889123     1.802115     1.791733
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     6.928693     6.948332     6.155682     4.700252     6.953266
# 26    21.653482    25.342224    23.527467    22.753381    23.932694
# 27    -3.087902    -6.462065    -4.266559    -2.898138    -5.161533
# 28    -2.228396    -5.617820    -3.164753    -1.690257    -3.805851
# 29          NaN          NaN          NaN          NaN          NaN
# 30     1.421540    -0.755828    -0.490497    -0.286989    -0.011507
# 31     4.506810     5.756543     3.740769     2.595190     5.098053
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     20.399534    21.844142
# 9     15.906392    17.604867
# 10     0.000000     0.000000
# 11     2.377601     2.232265
# 12     2.115541     2.007010
# 13    18.143376    20.735982
# 14     8.612223     7.949399
# 15     1.776257     2.145158
# 16          NaN          NaN
# 17     1.759214     1.883213
# 18     0.400622     4.033085
# 19     3.865825     3.346018
# 20     0.975480     0.978739
# 21     0.753755     0.400370
# 22     2.256158     1.108160
# 23          NaN          NaN
# 24          NaN          NaN
# 25     8.479300    10.257680
# 26    26.622676    30.993662
# 27    -6.223142    -9.149520
# 28    -4.463928    -7.266307
# 29          NaN          NaN
# 30     2.124222    -1.708764
# 31     8.276722     7.415339
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                       Country: Central African Rep.          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    15.078780
# 9                                               Taxes     8.407895
# 10                               Social contributions          NaN
# 11                                             Grants     5.871356
# 12                                      Other revenue     0.627392
# 13                                            Expense    16.336671
# 14                          Compensation of employees     4.038153
# 15                          Use of goods and services     9.459845
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.897196
# 18                                          Subsidies          NaN
# 19                                             Grants     0.000000
# 20                                    Social benefits     0.000000
# 21                                      Other expense     0.037731
# 22                            Gross operating balance    -1.257890
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     7.112845
# 26                                        Expenditure    23.449515
# 27                Net lending (+) / Net borrowing (-)    -8.370735
# 28                    Primary net lending / borrowing    -7.473539
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets          NaN
# 31                      Net incurrence of liabilities          NaN
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2014.000000  2015.000000  2016.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     10.914864    15.717551    19.105810     9.207579    15.522592
# 9      7.540404     8.172377     4.098503     5.448991     6.807586
# 10          NaN          NaN     0.000000     0.000000     0.000000
# 11     2.289575     6.163477    14.524525     3.544419     8.222365
# 12     0.911895     1.210273     0.482782     0.214169     0.492641
# 13    13.464091     8.184472     8.271978     9.306557     9.021342
# 14     4.003057     3.996115     5.748749     5.652907     4.547504
# 15     6.565684     1.950226     0.678511     1.519425     2.031592
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.607807     0.462223     0.231918     0.468567     0.106853
# 18          NaN          NaN     0.000000     0.000000     0.000000
# 19     0.000000     0.000000     0.000000     0.000000     0.000000
# 20     0.000000     0.000000     0.000000     0.000000     0.000000
# 21     0.261120          NaN     1.612801     1.665658     2.335394
# 22    -2.549227     7.533079    10.833832    -0.098978     6.501250
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.421037     6.960901     8.525065     0.986357     5.838232
# 26    16.885128    15.145373    16.797043    10.292914    14.859574
# 27    -5.970264     0.572177     2.308767    -1.085336     0.663018
# 28    -5.362457     1.034400     2.540685    -0.616769     0.769870
# 29          NaN          NaN          NaN          NaN          NaN
# 30          NaN          NaN     2.346136    -0.699078     1.772528
# 31          NaN          NaN    -0.217529     0.498647     1.069838
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2017.000000  2018.000000  2019.000000  2020.000000  2021.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     13.825754    16.416897    17.929120    21.076612    13.959096
# 9      7.081244     8.423424     8.110260     8.496561     7.996867
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     6.627560     7.819778     9.357088    11.797096     4.989224
# 12     0.116950     0.173695     0.461772     0.782956     0.973005
# 13     8.676799     9.869788     9.690573    13.631446    11.363790
# 14     4.155406     4.847437     4.873191     5.272694     5.670807
# 15     2.305613     2.408703     2.724633     5.657780     3.602243
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.183242     0.221384     0.485581     0.278795     0.587939
# 18     0.000000     0.000000     0.000000     0.000000     0.000000
# 19     0.000000     0.000000     0.000000     0.000000     0.000000
# 20     0.000000     0.000000     0.000000     0.000000     0.000000
# 21     2.032537     2.392264     1.607167     2.422178     1.502801
# 22     5.148956     6.547109     8.238547     7.445166     2.595306
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.571628     6.206197     4.797978     7.523205     6.530569
# 26    12.248426    16.075985    14.488551    21.154651    17.894359
# 27     1.577328     0.340912     3.440569    -0.078039    -3.935263
# 28     1.760571     0.562295     3.926150     0.200756    -3.347324
# 29          NaN          NaN          NaN          NaN          NaN
# 30     1.373324    -0.527020    -0.147187    -0.271210    -0.202092
# 31    -0.196835    -0.299156    -3.413301     0.096183     3.538617
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                                      Country: Ghana          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    14.288117
# 9                                               Taxes     9.942163
# 10                               Social contributions     0.000000
# 11                                             Grants     1.893047
# 12                                      Other revenue     2.452906
# 13                                            Expense    14.968883
# 14                          Compensation of employees     5.347651
# 15                          Use of goods and services     2.212343
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     2.321489
# 18                                          Subsidies     0.211498
# 19                                             Grants     3.761786
# 20                                    Social benefits     1.114116
# 21                                      Other expense     0.000000
# 22                            Gross operating balance    -0.680766
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     4.665846
# 26                                        Expenditure    19.634729
# 27                Net lending (+) / Net borrowing (-)    -5.346612
# 28                    Primary net lending / borrowing    -3.025123
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets    -0.659017
# 31                      Net incurrence of liabilities     4.687595
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     15.888034    15.402443    14.820295    14.728087    15.994862
# 9     10.922409    11.336630    10.671836    11.252186    11.690563
# 10     0.096432     0.000000     0.000000     0.000000     0.000000
# 11     1.654968     1.136465     0.594036     0.513055     1.465058
# 12     3.214225     2.929348     3.554423     2.962846     2.839241
# 13    15.532968    19.831431    19.281135    18.203509    17.364300
# 14     5.963883     7.030056     7.615074     6.596015     6.599175
# 15     2.458971     1.294656     1.164153     1.119604     0.756417
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.979045     2.386066     3.532341     4.462245     4.944998
# 18     0.000000     0.792343     0.930332     0.298534     0.013622
# 19     3.798526     3.687548     3.653596     3.056884     3.704098
# 20     1.332543     0.000000     0.000845     0.000000     0.033104
# 21     0.000000     4.640761     2.384794     2.670226     1.312885
# 22     0.355066    -4.428988    -4.460840    -3.475421    -1.369438
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.233665     3.162787     3.849053     3.841402     3.886954
# 26    18.766633    22.994218    23.130188    22.044911    21.251254
# 27    -2.878599    -7.591775    -8.309892    -7.316824    -5.256392
# 28    -0.899554    -5.205709    -4.777551    -2.854578    -0.311395
# 29          NaN          NaN          NaN          NaN          NaN
# 30    -0.087469     0.000000     0.000000     0.000000     0.000000
# 31     2.791130     8.536252     7.595463     7.279005     4.773360
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     14.678413    15.104574    15.437031    14.971384    14.067998
# 9     11.058329    11.577031    12.244242    11.996996    11.340432
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     0.519469     0.584043     0.367742     0.276578     0.313491
# 12     3.100614     2.943500     2.825048     2.697810     2.414075
# 13    18.289585    17.355240    17.601848    17.510945    21.883554
# 14     6.450427     6.383703     6.355425     6.231773     7.212553
# 15     1.466683     0.944493     1.661721     1.730389     1.894591
# 16          NaN          NaN          NaN          NaN          NaN
# 17     5.250111     5.164470     5.127177     5.544685     6.276270
# 18     0.000000     0.000000     0.040608     0.034844     0.042894
# 19     3.919634     3.499686     3.496305     3.203978     3.031569
# 20     0.000000     0.008720     0.053699     0.028185     0.028757
# 21     1.202730     1.354168     0.866912     0.737091     3.396920
# 22    -3.611172    -2.250666    -2.164816    -2.539561    -7.815556
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.496487     2.409231     1.535492     1.725407     3.082832
# 26    21.786073    19.764472    19.137340    19.236352    24.966386
# 27    -7.107660    -4.659898    -3.700308    -4.264968   -10.898388
# 28    -1.857549     0.504572     1.426869     1.279717    -4.622118
# 29          NaN          NaN          NaN          NaN          NaN
# 30     0.000000     0.000000     0.000000     0.000000     0.000000
# 31     6.340084     4.659370     3.782639     4.737657    11.455272
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     15.182434    15.838694
# 9     12.244687    12.380443
# 10     0.000000     0.000000
# 11     0.256060     0.183306
# 12     2.681686     3.274946
# 13    20.750875    22.831889
# 14     6.858054     6.462257
# 15     1.550987     1.298909
# 16          NaN          NaN
# 17     7.260765     7.487005
# 18     0.029442     0.027372
# 19     2.926553     4.023170
# 20     0.000000     0.015330
# 21     2.125073     3.517846
# 22    -5.568441    -6.993195
# 23          NaN          NaN
# 24          NaN          NaN
# 25     3.674951     3.062607
# 26    24.425826    25.894496
# 27    -9.243392   -10.055802
# 28    -1.982627    -2.568797
# 29          NaN          NaN
# 30     0.000000     0.000000
# 31     9.173733    10.677470
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                                    Country: Somalia          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2017.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue     5.505987
# 9                                               Taxes     3.160882
# 10                               Social contributions     0.000000
# 11                                             Grants     2.342341
# 12                                      Other revenue     0.002764
# 13                                            Expense     5.305569
# 14                          Compensation of employees     2.878364
# 15                          Use of goods and services     1.909398
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.000000
# 18                                          Subsidies     0.000000
# 19                                             Grants     0.426194
# 20                                    Social benefits     0.000000
# 21                                      Other expense     0.091613
# 22                            Gross operating balance     0.200417
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     0.140805
# 26                                        Expenditure     5.446374
# 27                Net lending (+) / Net borrowing (-)     0.059613
# 28                    Primary net lending / borrowing     0.059613
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     0.059770
# 31                      Net incurrence of liabilities     0.000000
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6   2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN
# 8      5.940495     6.696345    10.151622
# 9      3.855247     3.423035     2.797218
# 10     0.000000     0.000000     0.000000
# 11     1.996907     2.157284     5.917344
# 12     0.088341     1.116027     1.437060
# 13     5.561128     5.936478     9.475819
# 14     3.093556     3.216654     4.480427
# 15     1.793096     1.829386     1.610400
# 16          NaN          NaN          NaN
# 17     0.000000     0.000000     0.289495
# 18     0.000000     0.000000     0.043328
# 19     0.649947     0.885200     1.806895
# 20     0.006580     0.000000     1.245275
# 21     0.017949     0.005239     0.000000
# 22     0.379366     0.759867     0.675802
# 23          NaN          NaN          NaN
# 24          NaN          NaN          NaN
# 25     0.212207     0.292368     0.354670
# 26     5.773335     6.228846     9.830490
# 27     0.167160     0.467499     0.321132
# 28     0.167160     0.467499     0.610627
# 29          NaN          NaN          NaN
# 30     0.167160     0.468255     0.320662
# 31     0.000000     0.000000     0.000000
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                   Country: Tanzania, United Rep. of          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    15.828496
# 9                                               Taxes     9.959692
# 10                               Social contributions     0.000000
# 11                                             Grants     5.382082
# 12                                      Other revenue     0.486722
# 13                                            Expense    13.256212
# 14                          Compensation of employees     2.608065
# 15                          Use of goods and services     1.948918
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.706123
# 18                                          Subsidies     0.000000
# ...
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                        Country: Madagascar, Rep. of          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    12.350766
# 9                                               Taxes     8.535319
# 10                               Social contributions     0.817222
# 11                                             Grants     1.701269
# 12                                      Other revenue     1.296956
# 13                                            Expense     8.573464
# 14                          Compensation of employees     4.544242
# 15                          Use of goods and services     0.907660
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.708908
# 18                                          Subsidies     0.205967
# 19                                             Grants     0.994646
# 20                                    Social benefits     1.071979
# 21                                      Other expense     0.140063
# 22                            Gross operating balance     3.777302
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     4.379667
# 26                                        Expenditure    12.953131
# 27                Net lending (+) / Net borrowing (-)    -0.602365
# 28                    Primary net lending / borrowing     0.106543
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     1.443861
# 31                      Net incurrence of liabilities     1.995253
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     11.363006    10.200765    10.615277    11.252195    11.066907
# 9      8.710323     8.368253     8.785590     8.441132     8.945308
# 10     0.802777     0.313195     0.461016     0.437161     0.424191
# 11     1.668404     1.034374     1.080111     1.960498     1.277152
# 12     0.181503     0.484942     0.288560     0.413405     0.420257
# 13     8.935065     8.756528     9.404194     9.852741     9.558686
# 14     4.538120     4.583719     4.881447     4.782414     4.709828
# 15     0.879295     0.627947     0.526262     0.827001     0.643193
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.612333     0.566643     0.452120     0.470834     0.695203
# 18     0.281451     0.517408     0.872335     0.843072     0.218583
# 19     1.313780     1.124822     1.251880     1.291106     1.740694
# 20     1.150835     1.224902     1.303681     1.428855     1.332459
# 21     0.159250     0.111087     0.116471     0.209459     0.218727
# 22     2.427942     1.444237     1.211083     1.399455     1.508221
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.598527     2.341877     2.663977     3.303603     3.011981
# 26    12.533591    11.098404    12.068172    13.156344    12.570667
# 27    -1.170585    -0.897640    -1.452895    -1.904148    -1.503760
# 28    -0.558252    -0.330997    -1.000775    -1.433314    -0.808557
# 29          NaN          NaN          NaN          NaN          NaN
# 30    -0.311480    -0.182051    -1.406940     0.370538     0.598937
# 31     0.916901     1.070887     0.140358     2.560846     2.404337
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     13.037859    13.400483    14.124299    14.677379    13.120401
# 9      9.244851    10.027545    10.283129    10.531865     9.520729
# 10     0.367487     0.403811     0.709295     0.598694     0.658251
# 11     2.987682     2.525327     2.683008     3.109251     2.513790
# 12     0.437839     0.443800     0.448868     0.437569     0.427631
# 13     9.317263    10.589115     9.832365    10.132873    11.797752
# 14     4.773726     4.823838     5.162501     4.888019     5.685079
# 15     0.567400     0.706217     0.785441     0.677003     0.697819
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.738864     0.695264     0.769549     0.697552     0.731360
# 18     1.353145     1.799227     0.778154     1.537141     1.873233
# 19     0.343895     1.060135     0.833243     0.835740     1.129616
# 20     1.310121     1.399084     1.386713     1.385513     1.639660
# 21     0.230112     0.105350     0.116764     0.111905     0.040986
# 22     3.720595     2.811368     4.291935     4.544506     1.322649
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     4.432305     4.680546     5.336291     5.593365     6.761654
# 26    13.749569    15.269661    15.168655    15.726238    18.559406
# 27    -0.711710    -1.869178    -1.044356    -1.048859    -5.439005
# 28     0.027154    -1.173913    -0.274807    -0.351307    -4.707645
# 29          NaN          NaN          NaN          NaN          NaN
# 30     0.933621     0.709262     0.642661     0.219846     1.845124
# 31     1.539142     2.304001     1.713501     1.324988     7.103284
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     11.726947    11.589403
# 9     10.238531     9.348124
# 10     0.435101     0.575326
# 11     0.665403     1.278741
# 12     0.387913     0.387212
# 13    10.543214    10.052729
# 14     5.186930     5.463003
# 15     0.619468     0.710141
# 16          NaN          NaN
# 17     0.634853     0.558102
# 18     0.444524     0.646111
# 19     2.094123     1.040877
# 20     1.532153     1.586785
# 21     0.031163     0.047708
# 22     1.183733     1.536675
# 23          NaN          NaN
# 24          NaN          NaN
# 25     5.300242     5.457948
# 26    15.843456    15.510676
# 27    -4.116509    -3.921273
# 28    -3.481656    -3.363171
# 29          NaN          NaN
# 30     0.453873     0.307737
# 31     4.443250     4.175132
#                                            Unnamed: 0   Unnamed: 1  \
# 0   Statement of Operations (Revenue, Expenditures...          NaN
# 1                                     Country: Uganda          NaN
# 2                Sector: Budgetary central government          NaN
# 3                                Unit: Percent of GDP          NaN
# 4                                        Scale: Units          NaN
# 5                                                 NaN          NaN
# 6                                                 NaN  2010.000000
# 7                    TRANSACTIONS AFFECTING NET WORTH          NaN
# 8                                             Revenue    10.070772
# 9                                               Taxes     7.824826
# 10                               Social contributions     0.000000
# 11                                             Grants     2.034120
# 12                                      Other revenue     0.211826
# 13                                            Expense    10.594311
# 14                          Compensation of employees     1.313683
# 15                          Use of goods and services     3.486734
# 16                       Consumption of fixed capital          NaN
# 17                                           Interest     0.716535
# 18                                          Subsidies     0.162611
# 19                                             Grants     4.095194
# 20                                    Social benefits     0.413816
# 21                                      Other expense     0.405738
# 22                            Gross operating balance    -0.523539
# 23                              Net operating balance          NaN
# 24                TRANSACTIONS IN NONFINANCIAL ASSETS          NaN
# 25        Net/gross investment in nonfinancial assets     2.030321
# 26                                        Expenditure    12.624632
# 27                Net lending (+) / Net borrowing (-)    -2.553859
# 28                    Primary net lending / borrowing    -1.837324
# 29  TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITI...          NaN
# 30                Net acquisition of financial assets     0.494017
# 31                      Net incurrence of liabilities     3.330557
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2011.000000  2012.000000  2013.000000  2014.000000  2015.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     10.511067    10.018892     9.895764     9.817617    11.441704
# 9      9.090516     8.424885     8.548226     8.888605    10.247992
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     1.283533     1.457327     1.119338     0.777501     0.964259
# 12     0.137018     0.136680     0.228199     0.151510     0.229453
# 13    10.678726     9.262003     8.912551     9.499457    10.046966
# 14     1.419809     1.547373     1.677679     1.678231     1.826224
# 15     3.915034     2.582564     2.043294     2.390292     2.595567
# 16          NaN          NaN          NaN          NaN          NaN
# 17     0.610480     0.778575     1.063765     1.073731     1.256541
# 18     0.265210     0.241028     0.034699     0.039545     0.070444
# 19     3.811954     3.591578     3.442663     3.605193     3.798394
# 20     0.292893     0.259471     0.311234     0.253135     0.253020
# 21     0.363345     0.261414     0.339214     0.459329     0.246775
# 22    -0.167659     0.756889     0.983213     0.318159     1.394738
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     2.018561     2.383438          NaN     3.386639     3.336055
# 26    12.697287    11.645441          NaN    12.886096    13.383021
# 27    -2.186220    -1.626549          NaN    -3.068479    -1.941317
# 28    -1.575740    -0.847974          NaN    -1.994748    -0.684776
# 29          NaN          NaN          NaN          NaN          NaN
# 30     2.424236     3.561339          NaN    -4.907365    -1.375041
# 31     4.826527     4.760221          NaN    -2.143103     1.363632
#
#      Unnamed: 7   Unnamed: 8   Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2016.000000  2017.000000  2018.000000  2019.000000  2020.000000
# 7           NaN          NaN          NaN          NaN          NaN
# 8     12.077368    12.184076    12.033994    12.735021    13.052115
# 9     10.676824    11.041356    11.085010    11.538329    11.261532
# 10     0.000000     0.000000     0.000000     0.000000     0.000000
# 11     1.095522     0.832707     0.609686     0.857756     0.818408
# 12     0.305021     0.310013     0.339298     0.338936     0.972175
# 13    11.046203    10.638127    11.028013    11.882916    13.187900
# 14     1.881459     1.885831     1.899671     1.990409     2.304793
# 15     3.243678     2.244687     2.816061     3.331815     2.961825
# 16          NaN          NaN          NaN          NaN          NaN
# 17     1.606014     2.069376     1.780151     1.802732     2.075320
# 18     0.053199     0.084134     0.000000     0.000000     0.000000
# 19     3.900817     3.800718     2.666656     4.395410     5.257930
# 20     0.150609     0.152225     0.001008     0.000723     0.000192
# 21     0.210427     0.401155     1.864467     0.361826     0.587841
# 22     1.031165     1.545949     1.005981     0.852105    -0.135784
# 23          NaN          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN          NaN
# 25     3.350044     4.014815     3.541095     4.122388     6.039009
# 26    14.396247    14.652942    14.569108    16.005304    19.226909
# 27    -2.318879    -2.468866    -2.535114    -3.270283    -6.174794
# 28    -0.712864    -0.399490    -0.754963    -1.467551    -4.099474
# 29          NaN          NaN          NaN          NaN          NaN
# 30     1.461227     0.746111     0.322347    -0.153873     0.144441
# 31     4.079146     2.926325     2.806473     2.914337     6.143713
#
#     Unnamed: 12  Unnamed: 13
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   2021.000000  2022.000000
# 7           NaN          NaN
# 8     14.235960    12.916296
# 9     12.070587    11.474053
# 10     0.000000     0.000000
# 11     1.276301     0.652752
# 12     0.889071     0.789490
# 13    14.709899    14.264659
# 14     2.400278     2.134211
# 15     3.541087     3.193989
# 16          NaN          NaN
# 17     2.649289     2.789972
# 18     0.000000     0.000000
# 19     5.691095     5.622218
# 20     0.000333     0.000948
# 21     0.427817     0.523320
# 22    -0.473939    -1.348363
# 23          NaN          NaN
# 24          NaN          NaN
# 25     7.351049     4.890790
# 26    22.060948    19.155448
# 27    -7.824988    -6.239153
# 28    -5.175699    -3.449180
# 29          NaN          NaN
# 30     1.650998    -0.802281
# 31     9.073794     4.563515

# %% [markdown]
# Filtering

# %%
#REMOVE "JUNK" ROWS AND CONVERT TO CORRECT SCALE (MILLION/BILLIONS)
for key in master_table: #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
  scale = master_table[key].iloc[4,0] #get if values have scale of billions or millions
  
  # Drop rows 0 to 5, reformatting indexes and column headers
  master_table[key] = master_table[key].drop([0, 1, 2, 3, 4, 5]) 
  master_table[key] = master_table[key].reset_index(drop=True) 
  master_table[key].columns = master_table[key].iloc[0]
  master_table[key] = master_table[key][1:]
  master_table[key] = master_table[key].set_index(master_table[key].columns[0])
  master_table[key].columns = [int(float(col)) for col in master_table[key].columns]

  index_list = list(master_table[key].index)

  # Find the first occurrence of 'Grants' and rename it
  for i in range(len(index_list)):
      if index_list[i] == 'Grants':
          index_list[i] = 'Grants received'
          break

  # Assign the modified index back to the dataframe
  master_table[key].index = index_list
  # master_table[key] = master_table[key].rename({4: 'Tax Grants'}, axis='index')
  # index_to_rename = master_table[key].index[master_table[key]['name'] == 'grants'][0]
  # master_table[key].at[index_to_rename, 'name'] = 'tax grants'


  # master_table[key] = master_table[key].fillna(0)

  # if scale == "Scale: Billions":
  #   master_table[key] = master_table[key]* (10 ** 9) #multiple every value in dataframe by 1e9 if scale is billion
  # elif scale == "Scale: Millions":
  #   master_table[key] = master_table[key]* (10 ** 6) #multiple every value in dataframe by 1e9 if scale is billion


#FILTER OUT YEAR COLUMNS ACCOUNTING DOESNT ADD UP
#first level: make sure 'Taxes', 'Social Contributions', 'Grants, 'Other Revenue' Sums to 'Revenue'
#second level: make sure 'Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.' sum to 'Taxes'
first_level_ls = ['Compensation of employees', 'Use of goods and services', 'Consumption of fixed capital', 'Interest', 'Subsidies', 'Grants', 'Social benefits', 'Other expense', 'Net/gross investment in nonfinancial assets']
# second_level_ls = ['Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.']
                  
for key in master_table:
  years_accounting_error_ls = []
  years_available = master_table[key].columns
  for year in years_available:
    country_year_df = master_table[key][year]
    # revenue = 0 
    exp = 0
    for category in first_level_ls:
      if category in country_year_df.index:
        exp += country_year_df[category]
      # else: 
      #   print(category)
    # for category in second_level_ls:
    #   if category in country_year_df.index:
    #     taxes += country_year_df[category]
    # if round(taxes, 0) != round(country_year_df['Taxes'], 0) or round(revenue, 0) != round(country_year_df['Revenue'], 0):
    
    margin = 0.001
    lower_bound_exp = country_year_df['Expenditure'] - country_year_df['Expenditure']*margin
    upper_bound_exp = country_year_df['Expenditure'] + country_year_df['Expenditure']*margin

    # print(lower_bound_exp)
    # print(upper_bound_exp)
    # print(exp)
    if exp < lower_bound_exp or exp > upper_bound_exp:
    
      print(f"{round(exp, 0)}, {round(country_year_df['exp'], 0)}")

      years_accounting_error_ls.append(year)
  
  print(key)
  print(years_accounting_error_ls)
  master_table[key].drop(columns=years_accounting_error_ls, inplace=True)
 
    
    

#FILTER OUT COUNTRIES WITH LESS THAN 7 YEARS OF DATA
less_than_seven_years_data_countries = [] #create list to store countries with less than 7 years of historial data
for key in master_table: #iterate through master_table
  num_columns = master_table[key].shape[1] #count the number of columns (each column represents a year)
  if num_columns < 9: #if less than 7 columns/year, add to list to delete
    less_than_seven_years_data_countries.append(key)

print('remove')
for country in less_than_seven_years_data_countries:
  print(country)
  del master_table[country] #delete countries with less than 7 years from data table

master_table["Zambia"]
# Out:
# Benin
# []
# Senegal
# []
# Côte d'Ivoire
# []
# Burkina Faso
# []
# Central African Republic
# []
# Ghana
# []
# Somalia
# []
# Tanzania
# []
# Zambia
# []
# Democratic Republic of the Congo
# []
# Chad
# []
# Rwanda
# []
# Republic of Congo
# []
# Sudan
# []
# The Gambia
# []
# Togo
# []
# Mali
# []
# Malawi
# []
# Sao Tomee and Principe
# []
# Mozambique
# []
# Sierra Leone
# []
# Guinea-Bissau
# []
# Ethiopia
# []
# Burundi
# []
# Liberia
# []
# Cameroon
# []
# Madagascar
# []
# Uganda
# []
# remove
# Benin
# Somalia
# Chad
# Sudan
# The Gambia
# Guinea-Bissau
# Liberia
#                                                          2010       2011  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             16.586785  21.058592
# Taxes                                               12.834842  14.715943
# Social contributions                                 0.000000   0.000000
# Grants received                                      2.224197   3.590215
# Other revenue                                        1.527745   2.752434
# Expense                                             14.668856  14.495677
# Compensation of employees                            6.577420   6.095064
# Use of goods and services                            3.539223   5.706804
# Consumption of fixed capital                              NaN        NaN
# Interest                                             1.574419   0.933038
# Subsidies                                            0.120713   0.018320
# Grants                                               2.641436   1.405357
# Social benefits                                      0.053982   0.139129
# Other expense                                        0.161664   0.197964
# Gross operating balance                              1.917929   6.562915
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          3.044606   7.569856
# Expenditure                                         17.713463  22.065534
# Net lending (+) / Net borrowing (-)                 -1.126678  -1.006942
# Primary net lending / borrowing                      0.447741  -0.073903
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  1.090747   1.473173
# Net incurrence of liabilities                        2.776388   3.757821
#
#                                                          2012       2013  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             18.310983  17.699409
# Taxes                                               14.892364  14.347130
# Social contributions                                 0.000000   0.000000
# Grants received                                      1.642894   1.463176
# Other revenue                                        1.775725   1.889103
# Expense                                             16.532242  17.853331
# Compensation of employees                            8.123851   7.517437
# Use of goods and services                            4.109597   5.129683
# Consumption of fixed capital                              NaN        NaN
# Interest                                             1.394023   1.596278
# Subsidies                                            0.184753   1.103977
# Grants                                               2.323657   2.287471
# Social benefits                                      0.169520   0.085944
# Other expense                                        0.226840   0.132541
# Gross operating balance                              1.778741  -0.153922
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          1.542830   4.257229
# Expenditure                                         18.075072  22.110561
# Net lending (+) / Net borrowing (-)                  0.235911  -4.411152
# Primary net lending / borrowing                      1.629934  -2.814874
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  3.142093  -0.324393
# Net incurrence of liabilities                       10.832899   3.749443
#
#                                                          2014       2015  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             18.724955  19.859871
# Taxes                                               15.761077  14.393958
# Social contributions                                 0.000000   0.000000
# Grants received                                      0.987268   1.564107
# Other revenue                                        1.976610   3.901806
# Expense                                             20.256300  23.233779
# Compensation of employees                            9.198772   8.941714
# Use of goods and services                            4.395278   4.884168
# Consumption of fixed capital                              NaN        NaN
# Interest                                             2.893768   3.924616
# Subsidies                                            0.000000   0.000000
# Grants                                               3.600556   5.296542
# Social benefits                                      0.093168   0.043412
# Other expense                                        0.074759   0.143327
# Gross operating balance                             -1.531345  -3.373907
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          4.126697   4.654526
# Expenditure                                         24.382997  27.888305
# Net lending (+) / Net borrowing (-)                 -5.658042  -8.028434
# Primary net lending / borrowing                     -2.764274  -4.103817
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  1.163752   4.270402
# Net incurrence of liabilities                        6.707696  11.646941
#
#                                                          2016       2017  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             19.822529  19.780306
# Taxes                                               13.353177  15.184871
# Social contributions                                 0.000000   0.000000
# Grants received                                      1.690099   2.929078
# Other revenue                                        4.779253   1.666357
# Expense                                             22.408675  20.922095
# Compensation of employees                            8.627226   8.133147
# Use of goods and services                            6.598705   5.051876
# Consumption of fixed capital                              NaN        NaN
# Interest                                             4.923878   4.776921
# Subsidies                                            0.000000   0.001448
# Grants                                               2.136352   2.656543
# Social benefits                                      0.054158   0.219642
# Other expense                                        0.068357   0.082518
# Gross operating balance                             -2.586147  -1.141789
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          3.077264   4.136809
# Expenditure                                         25.485939  25.058904
# Net lending (+) / Net borrowing (-)                 -5.663410  -5.278599
# Primary net lending / borrowing                     -0.739532  -0.501678
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                 -0.029218  -7.503056
# Net incurrence of liabilities                        4.505888  11.019513
#
#                                                          2018       2019  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             20.420066  20.742244
# Taxes                                               16.587065  16.677623
# Social contributions                                 0.000000   0.000000
# Grants received                                      1.009103   1.146139
# Other revenue                                        2.823897   2.918482
# Expense                                             20.110712  21.956163
# Compensation of employees                            7.620317   7.433267
# Use of goods and services                            3.200786   3.086568
# Consumption of fixed capital                              NaN        NaN
# Interest                                             6.780952   9.220736
# Subsidies                                            0.000000   0.000000
# Grants                                               2.270220   2.096522
# Social benefits                                      0.120403   0.058584
# Other expense                                        0.118034   0.060486
# Gross operating balance                              0.309354  -1.213919
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          9.088611   6.660116
# Expenditure                                         29.199323  28.616279
# Net lending (+) / Net borrowing (-)                 -8.779257  -7.874035
# Primary net lending / borrowing                     -1.998305   1.346700
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  0.238538   0.351558
# Net incurrence of liabilities                        6.264415   7.240983
#
#                                                          2020       2021
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             21.297012  25.278068
# Taxes                                               16.442597  17.396921
# Social contributions                                 0.000000   0.000000
# Grants received                                      1.686293   2.503591
# Other revenue                                        3.168122   5.377556
# Expense                                             25.410238  26.060630
# Compensation of employees                            8.227592   7.285837
# Use of goods and services                            4.355992   6.608853
# Consumption of fixed capital                              NaN        NaN
# Interest                                             8.261685   6.914378
# Subsidies                                            0.000000   0.000000
# Grants                                               2.751984   3.046239
# Social benefits                                      0.253103   0.235902
# Other expense                                        1.559882   1.969422
# Gross operating balance                             -4.113226  -0.782562
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          9.013869   2.981486
# Expenditure                                         34.424106  29.042116
# Net lending (+) / Net borrowing (-)                -13.127095  -3.764048
# Primary net lending / borrowing                     -4.865410   3.150330
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  1.408524   2.209091
# Net incurrence of liabilities                       12.638995   5.536519

# %% [markdown]
# Convert Currency

# %%
# print('keep')
# for key in master_table:
#   print(key)

# #CONVERT LOCAL CURRENCY DENOMINATED VALUES TO USD
# error_countries = []
# for key in master_table:
#   #get annual 2010-2019 USD to domestic currency exchange rate using yfinance library
#   currency = country_currency_codes_table[key] #retrieve currency symbol from 'country_currency_codes_table'
#   symbol = f"{currency}=X"
#   try:
#     data = yf.download(symbol, start="2010-01-01", end="2020-01-01", interval="1mo") #download monthly USD-Currency dataset from 2010-2020
#     yearly_data_df = data['Close'].resample('YE').mean() #get the annual average exchange rate outputted as datafram
#     yearly_data_table = yearly_data_df.to_dict() # Convert the yearly_data to a hash table with the date as the key
#     year_to_exchange_rate_dict = {key.year: value for key, value in yearly_data_table.items()} # Convert the keys to only the year part
#     print(year_to_exchange_rate_dict)

#     #convert DataFrame values to USD
#     for year in master_table[key].columns: #loop through columns in dataframe
#       year_int = int(year)  # Convert year to integer to match the dictionary keys
#       master_table[key][year] = master_table[key][year] / year_to_exchange_rate_dict[year_int] #divide each column's values by that year's exchange rate

#   except Exception as e: #if errored out
#     print(f"Could not fetch rate for {key} ({currency}): {e}")
#     error_countries.append(key) #add country to error list
#     pass
    
# for country in error_countries:
#   del master_table[country] #delete countries where currency conversion failed
 
# for key in master_table:
#   print(key)
#   print(master_table[key])

# %% [markdown]
# Calculate Percentages

# %%
# yearly_averages_percentage_ls = []

# year = 2010
# for year_average_df in yearly_averages_ls:


#   total_taxes = year_average_df['Expenditure']
#   year_average_percentage_df = year_average_df / total_taxes * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places
  
#   first_level = 0
#   print(year)
#   for category in first_level_ls:
#     first_level += year_average_percentage_df[category]
#   print(first_level)
#   year += 1
  
#   yearly_averages_percentage_ls.append(year_average_percentage_df)

# for i in range(len(yearly_averages_percentage_ls)):
#   print(f"YEAR: {2010+i}")
#   print(yearly_averages_percentage_ls[i])


# for key in master_table: #iterate through master_table
#   total_taxes = master_table[key].loc['Expenditure']
#   master_table[key] = master_table[key] / total_taxes * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places

master_table['Central African Republic']
# Out:
#                                                          2010       2011  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             15.078780  10.914864
# Taxes                                                8.407895   7.540404
# Social contributions                                      NaN        NaN
# Grants received                                      5.871356   2.289575
# Other revenue                                        0.627392   0.911895
# Expense                                             16.336671  13.464091
# Compensation of employees                            4.038153   4.003057
# Use of goods and services                            9.459845   6.565684
# Consumption of fixed capital                              NaN        NaN
# Interest                                             0.897196   0.607807
# Subsidies                                                 NaN        NaN
# Grants                                               0.000000   0.000000
# Social benefits                                      0.000000   0.000000
# Other expense                                        0.037731   0.261120
# Gross operating balance                             -1.257890  -2.549227
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          7.112845   3.421037
# Expenditure                                         23.449515  16.885128
# Net lending (+) / Net borrowing (-)                 -8.370735  -5.970264
# Primary net lending / borrowing                     -7.473539  -5.362457
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                       NaN        NaN
# Net incurrence of liabilities                             NaN        NaN
#
#                                                          2012       2014  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             15.717551  19.105810
# Taxes                                                8.172377   4.098503
# Social contributions                                      NaN   0.000000
# Grants received                                      6.163477  14.524525
# Other revenue                                        1.210273   0.482782
# Expense                                              8.184472   8.271978
# Compensation of employees                            3.996115   5.748749
# Use of goods and services                            1.950226   0.678511
# Consumption of fixed capital                              NaN        NaN
# Interest                                             0.462223   0.231918
# Subsidies                                                 NaN   0.000000
# Grants                                               0.000000   0.000000
# Social benefits                                      0.000000   0.000000
# Other expense                                             NaN   1.612801
# Gross operating balance                              7.533079  10.833832
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          6.960901   8.525065
# Expenditure                                         15.145373  16.797043
# Net lending (+) / Net borrowing (-)                  0.572177   2.308767
# Primary net lending / borrowing                      1.034400   2.540685
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                       NaN   2.346136
# Net incurrence of liabilities                             NaN  -0.217529
#
#                                                          2015       2016  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                              9.207579  15.522592
# Taxes                                                5.448991   6.807586
# Social contributions                                 0.000000   0.000000
# Grants received                                      3.544419   8.222365
# Other revenue                                        0.214169   0.492641
# Expense                                              9.306557   9.021342
# Compensation of employees                            5.652907   4.547504
# Use of goods and services                            1.519425   2.031592
# Consumption of fixed capital                              NaN        NaN
# Interest                                             0.468567   0.106853
# Subsidies                                            0.000000   0.000000
# Grants                                               0.000000   0.000000
# Social benefits                                      0.000000   0.000000
# Other expense                                        1.665658   2.335394
# Gross operating balance                             -0.098978   6.501250
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          0.986357   5.838232
# Expenditure                                         10.292914  14.859574
# Net lending (+) / Net borrowing (-)                 -1.085336   0.663018
# Primary net lending / borrowing                     -0.616769   0.769870
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                 -0.699078   1.772528
# Net incurrence of liabilities                        0.498647   1.069838
#
#                                                          2017       2018  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             13.825754  16.416897
# Taxes                                                7.081244   8.423424
# Social contributions                                 0.000000   0.000000
# Grants received                                      6.627560   7.819778
# Other revenue                                        0.116950   0.173695
# Expense                                              8.676799   9.869788
# Compensation of employees                            4.155406   4.847437
# Use of goods and services                            2.305613   2.408703
# Consumption of fixed capital                              NaN        NaN
# Interest                                             0.183242   0.221384
# Subsidies                                            0.000000   0.000000
# Grants                                               0.000000   0.000000
# Social benefits                                      0.000000   0.000000
# Other expense                                        2.032537   2.392264
# Gross operating balance                              5.148956   6.547109
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          3.571628   6.206197
# Expenditure                                         12.248426  16.075985
# Net lending (+) / Net borrowing (-)                  1.577328   0.340912
# Primary net lending / borrowing                      1.760571   0.562295
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                  1.373324  -0.527020
# Net incurrence of liabilities                       -0.196835  -0.299156
#
#                                                          2019       2020  \
# TRANSACTIONS AFFECTING NET WORTH                          NaN        NaN
# Revenue                                             17.929120  21.076612
# Taxes                                                8.110260   8.496561
# Social contributions                                 0.000000   0.000000
# Grants received                                      9.357088  11.797096
# Other revenue                                        0.461772   0.782956
# Expense                                              9.690573  13.631446
# Compensation of employees                            4.873191   5.272694
# Use of goods and services                            2.724633   5.657780
# Consumption of fixed capital                              NaN        NaN
# Interest                                             0.485581   0.278795
# Subsidies                                            0.000000   0.000000
# Grants                                               0.000000   0.000000
# Social benefits                                      0.000000   0.000000
# Other expense                                        1.607167   2.422178
# Gross operating balance                              8.238547   7.445166
# Net operating balance                                     NaN        NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN        NaN
# Net/gross investment in nonfinancial assets          4.797978   7.523205
# Expenditure                                         14.488551  21.154651
# Net lending (+) / Net borrowing (-)                  3.440569  -0.078039
# Primary net lending / borrowing                      3.926150   0.200756
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN        NaN
# Net acquisition of financial assets                 -0.147187  -0.271210
# Net incurrence of liabilities                       -3.413301   0.096183
#
#                                                          2021
# TRANSACTIONS AFFECTING NET WORTH                          NaN
# Revenue                                             13.959096
# Taxes                                                7.996867
# Social contributions                                 0.000000
# Grants received                                      4.989224
# Other revenue                                        0.973005
# Expense                                             11.363790
# Compensation of employees                            5.670807
# Use of goods and services                            3.602243
# Consumption of fixed capital                              NaN
# Interest                                             0.587939
# Subsidies                                            0.000000
# Grants                                               0.000000
# Social benefits                                      0.000000
# Other expense                                        1.502801
# Gross operating balance                              2.595306
# Net operating balance                                     NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                       NaN
# Net/gross investment in nonfinancial assets          6.530569
# Expenditure                                         17.894359
# Net lending (+) / Net borrowing (-)                 -3.935263
# Primary net lending / borrowing                     -3.347324
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...        NaN
# Net acquisition of financial assets                 -0.202092
# Net incurrence of liabilities                        3.538617

# %% [markdown]
# Calculate Yearly Averages

# %%
data_by_year_table = {
  2010: [],
  2011: [],
  2012: [],
  2013: [],
  2014: [],
  2015: [],
  2016: [],
  2017: [],
  2018: [],
  2019: [],
  2020: [],
  2021: [],
  2022: []
} #make table that stores data by year

# master_averages_ls = [] #make master averages list as place to store averages

for key in master_table:
  years_available = master_table[key].columns
  for year in data_by_year_table:
    if year in years_available:
      data_by_year_table[year].append(master_table[key][year])

yearly_averages_ls = [] #make a list of the yearly averages
for year in data_by_year_table:
  merged_year_df = pd.concat(data_by_year_table[year], axis=1, join='outer')
  #SUM OR MEAN?
  year_average_df = merged_year_df.mean(axis=1) #get the average of all the countries' averages
  yearly_averages_ls.append(year_average_df)

 
# #Get average over decade
# #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
# for key in master_table:
#   per_category_average = master_table[key].mean(axis=1) #get the average of each category (ignoring np.NaN values) into a list
#   # per_category_average.drop('To other government units', inplace=True) #drop 'To other government units' since there's two rows named that and will error
#   master_averages_ls.append(per_category_average) #add each country average to to the master averages list



# merged_averages_df = pd.concat(master_averages_ls, axis=1, join='outer')
# average__of_averages_df = merged_averages_df.mean(axis=1) #get the average of all the countries' averages
# average__of_averages_df

for i in range(len(yearly_averages_ls)):
  print(f"YEAR: {2010+i}")
  print(yearly_averages_ls[i])
# Out:
# YEAR: 2010
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         21.063443
# Taxes                                                           10.938553
# Social contributions                                             0.062040
# Grants received                                                  7.135384
# Other revenue                                                    2.925076
# Expense                                                         13.528551
# Compensation of employees                                        4.715324
# Use of goods and services                                        3.673693
# Consumption of fixed capital                                          NaN
# Interest                                                         0.873144
# Subsidies                                                        0.792820
# Grants                                                           2.446346
# Social benefits                                                  0.307300
# Other expense                                                    0.726125
# Gross operating balance                                          7.534892
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      8.399545
# Expenditure                                                     21.928096
# Net lending (+) / Net borrowing (-)                             -0.864653
# Primary net lending / borrowing                                  0.008491
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              2.715841
# Net incurrence of liabilities                                    2.561783
# dtype: float64
# YEAR: 2011
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         19.995158
# Taxes                                                           11.600518
# Social contributions                                             0.072559
# Grants received                                                  5.460448
# Other revenue                                                    2.860171
# Expense                                                         13.634092
# Compensation of employees                                        4.803576
# Use of goods and services                                        3.694429
# Consumption of fixed capital                                          NaN
# Interest                                                         0.850018
# Subsidies                                                        0.677585
# Grants                                                           2.544556
# Social benefits                                                  0.358821
# Other expense                                                    0.656783
# Gross operating balance                                          6.361066
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      8.477598
# Expenditure                                                     22.111691
# Net lending (+) / Net borrowing (-)                             -2.116532
# Primary net lending / borrowing                                 -1.266514
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              2.316412
# Net incurrence of liabilities                                    4.048313
# dtype: float64
# YEAR: 2012
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         18.031665
# Taxes                                                           11.520905
# Social contributions                                             0.049588
# Grants received                                                  3.668378
# Other revenue                                                    2.789183
# Expense                                                         13.546288
# Compensation of employees                                        5.081041
# Use of goods and services                                        3.187324
# Consumption of fixed capital                                          NaN
# Interest                                                         0.853688
# Subsidies                                                        0.428595
# Grants                                                           2.546644
# Social benefits                                                  0.309916
# Other expense                                                    1.150202
# Gross operating balance                                          4.485376
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      6.939607
# Expenditure                                                     20.485895
# Net lending (+) / Net borrowing (-)                             -2.454230
# Primary net lending / borrowing                                 -1.600542
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.414289
# Net incurrence of liabilities                                    4.487814
# dtype: float64
# YEAR: 2013
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         18.701682
# Taxes                                                           11.767595
# Social contributions                                             0.060556
# Grants received                                                  3.784989
# Other revenue                                                    3.042385
# Expense                                                         12.868084
# Compensation of employees                                        4.707015
# Use of goods and services                                        2.982431
# Consumption of fixed capital                                          NaN
# Interest                                                         0.926815
# Subsidies                                                        0.532295
# Grants                                                           2.774043
# Social benefits                                                  0.222304
# Other expense                                                    0.783349
# Gross operating balance                                          5.217018
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      6.767331
# Expenditure                                                     19.687995
# Net lending (+) / Net borrowing (-)                             -1.121167
# Primary net lending / borrowing                                 -0.202408
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.254924
# Net incurrence of liabilities                                    3.067843
# dtype: float64
# YEAR: 2014
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         18.193926
# Taxes                                                           11.890217
# Social contributions                                             0.058249
# Grants received                                                  3.748617
# Other revenue                                                    2.499642
# Expense                                                         13.338230
# Compensation of employees                                        4.865680
# Use of goods and services                                        3.035385
# Consumption of fixed capital                                          NaN
# Interest                                                         1.053247
# Subsidies                                                        0.340774
# Grants                                                           2.913037
# Social benefits                                                  0.254725
# Other expense                                                    0.886506
# Gross operating balance                                          4.190387
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      6.475604
# Expenditure                                                     19.813834
# Net lending (+) / Net borrowing (-)                             -2.285218
# Primary net lending / borrowing                                 -1.231971
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              0.506078
# Net incurrence of liabilities                                    3.433516
# dtype: float64
# YEAR: 2015
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.451986
# Taxes                                                           12.443837
# Social contributions                                             0.059527
# Grants received                                                  2.986142
# Other revenue                                                    1.965340
# Expense                                                         14.432420
# Compensation of employees                                        5.245934
# Use of goods and services                                        3.192244
# Consumption of fixed capital                                          NaN
# Interest                                                         1.200777
# Subsidies                                                        0.411863
# Grants                                                           3.351484
# Social benefits                                                  0.273183
# Other expense                                                    0.782558
# Gross operating balance                                          2.545327
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      6.076293
# Expenditure                                                     20.508713
# Net lending (+) / Net borrowing (-)                             -3.530966
# Primary net lending / borrowing                                 -2.330189
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.216620
# Net incurrence of liabilities                                    4.991163
# dtype: float64
# YEAR: 2016
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.376689
# Taxes                                                           12.651722
# Social contributions                                             0.051425
# Grants received                                                  2.938481
# Other revenue                                                    1.737509
# Expense                                                         14.631926
# Compensation of employees                                        5.494528
# Use of goods and services                                        3.216913
# Consumption of fixed capital                                          NaN
# Interest                                                         1.410778
# Subsidies                                                        0.437096
# Grants                                                           3.017398
# Social benefits                                                  0.333392
# Other expense                                                    0.731595
# Gross operating balance                                          2.744763
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      6.119727
# Expenditure                                                     20.751653
# Net lending (+) / Net borrowing (-)                             -3.374964
# Primary net lending / borrowing                                 -1.964186
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.393913
# Net incurrence of liabilities                                    4.746778
# dtype: float64
# YEAR: 2017
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.154172
# Taxes                                                           12.623811
# Social contributions                                             0.063683
# Grants received                                                  2.703993
# Other revenue                                                    1.765717
# Expense                                                         14.667786
# Compensation of employees                                        5.344035
# Use of goods and services                                        3.100452
# Consumption of fixed capital                                     0.000000
# Interest                                                         1.583879
# Subsidies                                                        0.395678
# Grants                                                           2.947100
# Social benefits                                                  0.373003
# Other expense                                                    0.931018
# Gross operating balance                                          2.486385
# Net operating balance                                            0.699260
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      5.367721
# Expenditure                                                     20.035507
# Net lending (+) / Net borrowing (-)                             -2.881336
# Primary net lending / borrowing                                 -1.297457
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              0.519291
# Net incurrence of liabilities                                    3.864838
# dtype: float64
# YEAR: 2018
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.122745
# Taxes                                                           12.399649
# Social contributions                                             0.091028
# Grants received                                                  2.249869
# Other revenue                                                    2.386753
# Expense                                                         14.638163
# Compensation of employees                                        5.265090
# Use of goods and services                                        3.025813
# Consumption of fixed capital                                     0.000000
# Interest                                                         1.850373
# Subsidies                                                        0.562530
# Grants                                                           2.675189
# Social benefits                                                  0.388726
# Other expense                                                    0.926697
# Gross operating balance                                          2.484583
# Net operating balance                                            6.680931
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      4.991189
# Expenditure                                                     19.629352
# Net lending (+) / Net borrowing (-)                             -2.506606
# Primary net lending / borrowing                                 -0.656233
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              0.441843
# Net incurrence of liabilities                                    2.834268
# dtype: float64
# YEAR: 2019
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.537634
# Taxes                                                           12.956421
# Social contributions                                             0.050622
# Grants received                                                  2.208139
# Other revenue                                                    2.325265
# Expense                                                         14.685934
# Compensation of employees                                        5.284159
# Use of goods and services                                        2.851798
# Consumption of fixed capital                                     0.000000
# Interest                                                         2.110072
# Subsidies                                                        0.735467
# Grants                                                           2.536607
# Social benefits                                                  0.420471
# Other expense                                                    0.788219
# Gross operating balance                                          2.851700
# Net operating balance                                            8.102289
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      4.842148
# Expenditure                                                     19.528082
# Net lending (+) / Net borrowing (-)                             -1.990448
# Primary net lending / borrowing                                  0.119624
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.835022
# Net incurrence of liabilities                                    3.890949
# dtype: float64
# YEAR: 2020
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         16.761833
# Taxes                                                           12.356225
# Social contributions                                             0.053273
# Grants received                                                  2.427449
# Other revenue                                                    1.927689
# Expense                                                         16.183443
# Compensation of employees                                        5.654306
# Use of goods and services                                        3.100072
# Consumption of fixed capital                                          NaN
# Interest                                                         2.033043
# Subsidies                                                        0.791271
# Grants                                                           3.117568
# Social benefits                                                  0.537657
# Other expense                                                    0.991173
# Gross operating balance                                          0.578390
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      5.741619
# Expenditure                                                     21.925062
# Net lending (+) / Net borrowing (-)                             -5.163229
# Primary net lending / borrowing                                 -3.130186
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              0.729676
# Net incurrence of liabilities                                    5.889307
# dtype: float64
# YEAR: 2021
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         16.770780
# Taxes                                                           12.551863
# Social contributions                                             0.046515
# Grants received                                                  1.689377
# Other revenue                                                    2.495091
# Expense                                                         15.889095
# Compensation of employees                                        5.632350
# Use of goods and services                                        3.037104
# Consumption of fixed capital                                     0.000000
# Interest                                                         2.218931
# Subsidies                                                        0.361394
# Grants                                                           3.213370
# Social benefits                                                  0.567548
# Other expense                                                    0.879657
# Gross operating balance                                          0.881686
# Net operating balance                                            4.852123
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      4.897850
# Expenditure                                                     20.786945
# Net lending (+) / Net borrowing (-)                             -4.016164
# Primary net lending / borrowing                                 -1.797233
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                              1.454958
# Net incurrence of liabilities                                    5.295882
# dtype: float64
# YEAR: 2022
# TRANSACTIONS AFFECTING NET WORTH                                      NaN
# Revenue                                                         17.183773
# Taxes                                                           13.205851
# Social contributions                                             0.053558
# Grants received                                                  2.357584
# Other revenue                                                    1.570898
# Expense                                                         17.929468
# Compensation of employees                                        6.089774
# Use of goods and services                                        2.878460
# Consumption of fixed capital                                          NaN
# Interest                                                         2.392129
# Subsidies                                                        0.854991
# Grants                                                           3.857938
# Social benefits                                                  0.605116
# Other expense                                                    1.316828
# Gross operating balance                                         -0.745695
# Net operating balance                                                 NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                                   NaN
# Net/gross investment in nonfinancial assets                      5.508676
# Expenditure                                                     23.438144
# Net lending (+) / Net borrowing (-)                             -6.254371
# Primary net lending / borrowing                                 -3.862242
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIES (FINANCING)          NaN
# Net acquisition of financial assets                             -0.134732
# Net incurrence of liabilities                                    5.130163
# dtype: float64

# %% [markdown]
# Calculate Average Across Period

# %%
merged_percentages_df = pd.concat(yearly_averages_ls, axis=1, join='outer')
average_df = merged_percentages_df.mean(axis=1)
rounded_average_df = average_df.apply(lambda x: round(x, 2))

rounded_average_df = rounded_average_df.to_frame()
rounded_average_df
# Out:
#                                                         0
# TRANSACTIONS AFFECTING NET WORTH                      NaN
# Revenue                                             17.95
# Taxes                                               12.22
# Social contributions                                 0.06
# Grants received                                      3.34
# Other revenue                                        2.33
# Expense                                             14.61
# Compensation of employees                            5.24
# Use of goods and services                            3.15
# Consumption of fixed capital                         0.00
# Interest                                             1.49
# Subsidies                                            0.56
# Grants                                               2.92
# Social benefits                                      0.38
# Other expense                                        0.89
# Gross operating balance                              3.20
# Net operating balance                                5.08
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN
# Net/gross investment in nonfinancial assets          6.20
# Expenditure                                         20.82
# Net lending (+) / Net borrowing (-)                 -2.97
# Primary net lending / borrowing                     -1.48
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN
# Net acquisition of financial assets                  1.20
# Net incurrence of liabilities                        4.17

# %%
#check
first_level = 0
for category in first_level_ls:
  first_level += average_df[category]
print(first_level)

# second_level = 0
# for category in second_level_ls:
#   second_level += average_df[category]
# print(second_level)
# Out:
# 20.837479715601944

# %%
rounded_by_year_average_df = merged_percentages_df.round(2)
rounded_by_year_average_df
# Out:
#                                                        0      1      2   \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             21.06  20.00  18.03
# Taxes                                               10.94  11.60  11.52
# Social contributions                                 0.06   0.07   0.05
# Grants received                                      7.14   5.46   3.67
# Other revenue                                        2.93   2.86   2.79
# Expense                                             13.53  13.63  13.55
# Compensation of employees                            4.72   4.80   5.08
# Use of goods and services                            3.67   3.69   3.19
# Consumption of fixed capital                          NaN    NaN    NaN
# Interest                                             0.87   0.85   0.85
# Subsidies                                            0.79   0.68   0.43
# Grants                                               2.45   2.54   2.55
# Social benefits                                      0.31   0.36   0.31
# Other expense                                        0.73   0.66   1.15
# Gross operating balance                              7.53   6.36   4.49
# Net operating balance                                 NaN    NaN    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          8.40   8.48   6.94
# Expenditure                                         21.93  22.11  20.49
# Net lending (+) / Net borrowing (-)                 -0.86  -2.12  -2.45
# Primary net lending / borrowing                      0.01  -1.27  -1.60
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  2.72   2.32   1.41
# Net incurrence of liabilities                        2.56   4.05   4.49
#
#                                                        3      4      5   \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             18.70  18.19  17.45
# Taxes                                               11.77  11.89  12.44
# Social contributions                                 0.06   0.06   0.06
# Grants received                                      3.78   3.75   2.99
# Other revenue                                        3.04   2.50   1.97
# Expense                                             12.87  13.34  14.43
# Compensation of employees                            4.71   4.87   5.25
# Use of goods and services                            2.98   3.04   3.19
# Consumption of fixed capital                          NaN    NaN    NaN
# Interest                                             0.93   1.05   1.20
# Subsidies                                            0.53   0.34   0.41
# Grants                                               2.77   2.91   3.35
# Social benefits                                      0.22   0.25   0.27
# Other expense                                        0.78   0.89   0.78
# Gross operating balance                              5.22   4.19   2.55
# Net operating balance                                 NaN    NaN    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          6.77   6.48   6.08
# Expenditure                                         19.69  19.81  20.51
# Net lending (+) / Net borrowing (-)                 -1.12  -2.29  -3.53
# Primary net lending / borrowing                     -0.20  -1.23  -2.33
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  1.25   0.51   1.22
# Net incurrence of liabilities                        3.07   3.43   4.99
#
#                                                        6      7      8   \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             17.38  17.15  17.12
# Taxes                                               12.65  12.62  12.40
# Social contributions                                 0.05   0.06   0.09
# Grants received                                      2.94   2.70   2.25
# Other revenue                                        1.74   1.77   2.39
# Expense                                             14.63  14.67  14.64
# Compensation of employees                            5.49   5.34   5.27
# Use of goods and services                            3.22   3.10   3.03
# Consumption of fixed capital                          NaN   0.00   0.00
# Interest                                             1.41   1.58   1.85
# Subsidies                                            0.44   0.40   0.56
# Grants                                               3.02   2.95   2.68
# Social benefits                                      0.33   0.37   0.39
# Other expense                                        0.73   0.93   0.93
# Gross operating balance                              2.74   2.49   2.48
# Net operating balance                                 NaN   0.70   6.68
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          6.12   5.37   4.99
# Expenditure                                         20.75  20.04  19.63
# Net lending (+) / Net borrowing (-)                 -3.37  -2.88  -2.51
# Primary net lending / borrowing                     -1.96  -1.30  -0.66
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  1.39   0.52   0.44
# Net incurrence of liabilities                        4.75   3.86   2.83
#
#                                                        9      10     11     12
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN    NaN
# Revenue                                             17.54  16.76  16.77  17.18
# Taxes                                               12.96  12.36  12.55  13.21
# Social contributions                                 0.05   0.05   0.05   0.05
# Grants received                                      2.21   2.43   1.69   2.36
# Other revenue                                        2.33   1.93   2.50   1.57
# Expense                                             14.69  16.18  15.89  17.93
# Compensation of employees                            5.28   5.65   5.63   6.09
# Use of goods and services                            2.85   3.10   3.04   2.88
# Consumption of fixed capital                         0.00    NaN   0.00    NaN
# Interest                                             2.11   2.03   2.22   2.39
# Subsidies                                            0.74   0.79   0.36   0.85
# Grants                                               2.54   3.12   3.21   3.86
# Social benefits                                      0.42   0.54   0.57   0.61
# Other expense                                        0.79   0.99   0.88   1.32
# Gross operating balance                              2.85   0.58   0.88  -0.75
# Net operating balance                                8.10    NaN   4.85    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          4.84   5.74   4.90   5.51
# Expenditure                                         19.53  21.93  20.79  23.44
# Net lending (+) / Net borrowing (-)                 -1.99  -5.16  -4.02  -6.25
# Primary net lending / borrowing                      0.12  -3.13  -1.80  -3.86
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN    NaN
# Net acquisition of financial assets                  1.84   0.73   1.45  -0.13
# Net incurrence of liabilities                        3.89   5.89   5.30   5.13

# %% [markdown]
# Plot Over Time

# %%
rounded_by_year_average_df.columns = [str(int(col) + 2010) for col in rounded_by_year_average_df.columns]

def graph(rows_to_plot):
    # sns.set(style="whitegrid")

    # Plotting
    plt.figure(figsize=(10, 6))
    for row in rows_to_plot:
        sns.lineplot(x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], marker='o', label=row)

    # Add labels and title
    plt.xlabel('Year', fontsize=12)
    plt.ylabel('Percentage of GDP', fontsize=12)
    # plt.title('Percentage of Tax Revenue Over Time')

    # Customize the legend
    plt.legend(title='Category', title_fontsize='12', fontsize='10', loc='upper right')

    # Customize the ticks and grid
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', linewidth=0.5)

    # Adjust y-axis limits to be 120% of the original range
    y_min, y_max = plt.ylim()
    y_range = y_max - y_min
    plt.ylim(y_min, y_max + 0.25 * y_range)

    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
graph(['Net/gross investment in nonfinancial assets', 'Compensation of employees', 'Use of goods and services', 'Interest', 'Subsidies', 'Grants'])
graph(['Net lending (+) / Net borrowing (-)', 'Interest'])
graph(['Net/gross investment in nonfinancial assets', 'Interest'])

# %%
net_lending = rounded_by_year_average_df.loc['Net lending (+) / Net borrowing (-)']
net_borrowing = -1 * net_lending
rounded_by_year_average_df.loc['Net Borrowing'] = net_borrowing

current_spending = rounded_by_year_average_df.loc["Expense"]
interest = rounded_by_year_average_df.loc["Interest"]
current_minus_interest = current_spending - interest
rounded_by_year_average_df.loc['Current Spending minus Interest'] = current_minus_interest


social = rounded_by_year_average_df.loc['Social contributions']
other = rounded_by_year_average_df.loc['Other revenue']
other_rev_minus_grants = social + other
rounded_by_year_average_df.loc['Other Revenue minus Grants'] = other_rev_minus_grants


rounded_by_year_average_df.loc['Current Spending'] = current_spending


rounded_by_year_average_df
# Out:
#                                                      2010   2011   2012  \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             21.06  20.00  18.03
# Taxes                                               10.94  11.60  11.52
# Social contributions                                 0.06   0.07   0.05
# Grants received                                      7.14   5.46   3.67
# Other revenue                                        2.93   2.86   2.79
# Expense                                             13.53  13.63  13.55
# Compensation of employees                            4.72   4.80   5.08
# Use of goods and services                            3.67   3.69   3.19
# Consumption of fixed capital                          NaN    NaN    NaN
# Interest                                             0.87   0.85   0.85
# Subsidies                                            0.79   0.68   0.43
# Grants                                               2.45   2.54   2.55
# Social benefits                                      0.31   0.36   0.31
# Other expense                                        0.73   0.66   1.15
# Gross operating balance                              7.53   6.36   4.49
# Net operating balance                                 NaN    NaN    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          8.40   8.48   6.94
# Expenditure                                         21.93  22.11  20.49
# Net lending (+) / Net borrowing (-)                 -0.86  -2.12  -2.45
# Primary net lending / borrowing                      0.01  -1.27  -1.60
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  2.72   2.32   1.41
# Net incurrence of liabilities                        2.56   4.05   4.49
# Net Borrowing                                        0.86   2.12   2.45
# Current Spending minus Interest                     12.66  12.78  12.70
# Other Revenue minus Grants                           2.99   2.93   2.84
# Current Spending                                    13.53  13.63  13.55
#
#                                                      2013   2014   2015  \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             18.70  18.19  17.45
# Taxes                                               11.77  11.89  12.44
# Social contributions                                 0.06   0.06   0.06
# Grants received                                      3.78   3.75   2.99
# Other revenue                                        3.04   2.50   1.97
# Expense                                             12.87  13.34  14.43
# Compensation of employees                            4.71   4.87   5.25
# Use of goods and services                            2.98   3.04   3.19
# Consumption of fixed capital                          NaN    NaN    NaN
# Interest                                             0.93   1.05   1.20
# Subsidies                                            0.53   0.34   0.41
# Grants                                               2.77   2.91   3.35
# Social benefits                                      0.22   0.25   0.27
# Other expense                                        0.78   0.89   0.78
# Gross operating balance                              5.22   4.19   2.55
# Net operating balance                                 NaN    NaN    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          6.77   6.48   6.08
# Expenditure                                         19.69  19.81  20.51
# Net lending (+) / Net borrowing (-)                 -1.12  -2.29  -3.53
# Primary net lending / borrowing                     -0.20  -1.23  -2.33
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  1.25   0.51   1.22
# Net incurrence of liabilities                        3.07   3.43   4.99
# Net Borrowing                                        1.12   2.29   3.53
# Current Spending minus Interest                     11.94  12.29  13.23
# Other Revenue minus Grants                           3.10   2.56   2.03
# Current Spending                                    12.87  13.34  14.43
#
#                                                      2016   2017   2018  \
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN
# Revenue                                             17.38  17.15  17.12
# Taxes                                               12.65  12.62  12.40
# Social contributions                                 0.05   0.06   0.09
# Grants received                                      2.94   2.70   2.25
# Other revenue                                        1.74   1.77   2.39
# Expense                                             14.63  14.67  14.64
# Compensation of employees                            5.49   5.34   5.27
# Use of goods and services                            3.22   3.10   3.03
# Consumption of fixed capital                          NaN   0.00   0.00
# Interest                                             1.41   1.58   1.85
# Subsidies                                            0.44   0.40   0.56
# Grants                                               3.02   2.95   2.68
# Social benefits                                      0.33   0.37   0.39
# Other expense                                        0.73   0.93   0.93
# Gross operating balance                              2.74   2.49   2.48
# Net operating balance                                 NaN   0.70   6.68
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          6.12   5.37   4.99
# Expenditure                                         20.75  20.04  19.63
# Net lending (+) / Net borrowing (-)                 -3.37  -2.88  -2.51
# Primary net lending / borrowing                     -1.96  -1.30  -0.66
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN
# Net acquisition of financial assets                  1.39   0.52   0.44
# Net incurrence of liabilities                        4.75   3.86   2.83
# Net Borrowing                                        3.37   2.88   2.51
# Current Spending minus Interest                     13.22  13.09  12.79
# Other Revenue minus Grants                           1.79   1.83   2.48
# Current Spending                                    14.63  14.67  14.64
#
#                                                      2019   2020   2021   2022
# TRANSACTIONS AFFECTING NET WORTH                      NaN    NaN    NaN    NaN
# Revenue                                             17.54  16.76  16.77  17.18
# Taxes                                               12.96  12.36  12.55  13.21
# Social contributions                                 0.05   0.05   0.05   0.05
# Grants received                                      2.21   2.43   1.69   2.36
# Other revenue                                        2.33   1.93   2.50   1.57
# Expense                                             14.69  16.18  15.89  17.93
# Compensation of employees                            5.28   5.65   5.63   6.09
# Use of goods and services                            2.85   3.10   3.04   2.88
# Consumption of fixed capital                         0.00    NaN   0.00    NaN
# Interest                                             2.11   2.03   2.22   2.39
# Subsidies                                            0.74   0.79   0.36   0.85
# Grants                                               2.54   3.12   3.21   3.86
# Social benefits                                      0.42   0.54   0.57   0.61
# Other expense                                        0.79   0.99   0.88   1.32
# Gross operating balance                              2.85   0.58   0.88  -0.75
# Net operating balance                                8.10    NaN   4.85    NaN
# TRANSACTIONS IN NONFINANCIAL ASSETS                   NaN    NaN    NaN    NaN
# Net/gross investment in nonfinancial assets          4.84   5.74   4.90   5.51
# Expenditure                                         19.53  21.93  20.79  23.44
# Net lending (+) / Net borrowing (-)                 -1.99  -5.16  -4.02  -6.25
# Primary net lending / borrowing                      0.12  -3.13  -1.80  -3.86
# TRANSACTIONS IN FINANCIAL ASSETS AND LIABILITIE...    NaN    NaN    NaN    NaN
# Net acquisition of financial assets                  1.84   0.73   1.45  -0.13
# Net incurrence of liabilities                        3.89   5.89   5.30   5.13
# Net Borrowing                                        1.99   5.16   4.02   6.25
# Current Spending minus Interest                     12.58  14.15  13.67  15.54
# Other Revenue minus Grants                           2.38   1.98   2.55   1.62
# Current Spending                                    14.69  16.18  15.89  17.93

# %%
graph(['Net Borrowing', 'Current Spending', 'Net/gross investment in nonfinancial assets', 'Taxes', 'Other Revenue minus Grants', 'Grants received'])

# %%
#net borrowing = - opposite of net lending
#current spending - net interest = expenses - net interest
#capital spending
#tax revenue
#non-tax revenue = revenue - tax
#interest

# rows_to_plot =  ["Net Borrowing", "Current Spending minus Interest", "Net/gross investment in nonfinancial assets", "Taxes", "Other Revenue", "Interest"]
# # Plotting
# plt.figure(figsize=(10, 6))
# for row in rows_to_plot:
#   sns.lineplot(x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], marker='o', label=row)

#     # Add labels and title
# plt.xlabel('Year', fontsize=12)
# plt.ylabel('Percentage of Expenditure', fontsize=12)
#     # plt.title('Percentage of Tax Revenue Over Time')

#     # Customize the legend
# plt.legend(title='Category', title_fontsize='12', fontsize='10', loc='upper right')

#     # Customize the ticks and grid
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.grid(True, linestyle='--', linewidth=0.5)

#     # Adjust y-axis limits to be 120% of the original range
# y_min, y_max = plt.ylim()
# y_range = y_max - y_min
# plt.ylim(y_min, y_max + 0.25 * y_range)

#     # Show the plot
# plt.tight_layout()
# plt.show()



# Define rows to plot
rows_to_plot = [
    "Net Borrowing", 
    "Current Spending minus Interest", 
    "Net/gross investment in nonfinancial assets", 
    "Taxes", 
    "Other Revenue minus Grants", 
    "Grants received"
    "Interest"
]

# Define markers
marker_style_1 = '-'  # Circle marker
marker_style_2 = '--'  # Square marker

# Define which rows get which marker
rows_with_marker_1 = ["Net Borrowing", "Taxes", "Other Revenue minus Grants", "Grants received"]
rows_with_marker_2 = [
    "Current Spending minus Interest", 
    "Net/gross investment in nonfinancial assets"
]


#new
# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot the first set of rows
for row in rows_with_marker_1 + rows_with_marker_2:
    if row in rows_with_marker_1:
        linestyle = marker_style_1
    else:
        linestyle = marker_style_2
    sns.lineplot(ax=ax1, x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], linestyle=linestyle, label=row)

# Customize the first y-axis
ax1.set_xlabel('Year', fontsize=12)
ax1.set_ylabel('Percentage of GDP', fontsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.grid(True, linestyle='--', linewidth=0.5)

# Create a second y-axis for "Interest"
ax2 = ax1.twinx()
sns.lineplot(ax=ax2, x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc["Interest"], linestyle='--', color='#00BFFF', label='_nolegend_')

# Customize the second y-axis
ax2.set_ylabel('Percentage of GDP (Interest)', fontsize=12, color='#00BFFF')
ax2.tick_params(axis='y', labelsize=12, colors='#00BFFF')

# Combine legends from both y-axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, title='Category', title_fontsize='12', fontsize='10', loc='upper right')

# lines, labels = ax1.get_legend_handles_labels()
# ax1.legend(lines, labels, title='Category', title_fontsize='12', fontsize='10', loc='upper right')
# lines, labels = ax1.get_legend_handles_labels()
# ax1.legend(lines, labels, title='Category', title_fontsize='12', fontsize='10', loc='upper right')


# Adjust y-axis limits to be 120% of the original range
y_min, y_max = ax1.get_ylim()
y_range = y_max - y_min
ax1.set_ylim(y_min, y_max + 0.4 * y_range)
ax2.set_ylim(0, 3.5)

# Show the plot
plt.tight_layout()
plt.show()
