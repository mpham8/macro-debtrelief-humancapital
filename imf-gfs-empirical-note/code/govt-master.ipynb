# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Config

# %%
folder_path = "../data/revenue-data" #set folder_path to "expenditure-investment-data" or "revenue-data"
taxes_or_expenditure = "Taxes" #set type to "Taxes" or "Expenditure"
unweighted_or_aggregated = "aggregated" #set unweighted_or_aggregate to "unweighted" or "aggregated"
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019] #set yours want to analyze
years_filter = 7

graphs = [ #each row is over time graph
  ['Revenue', 'Grants', 'Other revenue'],
  ['Taxes on income, profits, & capital gains', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.'],
  ['Property income', 'Sales of goods & services', 'Other transfers'],
  ['Taxes on income, profits, & capital gains: individuals', 'Taxes on income, profits, & capital gains: corporations', 'General taxes on goods & services', 'Excise taxes']
]

# graphs = [
#   ['Net/gross investment in nonfinancial assets', 'Compensation of employees', 'Use of goods and services', 'Interest', 'Subsidies', 'Grants'],
#   ['Net lending (+) / Net borrowing (-)', 'Interest'],
#   ['Net/gross investment in nonfinancial assets', 'Interest']
# ]

# %% [markdown]
# Currency Codes

# %%
country_currency_codes_table = {
    'Burundi': 'BIF',
    'Benin': 'XOF',
    'Burkina Faso': 'XOF',
    'Central African Republic': 'XAF',
    "Côte d'Ivoire": 'XOF',
    'Cameroon': 'XAF',
    'Democratic Republic of the Congo': 'CDF',
    'Republic of Congo': 'XAF',
    'Comoros': 'KMF',
    'Eritrea': 'ERN',
    'Ethiopia': 'ETB',
    'Ghana': 'GHS',
    'Guinea': 'GNF',
    'The Gambia': 'GMD',
    'Guinea-Bissau': 'XOF',
    'Liberia': 'LRD',
    'Madagascar': 'MGA',
    'Mali': 'XOF',
    'Mozambique': 'MZN',
    'Mauritania': 'MRU',
    'Malawi': 'MWK',
    'Niger': 'XOF',
    'Rwanda': 'RWF',
    'Sudan': 'SDG',
    'Senegal': 'XOF',
    'Sierra Leone': 'SLL',
    'Somalia': 'SOS',
    'Sao Tomee and Principe': 'STN',
    'Chad': 'XAF',
    'Togo': 'XOF',
    'Tanzania': 'TZS',
    'Uganda': 'UGX',
    'Zambia': 'ZMW'
}

# %% [markdown]
# Read Data

# %%
#read in stata dataset as dataframe "country_code_df"
country_code_df = pd.read_stata("codesffactors_Mar23_2019.dta") 
country_code_df.replace('--', np.nan, inplace=True) #replace all entries that are '--' with NaN data value

country_code_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #read in stata dataset as dataframe "country_code_df"
# ----> 2 country_code_df = pd.read_stata("codesffactors_Mar23_2019.dta")
#       3 country_code_df.replace('--', np.nan, inplace=True) #replace all entries that are '--' with NaN data value
#       5 country_code_df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/stata.py:2109, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2106     return reader
#    2108 with reader:
# -> 2109     return reader.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/stata.py:1683, in StataReader.read(self, nrows, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals)
#    1671 @Appender(_read_method_doc)
#    1672 def read(
#    1673     self,
#    (...)
#    1681     order_categoricals: bool | None = None,
#    1682 ) -> DataFrame:
# -> 1683     self._ensure_open()
#    1685     # Handle options
#    1686     if convert_dates is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/stata.py:1175, in StataReader._ensure_open(self)
#    1171 """
#    1172 Ensure the file has been opened and its header data read.
#    1173 """
#    1174 if not hasattr(self, "_path_or_buf"):
# -> 1175     self._open_file()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/stata.py:1188, in StataReader._open_file(self)
#    1181 if not self._entered:
#    1182     warnings.warn(
#    1183         "StataReader is being used without using a context manager. "
#    1184         "Using StataReader as a context manager is the only supported method.",
#    1185         ResourceWarning,
#    1186         stacklevel=find_stack_level(),
#    1187     )
# -> 1188 handles = get_handle(
#    1189     self._original_path_or_buf,
#    1190     "rb",
#    1191     storage_options=self._storage_options,
#    1192     is_text=False,
#    1193     compression=self._compression,
#    1194 )
#    1195 if hasattr(handles.handle, "seekable") and handles.handle.seekable():
#    1196     # If the handle is directly seekable, use it without an extra copy.
#    1197     self._path_or_buf = handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'codesffactors_Mar23_2019.dta'

# %%
region_classification_ls = country_code_df['wbregion'].unique() #get a list of region classifications
income_classification_ls = country_code_df['wbigroup2017'].unique() #get a list of income classifications
income_classification_ls = [x for x in income_classification_ls if not pd.isna(x)] # remove '--' from income_classification_ls

print(f"The region classifications are: {', '.join(country for country in region_classification_ls)}")
print(f"The income classifications are: {', '.join(country for country in income_classification_ls)}")
# Out:
# The region classifications are: Latin America & Caribbean, South Asia, Sub-Saharan Africa, Europe & Central Asia, Middle East & North Africa, East Asia & Pacific, North America
# The income classifications are: High income, Low income, Lower middle income, Upper middle income

# %%
ssa_hipc_countries = country_code_df[(country_code_df['hipc'] == 1) & (country_code_df['wbregion'] == 'Sub-Saharan Africa')]
ssa_hipc_countries_ls = ssa_hipc_countries['imfweoctry'].to_list()

ssa_hipc_countries_ls
# Out:
# ['Burundi',
#  'Benin',
#  'Burkina Faso',
#  'Central African Republic',
#  "Côte d'Ivoire",
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Republic of Congo',
#  'Comoros',
#  'Eritrea',
#  'Ethiopia',
#  'Ghana',
#  'Guinea',
#  'The Gambia',
#  'Guinea-Bissau',
#  'Liberia',
#  'Madagascar',
#  'Mali',
#  'Mozambique',
#  'Mauritania',
#  'Malawi',
#  'Niger',
#  'Rwanda',
#  'Sudan',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'São Tomé and Príncipe',
#  'Chad',
#  'Togo',
#  'Tanzania',
#  'Uganda',
#  'Zambia']

# %% [markdown]
# Read in IMF's Government Finance Statistics

# %%
master_table = {}

# Loop that goes through all files 'file_name' in the folder 'folder_path'
for file_name in os.listdir(folder_path):
  if file_name.endswith('.xlsx') and not file_name.startswith('~$'): #check to see if is spreadsheet .xlsx format
    raw_df = pd.read_excel(folder_path+ "/" + file_name) #read in .xlsx as dataframe
    master_table[file_name[:-5]] = raw_df #store dataframe as an entry in the master_table hash table

master_table["Togo"]
# for key in master_table:
#   print(master_table[key])
# Out:
#                                            Unnamed: 0  \
# 0                          Detailed Revenue Breakdown
# 1                                       Country: Togo
# 2                Sector: Budgetary central government
# 3                             Unit: Domestic currency
# 4                                     Scale: Billions
# 5                                                 NaN
# 6                                                 NaN
# 7                                             Revenue
# 8                                               Taxes
# 9           Taxes on income, profits, & capital gains
# 10  Taxes on income, profits, & capital gains: ind...
# 11  Taxes on income, profits, & capital gains: cor...
# 12   Taxes on income, profits, & capital gains: other
# 13                       Taxes on payroll & workforce
# 14                                  Taxes on property
# 15                          Taxes on goods & services
# 16                  General taxes on goods & services
# 17                                       Excise taxes
# 18                  Taxes on int trade & transactions
# 19                                 Other taxes n.e.c.
# 20                               Social contributions
# 21                      Social security contributions
# 22                         Other social contributions
# 23                                             Grants
# 24                          Grants from foreign govts
# 25                               Grants from int orgs
# 26                         Grants from other gen govt
# 27                Grants from other gen govt: current
# 28                Grants from other gen govt: capital
# 29                                      Other revenue
# 30                                    Property income
# 31                          Sales of goods & services
# 32                        Fines, penalties & forfeits
# 33                                    Other transfers
# 34                  NI & SGS: premiums, fees & claims
#
#                     Unnamed: 1  Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 0   Detailed Revenue Breakdown         NaN          NaN          NaN
# 1                          NaN         NaN          NaN          NaN
# 2                          NaN         NaN          NaN          NaN
# 3                          NaN         NaN          NaN          NaN
# 4                          NaN         NaN          NaN          NaN
# 5                          NaN         NaN          NaN          NaN
# 6                         2010     2011.00  2012.000000  2013.000000
# 7                   359.243964      401.23   398.596316   479.559000
# 8                   246.773948      291.44   314.027022   359.872000
# 9                    35.970043       41.38    41.515238    57.880885
# 10                   16.410276       14.02    17.294998    21.759559
# 11                   13.434986       19.36    21.089013    31.664081
# 12                    6.124782        8.00     3.131227     4.457245
# 13                    3.701915        3.85     4.380313     3.415160
# 14                    0.759776        0.83     0.504397     0.468860
# 15                  128.842932      155.70   169.106915   177.783000
# 16                  112.278789      139.30   147.835574   152.957000
# 17                   16.221223       16.12    20.535556    23.944116
# 18                   63.371555       73.51    78.678113    95.976299
# 19                   14.127726       16.17    19.842047    24.347561
# 20                           0        0.00     0.000000     0.000000
# 21                           0        0.00     0.000000     0.000000
# 22                           0        0.00     0.000000     0.000000
# 23                   62.256758       84.60    40.692338    73.510500
# 24                           0        0.00     0.000000     0.000000
# 25                   62.256758       84.60    40.692338    73.510500
# 26                           0        0.00     0.000000     0.000000
# 27                           0        0.00     0.000000     0.000000
# 28                           0        0.00     0.000000     0.000000
# 29                   50.213258       25.19    43.876955    46.176704
# 30                   31.748282        8.07    22.992005    21.970938
# 31                    2.047527        2.91     2.970211     3.710393
# 32                           0        0.00     0.000000     0.000000
# 33                   16.417448       14.21    17.914739    20.495373
# 34                           0        0.00     0.000000     0.000000
#
#      Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6   2014.000000  2015.000000  2016.000000  2017.000000  2018.000000
# 7    496.763876   562.356688   604.225592   610.311564   710.794350
# 8    415.629808   468.507362   498.921783   484.332771   502.083773
# 9     59.051105    98.003532    75.992924    86.185978   101.125915
# 10    19.639408    24.477254    23.728005    31.011975    34.090398
# 11    39.411697    73.526279    52.264919    55.174002    67.035516
# 12     0.000000     0.000000     0.000000     0.000000     0.000000
# 13     3.778786     2.697973     4.852346     2.424801     2.385552
# 14     4.233720     1.727430     3.720627     3.337906     1.216743
# 15   221.827666   258.736148   261.715146   287.362617   283.438924
# 16   182.002804   216.237056   211.375161   235.388614   231.040430
# 17    30.155533    35.494361    43.508014    44.653076    45.815389
# 18    99.193995   103.924367   101.895050   101.685626   110.659836
# 19    27.544535     3.417911     1.999015     3.335843     3.256803
# 20     0.000000     0.000000     0.000000     0.000000     0.000000
# 21     0.000000     0.000000     0.000000     0.000000     0.000000
# 22     0.000000     0.000000     0.000000     0.000000     0.000000
# 23    45.762180    57.237663    75.600504    88.526789   105.894866
# 24     0.000000     0.000000     0.000000     1.994560     0.957690
# 25    45.762180    57.237663    75.600504    86.532229   104.937176
# 26     0.000000     0.000000     0.000000     0.000000     0.000000
# 27     0.000000     0.000000     0.000000     0.000000     0.000000
# 28     0.000000     0.000000     0.000000     0.000000     0.000000
# 29    35.371889    36.611663    29.703305    37.452005   102.815710
# 30    26.455790    19.855529    15.218347    24.071510    83.416098
# 31     5.698368     5.367309    10.716187     9.850118    18.251849
# 32     1.707281     0.895926     0.254965     0.000000     1.147763
# 33     1.510449    10.492899     3.513806     3.530376     0.000000
# 34     0.000000     0.000000     0.000000     0.000000     0.000000
#
#     Unnamed: 10
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6   2019.000000
# 7    746.915731
# 8    556.531390
# 9    119.292328
# 10    36.363470
# 11    82.928858
# 12     0.000000
# 13     1.664815
# 14     8.021254
# 15   305.398869
# 16   246.928591
# 17    38.471200
# 18   119.082971
# 19     3.071152
# 20     0.000000
# 21     0.000000
# 22     0.000000
# 23   122.423147
# 24     2.927850
# 25   119.495297
# 26     0.000000
# 27     0.000000
# 28     0.000000
# 29    67.961194
# 30    41.201066
# 31    23.677935
# 32     1.861345
# 33     0.000000
# 34     1.220849

# %% [markdown]
# Filtering

# %%
#REMOVE "JUNK" ROWS AND CONVERT TO CORRECT SCALE (MILLION/BILLIONS)
for key in master_table: #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
  scale = master_table[key].iloc[4,0] #get if values have scale of billions or millions
  
  # Drop rows 0 to 5, reformatting indexes and column headers
  master_table[key] = master_table[key].drop([0, 1, 2, 3, 4, 5])
  if taxes_or_expenditure == "Expenditure":
    master_table[key] = master_table[key].drop([11])
  master_table[key] = master_table[key].reset_index(drop=True) 
  master_table[key].columns = master_table[key].iloc[0]
  master_table[key] = master_table[key][1:]
  master_table[key] = master_table[key].set_index(master_table[key].columns[0])
  master_table[key].columns = [int(float(col)) for col in master_table[key].columns]
  # master_table[key] = master_table[key].fillna(0)

  if unweighted_or_aggregated == "aggregated":
    if scale == "Scale: Billions":
      master_table[key] = master_table[key]* (10 ** 9) #multiple every value in dataframe by 1e9 if scale is billion
    elif scale == "Scale: Millions":
      master_table[key] = master_table[key]* (10 ** 6) #multiple every value in dataframe by 1e9 if scale is billion


#FILTER OUT YEAR COLUMNS ACCOUNTING DOESNT ADD UP
#first level: make sure 'Taxes', 'Social Contributions', 'Grants, 'Other Revenue' Sums to 'Revenue'
#second level: make sure 'Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.' sum to 'Taxes'
if taxes_or_expenditure == "Expenditure":
  first_level_ls = ['Compensation of employees', 'Use of goods and services', 'Consumption of fixed capital', 'Interest', 'Subsidies', 'Grants', 'Social benefits', 'Other expense', 'Net/gross investment in nonfinancial assets']
else:
  first_level_ls = ['Taxes', 'Social contributions', 'Grants', 'Other revenue']
  second_level_ls = ['Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.']
                  
for key in master_table:
  years_accounting_error_ls = []
  years_available = master_table[key].columns
  for year in years_available:
    country_year_df = master_table[key][year]
    first_level_total = 0 
    second_level_total = 0
    for category in first_level_ls:
      if category in country_year_df.index:
        first_level_total += country_year_df[category]
      # else: 
      #   print(category)
    if taxes_or_expenditure == "Taxes":
      for category in second_level_ls:
        if category in country_year_df.index:
          second_level_total += country_year_df[category]
    # if round(taxes, 0) != round(country_year_df['Taxes'], 0) or round(revenue, 0) != round(country_year_df['Revenue'], 0):
    
    margin = 0.001
    if taxes_or_expenditure == "Taxes":
      lower_bound_taxes = country_year_df['Taxes'] - country_year_df['Taxes']*margin
      upper_bound_taxes = country_year_df['Taxes'] + country_year_df['Taxes']*margin
      lower_bound_revenue = country_year_df['Revenue'] - country_year_df['Revenue']*margin
      upper_bound_revenue = country_year_df['Revenue'] + country_year_df['Revenue']*margin

      if second_level_total < lower_bound_taxes or second_level_total > upper_bound_taxes or first_level_total < lower_bound_revenue or first_level_total > upper_bound_revenue:
        print(f"{round(first_level_total, 0)}, {round(country_year_df['Taxes'], 0)}, {round(first_level_total, 0)}, {round(country_year_df['Revenue'], 0)}")
        years_accounting_error_ls.append(year)

    elif taxes_or_expenditure == "Expenditure":
      lower_bound_exp = country_year_df['Expenditure'] - country_year_df['Expenditure']*margin
      upper_bound_exp = country_year_df['Expenditure'] + country_year_df['Expenditure']*margin
      if first_level_total < lower_bound_exp or first_level_total > upper_bound_exp:
        print(f"{round(first_level_total, 0)}, {round(country_year_df['exp'], 0)}")
        years_accounting_error_ls.append(year)
  
  print(key)
  print(years_accounting_error_ls)
  master_table[key].drop(columns=years_accounting_error_ls, inplace=True)
 
    
    

#FILTER OUT COUNTRIES WITH LESS THAN 7 YEARS OF DATA
less_than_seven_years_data_countries = [] #create list to store countries with less than 7 years of historial data
for key in master_table: #iterate through master_table
  num_columns = master_table[key].shape[1] #count the number of columns (each column represents a year)
  if num_columns < years_filter: #if less than 7 columns/year, add to list to delete
    less_than_seven_years_data_countries.append(key)

print('remove')
for country in less_than_seven_years_data_countries:
  print(country)
  del master_table[country] #delete countries with less than 7 years from data table
# Out:
# Benin
# []
# Senegal
# []
# Côte d'Ivoire
# []
# Burkina Faso
# []
# Central African Republic
# []
# Somalia
# []
# Tanzania
# []
# Democratic Republic of the Congo
# []
# Rwanda
# []
# Republic of Congo
# []
# Sudan
# []
# 604225591780.0, 498921783147.0, 604225591780.0, 604225591780.0
# Togo
# [2016]
# Mali
# []
# Malawi
# []
# Sao Tomee and Principe
# []
# Mozambique
# []
# Sierra Leone
# []
# Guinea-Bissau
# []
# Burundi
# []
# Liberia
# []
# Cameroon
# []
# Madagascar
# []
# remove
# Benin
# Somalia
# Guinea-Bissau
# Liberia

# %% [markdown]
# Convert Currency

# %%
print('keep')
for key in master_table:
  print(key)

#CONVERT LOCAL CURRENCY DENOMINATED VALUES TO USD
if unweighted_or_aggregated == "aggregated":
  error_countries = []
  for key in master_table:
    #get annual 2010-2019 USD to domestic currency exchange rate using yfinance library
    currency = country_currency_codes_table[key] #retrieve currency symbol from 'country_currency_codes_table'
    symbol = f"{currency}=X"
    try:
      start_date = str(years[0]) + "-01-01"
      end_date = str(years[-1] + 1) + "-01-01"
      data = yf.download(symbol, start=start_date, end=end_date, interval="1mo") #download monthly USD-Currency dataset from 2010-2020
      yearly_data_df = data['Close'].resample('YE').mean() #get the annual average exchange rate outputted as datafram
      yearly_data_table = yearly_data_df.to_dict() # Convert the yearly_data to a hash table with the date as the key
      year_to_exchange_rate_dict = {key.year: value for key, value in yearly_data_table.items()} # Convert the keys to only the year part
      print(year_to_exchange_rate_dict)

      #convert DataFrame values to USD
      for year in master_table[key].columns: #loop through columns in dataframe
        year_int = int(year)  # Convert year to integer to match the dictionary keys
        master_table[key][year] = master_table[key][year] / year_to_exchange_rate_dict[year_int] #divide each column's values by that year's exchange rate

    except Exception as e: #if errored out
      print(f"Could not fetch rate for {key} ({currency}): {e}")
      error_countries.append(key) #add country to error list
      pass
      
  for country in error_countries:
    del master_table[country] #delete countries where currency conversion failed
  
  for key in master_table:
    print(key)
    print(master_table[key])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# keep
# Senegal
# Côte d'Ivoire
# Burkina Faso
# Central African Republic
# Tanzania
# Democratic Republic of the Congo
# Rwanda
# Republic of Congo
# Sudan
# Togo
# Mali
# Malawi
# Sao Tomee and Principe
# Mozambique
# Sierra Leone
# Burundi
# Cameroon
# Madagascar
# {2010: 487.61083221435547, 2011: 460.5933329264323, 2012: 501.0466715494792, 2013: 492.91916910807294, 2014: 497.47583770751953, 2015: 594.4266713460287, 2016: 594.0358378092448, 2017: 577.82666015625, 2018: 557.75, 2019: 583.7949981689453}
# {2010: 487.61083221435547, 2011: 460.5933329264323, 2012: 501.0466715494792, 2013: 492.91916910807294, 2014: 497.47583770751953, 2015: 594.4266713460287, 2016: 594.0358378092448, 2017: 577.82666015625, 2018: 557.75, 2019: 583.7949981689453}
# {2010: 487.61083221435547, 2011: 460.5933329264323, 2012: 501.0466715494792, 2013: 492.91916910807294, 2014: 497.47583770751953, 2015: 594.4266713460287, 2016: 594.0358378092448, 2017: 577.82666015625, 2018: 557.75, 2019: 583.7949981689453}
# {2010: 487.5991668701172, 2011: 460.59083048502606, 2012: 501.04666900634766, 2013: 492.91916910807294, 2014: 497.4808349609375, 2015: 594.4341735839844, 2016: 594.0333353678385, 2017: 578.2424977620443, 2018: 556.1933390299479, 2019: 586.7139180501302}
# {2010: 1422.5833231608074, 2011: 1568.4333394368489, 2012: 1563.4083455403645, 2013: 1581.8916727701824, 2014: 1632.8416646321614, 2015: 1989.9833170572917, 2016: 2136.6749674479165, 2017: 2193.6416625976562, 2018: 2273.074991861979, 2019: 2301.0916748046875}
# {2010: 886.25, 2011: 910.0, 2012: 904.5833333333334, 2013: 906.6291656494141, 2014: 907.25, 2015: 910.0, 2016: 978.4496866861979, 2017: 1457.9642842610676, 2018: 1580.0, 2019: 1630.0}
# {2010: 575.0333302815756, 2011: 590.4300028483073, 2012: 599.2916666666666, 2013: 640.4175059000651, 2014: 674.0025024414062, 2015: 696.072499593099, 2016: 768.2083384195963, 2017: 827.0033365885416, 2018: 847.0541687011719, 2019: 901.6158345540365}
# {2010: 487.5991668701172, 2011: 460.59083048502606, 2012: 501.04666900634766, 2013: 492.91916910807294, 2014: 497.4808349609375, 2015: 594.4341735839844, 2016: 594.0333353678385, 2017: 578.2424977620443, 2018: 556.1933390299479, 2019: 586.7139180501302}
# {2010: 2.318599979082743, 2011: 2.648924986521403, 2012: 3.52014168103536, 2013: 4.590566674868266, 2014: 5.666366696357727, 2015: 5.987816691398621, 2016: 6.130283355712891, 2017: 6.609750032424927, 2018: 25.39816665649414, 2019: 45.693160692850746}
# {2010: 487.61083221435547, 2011: 460.5933329264323, 2012: 501.0466715494792, 2013: 492.91916910807294, 2014: 497.47583770751953, 2015: 594.4266713460287, 2016: 594.0358378092448, 2017: 577.82666015625, 2018: 557.75, 2019: 583.7949981689453}
# [*********************100%%**********************]  1 of 1 completed
# {2010: 487.61083221435547, 2011: 460.5933329264323, 2012: 501.0466715494792, 2013: 492.91916910807294, 2014: 497.47583770751953, 2015: 594.4266713460287, 2016: 594.0358378092448, 2017: 577.82666015625, 2018: 557.75, 2019: 583.7949981689453}
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['STN=X']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# {2010: 148.9291674296061, 2011: 155.58916854858398, 2012: 247.6258316040039, 2013: 362.4624989827474, 2014: 410.5541687011719, 2015: 495.21583557128906, 2016: 700.3816680908203, 2017: 720.1374969482422, 2018: 704.3308308919271, 2019: 718.8183339436849}
# Could not fetch rate for Sao Tomee and Principe (STN): Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
# {2010: 34.550000508626304, 2011: 28.579166730244953, 2012: 28.048333326975506, 2013: 29.664999802907307, 2014: 31.18499978383382, 2015: 39.24833265940348, 2016: 62.973334312438965, 2017: 62.673333168029785, 2018: 59.819166819254555, 2019: 61.90666675567627}
# {2010: 3920.0, 2011: 4280.166666666667, 2012: 4277.166666666667, 2013: 4268.166666666667, 2014: 4302.333333333333, 2015: 4348.583333333333, 2016: 5087.916666666667, 2017: 7505.0, 2018: 7962.916666666667, 2019: 9048.333333333334}
# {2010: 1206.0750122070312, 2011: 1216.6916605631511, 2012: 1396.4749857584636, 2013: 1531.5916748046875, 2014: 1530.9249877929688, 2015: 1536.9166666666667, 2016: 1605.7583312988281, 2017: 1700.5, 2018: 1756.2916666666667, 2019: 1822.7166646321614}
# {2010: 487.5991668701172, 2011: 460.59083048502606, 2012: 501.04666900634766, 2013: 492.91916910807294, 2014: 497.4808349609375, 2015: 594.4341735839844, 2016: 594.0333353678385, 2017: 578.2424977620443, 2018: 556.1933390299479, 2019: 586.7139180501302}
# {2010: 2070.574991861979, 2011: 1995.8000183105469, 2012: 2154.4749755859375, 2013: 2174.9000040690103, 2014: 2460.4250284830728, 2015: 3095.6833699544272, 2016: 3135.3916625976562, 2017: 3076.9583333333335, 2018: 3307.1916707356772, 2019: 3290.9500080744424}
# Senegal
#                                                                  2010  \
# nan
# Revenue                                              2867744175.10332
# Taxes                                               2450158089.947426
# Taxes on income, profits, & capital gains             669103855.56934
# Taxes on income, profits, & capital gains: indi...   391695469.581032
# Taxes on income, profits, & capital gains: corp...   217586076.587321
# Taxes on income, profits, & capital gains: other      59822309.400987
# Taxes on payroll & workforce                          22047852.485512
# Taxes on property                                      3984036.441885
# Taxes on goods & services                           1277154486.224036
# General taxes on goods & services                   1052166272.974556
# Excise taxes                                         214787589.531971
# Taxes on int trade & transactions                    372476317.677778
# Other taxes n.e.c.                                   105391541.548873
# Social contributions                                              0.0
# Social security contributions                                     0.0
# Other social contributions                                        0.0
# Grants                                               331967604.708258
# Grants from foreign govts                            331967604.708258
# Grants from int orgs                                              0.0
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                         85618480.447635
# Property income                                       64867559.115453
# Sales of goods & services                                         0.0
# Fines, penalties & forfeits                                       0.0
# Other transfers                                       20750921.332182
# NI & SGS: premiums, fees & claims                                 0.0
#
#                                                             2011  \
# nan
# Revenue                                             3.312249e+09
# Taxes                                               2.794005e+09
# Taxes on income, profits, & capital gains           7.184212e+08
# Taxes on income, profits, & capital gains: indi...  4.589732e+08
# Taxes on income, profits, & capital gains: corp...  2.127690e+08
# Taxes on income, profits, & capital gains: other    4.667892e+07
# Taxes on payroll & workforce                        2.692180e+07
# Taxes on property                                   4.993559e+06
# Taxes on goods & services                           1.490035e+09
# General taxes on goods & services                   1.211915e+09
# Excise taxes                                        2.650929e+08
# Taxes on int trade & transactions                   4.424728e+08
# Other taxes n.e.c.                                  1.111610e+08
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              3.256669e+08
# Grants from foreign govts                           3.256669e+08
# Grants from int orgs                                0.000000e+00
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       1.925777e+08
# Property income                                     7.403494e+07
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     1.185427e+08
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2012  \
# nan
# Revenue                                             3.298894e+09
# Taxes                                               2.745253e+09
# Taxes on income, profits, & capital gains           7.614061e+08
# Taxes on income, profits, & capital gains: indi...  4.752052e+08
# Taxes on income, profits, & capital gains: corp...  2.273241e+08
# Taxes on income, profits, & capital gains: other    5.887675e+07
# Taxes on payroll & workforce                        3.013691e+07
# Taxes on property                                   4.989555e+06
# Taxes on goods & services                           1.378115e+09
# General taxes on goods & services                   1.133427e+09
# Excise taxes                                        2.327129e+08
# Taxes on int trade & transactions                   3.895845e+08
# Other taxes n.e.c.                                  1.810211e+08
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.109398e+08
# Grants from foreign govts                           4.109398e+08
# Grants from int orgs                                0.000000e+00
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       1.427013e+08
# Property income                                     7.803664e+07
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     6.466463e+07
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2013  \
# nan
# Revenue                                             3.365623e+09
# Taxes                                                        NaN
# Taxes on income, profits, & capital gains                    NaN
# Taxes on income, profits, & capital gains: indi...           NaN
# Taxes on income, profits, & capital gains: corp...           NaN
# Taxes on income, profits, & capital gains: other             NaN
# Taxes on payroll & workforce                                 NaN
# Taxes on property                                            NaN
# Taxes on goods & services                                    NaN
# General taxes on goods & services                            NaN
# Excise taxes                                                 NaN
# Taxes on int trade & transactions                            NaN
# Other taxes n.e.c.                                           NaN
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              3.804681e+08
# Grants from foreign govts                                    NaN
# Grants from int orgs                                         NaN
# Grants from other gen govt                                   NaN
# Grants from other gen govt: current                          NaN
# Grants from other gen govt: capital                          NaN
# Other revenue                                                NaN
# Property income                                              NaN
# Sales of goods & services                                    NaN
# Fines, penalties & forfeits                                  NaN
# Other transfers                                              NaN
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2014  \
# nan
# Revenue                                             3.890565e+09
# Taxes                                               2.980095e+09
# Taxes on income, profits, & capital gains           8.076076e+08
# Taxes on income, profits, & capital gains: indi...  3.784331e+08
# Taxes on income, profits, & capital gains: corp...  2.791450e+08
# Taxes on income, profits, & capital gains: other    1.500296e+08
# Taxes on payroll & workforce                        4.238914e+07
# Taxes on property                                   5.263455e+07
# Taxes on goods & services                           1.582723e+09
# General taxes on goods & services                   6.357363e+08
# Excise taxes                                        7.990478e+08
# Taxes on int trade & transactions                   4.393617e+08
# Other taxes n.e.c.                                  5.537885e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              6.267377e+08
# Grants from foreign govts                           4.698131e+08
# Grants from int orgs                                1.329245e+08
# Grants from other gen govt                          2.400004e+07
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 2.400004e+07
# Other revenue                                       2.837325e+08
# Property income                                     1.070937e+08
# Sales of goods & services                           4.331781e+07
# Fines, penalties & forfeits                         1.043354e+06
# Other transfers                                     1.322776e+08
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2015  \
# nan
# Revenue                                             3.521774e+09
# Taxes                                               2.799493e+09
# Taxes on income, profits, & capital gains           7.325009e+08
# Taxes on income, profits, & capital gains: indi...  3.663576e+08
# Taxes on income, profits, & capital gains: corp...  2.538972e+08
# Taxes on income, profits, & capital gains: other    1.122461e+08
# Taxes on payroll & workforce                        3.655750e+07
# Taxes on property                                   5.288060e+07
# Taxes on goods & services                           1.538321e+09
# General taxes on goods & services                   1.144341e+09
# Excise taxes                                        2.652507e+08
# Taxes on int trade & transactions                   3.935890e+08
# Other taxes n.e.c.                                  4.564464e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              3.903205e+08
# Grants from foreign govts                           3.748714e+08
# Grants from int orgs                                1.544911e+07
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       3.319600e+08
# Property income                                     9.288352e+07
# Sales of goods & services                           3.720792e+07
# Fines, penalties & forfeits                         4.276440e+04
# Other transfers                                     2.018686e+08
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2016  \
# nan
# Revenue                                             3.784574e+09
# Taxes                                               3.122412e+09
# Taxes on income, profits, & capital gains           8.634455e+08
# Taxes on income, profits, & capital gains: indi...  4.956054e+08
# Taxes on income, profits, & capital gains: corp...  2.917385e+08
# Taxes on income, profits, & capital gains: other    7.610156e+07
# Taxes on payroll & workforce                        3.864472e+07
# Taxes on property                                   4.987365e+07
# Taxes on goods & services                           1.703620e+09
# General taxes on goods & services                   1.140722e+09
# Excise taxes                                        4.468540e+08
# Taxes on int trade & transactions                   4.072871e+08
# Other taxes n.e.c.                                  5.954137e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              1.889583e+08
# Grants from foreign govts                           1.576942e+08
# Grants from int orgs                                3.126411e+07
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       4.732032e+08
# Property income                                     2.993995e+08
# Sales of goods & services                           3.591378e+07
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     1.018457e+08
# NI & SGS: premiums, fees & claims                   3.604420e+07
#
#                                                             2017  \
# nan
# Revenue                                             4.276963e+09
# Taxes                                               3.356166e+09
# Taxes on income, profits, & capital gains           9.407164e+08
# Taxes on income, profits, & capital gains: indi...  4.508813e+08
# Taxes on income, profits, & capital gains: corp...  4.767868e+08
# Taxes on income, profits, & capital gains: other    1.304826e+07
# Taxes on payroll & workforce                        3.471650e+07
# Taxes on property                                   5.914133e+07
# Taxes on goods & services                           1.783313e+09
# General taxes on goods & services                   1.374525e+09
# Excise taxes                                        2.700253e+08
# Taxes on int trade & transactions                   4.803966e+08
# Other taxes n.e.c.                                  5.788257e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.583200e+08
# Grants from foreign govts                           3.899385e+08
# Grants from int orgs                                1.179017e+07
# Grants from other gen govt                          5.659137e+07
# Grants from other gen govt: current                 5.659137e+07
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       4.624773e+08
# Property income                                     1.190512e+08
# Sales of goods & services                           1.578896e+07
# Fines, penalties & forfeits                         1.367192e+04
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   3.276235e+08
#
#                                                             2018          2019
# nan
# Revenue                                             4.550510e+09  4.975361e+09
# Taxes                                               3.770475e+09  4.326473e+09
# Taxes on income, profits, & capital gains           1.079016e+09  1.231655e+09
# Taxes on income, profits, & capital gains: indi...  5.623056e+08  6.177306e+08
# Taxes on income, profits, & capital gains: corp...  5.031700e+08  5.994599e+08
# Taxes on income, profits, & capital gains: other    1.354055e+07  1.446431e+07
# Taxes on payroll & workforce                        1.348608e+07  7.250747e+07
# Taxes on property                                   7.714137e+07  6.728339e+06
# Taxes on goods & services                           1.937565e+09  2.324858e+09
# General taxes on goods & services                   1.378135e+09  1.637323e+09
# Excise taxes                                        3.637096e+08  3.185887e+08
# Taxes on int trade & transactions                   5.851449e+08  6.261410e+08
# Other taxes n.e.c.                                  7.812148e+07  6.458381e+07
# Social contributions                                0.000000e+00  0.000000e+00
# Social security contributions                       0.000000e+00  0.000000e+00
# Other social contributions                          0.000000e+00  0.000000e+00
# Grants                                              4.597838e+08  3.842548e+08
# Grants from foreign govts                           0.000000e+00  3.666874e+08
# Grants from int orgs                                4.597838e+08  1.756739e+07
# Grants from other gen govt                          0.000000e+00  0.000000e+00
# Grants from other gen govt: current                 0.000000e+00  0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00  0.000000e+00
# Other revenue                                       3.202579e+08  2.646328e+08
# Property income                                     1.377524e+08  1.726599e+08
# Sales of goods & services                           1.856519e+07  1.883648e+07
# Fines, penalties & forfeits                         0.000000e+00  0.000000e+00
# Other transfers                                     0.000000e+00  7.313644e+07
# NI & SGS: premiums, fees & claims                   1.639403e+08  0.000000e+00
# Côte d'Ivoire
#                                                                  2010  \
# nan
# Revenue                                             4305400662.381335
# Taxes                                               3620879363.942934
# Taxes on income, profits, & capital gains            868520492.206432
# Taxes on income, profits, & capital gains: indi...   390680410.307734
# Taxes on income, profits, & capital gains: corp...   384322881.321099
# Taxes on income, profits, & capital gains: other      93517200.577599
# Taxes on payroll & workforce                                      0.0
# Taxes on property                                     15791281.676481
# Taxes on goods & services                            912165954.107583
# General taxes on goods & services                    339988345.310429
# Excise taxes                                         212464517.101739
# Taxes on int trade & transactions                   1824405737.584043
# Other taxes n.e.c.                                                0.0
# Social contributions                                              0.0
# Social security contributions                                     0.0
# Other social contributions                                        0.0
# Grants                                               313387213.540867
# Grants from foreign govts                                         NaN
# Grants from int orgs                                              NaN
# Grants from other gen govt                                        NaN
# Grants from other gen govt: current                               NaN
# Grants from other gen govt: capital                               NaN
# Other revenue                                        371127932.450128
# Property income                                      371127932.450128
# Sales of goods & services                                         0.0
# Fines, penalties & forfeits                                       0.0
# Other transfers                                                   0.0
# NI & SGS: premiums, fees & claims                                 0.0
#
#                                                             2011  \
# nan
# Revenue                                             3.322714e+09
# Taxes                                               2.842529e+09
# Taxes on income, profits, & capital gains           7.533761e+08
# Taxes on income, profits, & capital gains: indi...  2.941858e+08
# Taxes on income, profits, & capital gains: corp...  3.777736e+08
# Taxes on income, profits, & capital gains: other    8.141672e+07
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   1.280956e+07
# Taxes on goods & services                           7.154793e+08
# General taxes on goods & services                   2.239394e+08
# Excise taxes                                        1.697810e+08
# Taxes on int trade & transactions                   1.360853e+09
# Other taxes n.e.c.                                  0.000000e+00
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              7.134493e+07
# Grants from foreign govts                                    NaN
# Grants from int orgs                                         NaN
# Grants from other gen govt                                   NaN
# Grants from other gen govt: current                          NaN
# Grants from other gen govt: capital                          NaN
# Other revenue                                       4.088531e+08
# Property income                                     4.088531e+08
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2012  \
# nan
# Revenue                                             4.642102e+09
# Taxes                                               3.928237e+09
# Taxes on income, profits, & capital gains           9.929873e+08
# Taxes on income, profits, & capital gains: indi...  4.265730e+08
# Taxes on income, profits, & capital gains: corp...  4.554466e+08
# Taxes on income, profits, & capital gains: other    1.109677e+08
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   1.876073e+07
# Taxes on goods & services                           1.097501e+09
# General taxes on goods & services                   4.072555e+08
# Excise taxes                                        1.480900e+08
# Taxes on int trade & transactions                   1.818992e+09
# Other taxes n.e.c.                                  0.000000e+00
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              1.620767e+08
# Grants from foreign govts                                    NaN
# Grants from int orgs                                         NaN
# Grants from other gen govt                                   NaN
# Grants from other gen govt: current                          NaN
# Grants from other gen govt: capital                          NaN
# Other revenue                                       5.517849e+08
# Property income                                     5.517849e+08
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2013  \
# nan
# Revenue                                             5.427178e+09
# Taxes                                               4.556995e+09
# Taxes on income, profits, & capital gains           1.240510e+09
# Taxes on income, profits, & capital gains: indi...  5.231121e+08
# Taxes on income, profits, & capital gains: corp...  5.767497e+08
# Taxes on income, profits, & capital gains: other    1.406469e+08
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   2.487993e+07
# Taxes on goods & services                           1.129715e+09
# General taxes on goods & services                   5.026544e+08
# Excise taxes                                        5.556579e+07
# Taxes on int trade & transactions                   2.161896e+09
# Other taxes n.e.c.                                  0.000000e+00
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.087080e+08
# Grants from foreign govts                                    NaN
# Grants from int orgs                                         NaN
# Grants from other gen govt                                   NaN
# Grants from other gen govt: current                          NaN
# Grants from other gen govt: capital                          NaN
# Other revenue                                       4.614692e+08
# Property income                                     4.614692e+08
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2014  \
# nan
# Revenue                                             5.792121e+09
# Taxes                                               4.904636e+09
# Taxes on income, profits, & capital gains           1.277504e+09
# Taxes on income, profits, & capital gains: indi...  6.843054e+08
# Taxes on income, profits, & capital gains: corp...  4.554754e+08
# Taxes on income, profits, & capital gains: other    1.377233e+08
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   2.593091e+07
# Taxes on goods & services                           1.217133e+09
# General taxes on goods & services                   5.176131e+08
# Excise taxes                                        7.638562e+07
# Taxes on int trade & transactions                   2.384068e+09
# Other taxes n.e.c.                                  0.000000e+00
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              6.319674e+08
# Grants from foreign govts                                    NaN
# Grants from int orgs                                         NaN
# Grants from other gen govt                                   NaN
# Grants from other gen govt: current                          NaN
# Grants from other gen govt: capital                          NaN
# Other revenue                                       2.555179e+08
# Property income                                     2.555179e+08
# Sales of goods & services                           0.000000e+00
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2015  \
# nan
# Revenue                                             6.017592e+09
# Taxes                                               5.092470e+09
# Taxes on income, profits, & capital gains           1.263915e+09
# Taxes on income, profits, & capital gains: indi...  6.160140e+08
# Taxes on income, profits, & capital gains: corp...  6.479005e+08
# Taxes on income, profits, & capital gains: other    0.000000e+00
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   2.193883e+08
# Taxes on goods & services                           2.029428e+09
# General taxes on goods & services                   1.379163e+09
# Excise taxes                                        4.302459e+08
# Taxes on int trade & transactions                   1.555721e+09
# Other taxes n.e.c.                                  2.401873e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.747430e+08
# Grants from foreign govts                           2.584002e+08
# Grants from int orgs                                2.163428e+08
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       4.503789e+08
# Property income                                     3.991913e+08
# Sales of goods & services                           4.950226e+07
# Fines, penalties & forfeits                         1.685396e+06
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2016  \
# nan
# Revenue                                             6.157411e+09
# Taxes                                               5.534352e+09
# Taxes on income, profits, & capital gains           1.365900e+09
# Taxes on income, profits, & capital gains: indi...  7.020509e+08
# Taxes on income, profits, & capital gains: corp...  6.638488e+08
# Taxes on income, profits, & capital gains: other    0.000000e+00
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   2.438141e+08
# Taxes on goods & services                           2.245478e+09
# General taxes on goods & services                   1.469941e+09
# Excise taxes                                        5.531047e+08
# Taxes on int trade & transactions                   1.654006e+09
# Other taxes n.e.c.                                  2.515448e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.922565e+08
# Grants from foreign govts                           2.484530e+08
# Grants from int orgs                                1.783192e+08
# Grants from other gen govt                          6.548426e+07
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 6.548426e+07
# Other revenue                                       1.308024e+08
# Property income                                     6.842750e+07
# Sales of goods & services                           2.896661e+07
# Fines, penalties & forfeits                         1.425391e+06
# Other transfers                                     3.198292e+07
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2017  \
# nan
# Revenue                                             6.768858e+09
# Taxes                                               6.203783e+09
# Taxes on income, profits, & capital gains           1.567136e+09
# Taxes on income, profits, & capital gains: indi...  7.770886e+08
# Taxes on income, profits, & capital gains: corp...  7.900471e+08
# Taxes on income, profits, & capital gains: other    0.000000e+00
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   2.616493e+08
# Taxes on goods & services                           2.468261e+09
# General taxes on goods & services                   1.648381e+09
# Excise taxes                                        5.655162e+08
# Taxes on int trade & transactions                   1.881931e+09
# Other taxes n.e.c.                                  2.480548e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              4.605187e+08
# Grants from foreign govts                           2.611510e+08
# Grants from int orgs                                1.993677e+08
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       1.045566e+08
# Property income                                     7.075405e+07
# Sales of goods & services                           2.484270e+07
# Fines, penalties & forfeits                         1.641082e+06
# Other transfers                                     7.318804e+06
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2018          2019
# nan
# Revenue                                             7.415644e+09  7.720610e+09
# Taxes                                               6.799031e+09  7.069495e+09
# Taxes on income, profits, & capital gains           1.877618e+09  1.834848e+09
# Taxes on income, profits, & capital gains: indi...  8.938627e+08  8.800815e+08
# Taxes on income, profits, & capital gains: corp...  9.837549e+08  9.090263e+08
# Taxes on income, profits, & capital gains: other    0.000000e+00  4.574021e+07
# Taxes on payroll & workforce                        0.000000e+00  4.105179e+07
# Taxes on property                                   3.118274e+08  3.328286e+08
# Taxes on goods & services                           2.757505e+09  2.880214e+09
# General taxes on goods & services                   1.866915e+09  1.874443e+09
# Excise taxes                                        5.834426e+08  6.931640e+08
# Taxes on int trade & transactions                   1.824364e+09  1.940419e+09
# Other taxes n.e.c.                                  2.771786e+07  4.013337e+07
# Social contributions                                0.000000e+00  0.000000e+00
# Social security contributions                       0.000000e+00  0.000000e+00
# Other social contributions                          0.000000e+00  0.000000e+00
# Grants                                              4.413805e+08  4.709053e+08
# Grants from foreign govts                           2.846078e+08  4.558770e+08
# Grants from int orgs                                1.567727e+08  1.502826e+07
# Grants from other gen govt                          0.000000e+00  0.000000e+00
# Grants from other gen govt: current                 0.000000e+00  0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00  0.000000e+00
# Other revenue                                       1.752321e+08  1.802096e+08
# Property income                                     1.070807e+08  9.785185e+07
# Sales of goods & services                           2.567087e+07  3.003497e+07
# Fines, penalties & forfeits                         1.659391e+06  3.511140e+06
# Other transfers                                     4.082116e+07  4.881165e+07
# NI & SGS: premiums, fees & claims                   0.000000e+00  0.000000e+00
# Burkina Faso
#                                                                  2010  \
# nan
# Revenue                                             1805167034.544164
# Taxes                                               1160249040.060895
# Taxes on income, profits, & capital gains            273950025.665708
# Taxes on income, profits, & capital gains: indi...                NaN
# Taxes on income, profits, & capital gains: corp...                NaN
# Taxes on income, profits, & capital gains: other                  NaN
# Taxes on payroll & workforce                          11237418.461596
# Taxes on property                                      8531351.937176
# Taxes on goods & services                             653053580.77036
# General taxes on goods & services                     484414997.36036
# Excise taxes                                         168639929.899775
# Taxes on int trade & transactions                    198436375.630934
# Other taxes n.e.c.                                    15038613.934599
# Social contributions                                              0.0
# Social security contributions                                     0.0
# Other social contributions                                        0.0
# Grants                                               407989295.677798
# Grants from foreign govts                            303135185.345967
# Grants from int orgs                                 104852615.381449
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                        236928698.805471
# Property income                                        6137191.568141
# Sales of goods & services                            176885453.381568
# Fines, penalties & forfeits                            6591024.308064
# Other transfers                                       47315724.764001
# NI & SGS: premiums, fees & claims                                 0.0
#
#                                                             2011  \
# nan
# Revenue                                             2.273785e+09
# Taxes                                               1.510300e+09
# Taxes on income, profits, & capital gains           4.364457e+08
# Taxes on income, profits, & capital gains: indi...           NaN
# Taxes on income, profits, & capital gains: corp...           NaN
# Taxes on income, profits, & capital gains: other             NaN
# Taxes on payroll & workforce                        1.083145e+07
# Taxes on property                                   1.063428e+07
# Taxes on goods & services                           7.962838e+08
# General taxes on goods & services                   6.133437e+08
# Excise taxes                                        1.829387e+08
# Taxes on int trade & transactions                   2.431147e+08
# Other taxes n.e.c.                                  1.298995e+07
# Social contributions                                0.000000e+00
# Social security contributions                       0.000000e+00
# Other social contributions                          0.000000e+00
# Grants                                              5.507461e+08
# Grants from foreign govts                           3.920378e+08
# Grants from int orgs                                1.587083e+08
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       2.127299e+08
# Property income                                     3.090844e+07
# Sales of goods & services                           7.362842e+07
# Fines, penalties & forfeits                         5.902871e+06
# Other transfers                                     1.022902e+08
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
# ...
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   0.000000e+00
# Taxes on goods & services                           1.927165e+09
# General taxes on goods & services                   1.571966e+09
# Excise taxes                                        3.551989e+08
# Taxes on int trade & transactions                   5.864991e+08
# Other taxes n.e.c.                                  2.176646e+08
# Social contributions                                7.524830e+07
# Social security contributions                       0.000000e+00
# Other social contributions                          7.524830e+07
# Grants                                              9.107233e+07
# Grants from foreign govts                           0.000000e+00
# Grants from int orgs                                9.107233e+07
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       8.915325e+08
# Property income                                     7.817743e+08
# Sales of goods & services                           1.097582e+08
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2017  \
# nan
# Revenue                                             5.437684e+09
# Taxes                                               4.304941e+09
# Taxes on income, profits, & capital gains           1.108704e+09
# Taxes on income, profits, & capital gains: indi...  3.681846e+08
# Taxes on income, profits, & capital gains: corp...  6.675400e+08
# Taxes on income, profits, & capital gains: other    7.297976e+07
# Taxes on payroll & workforce                        0.000000e+00
# Taxes on property                                   0.000000e+00
# Taxes on goods & services                           2.234357e+09
# General taxes on goods & services                   1.880872e+09
# Excise taxes                                        3.534849e+08
# Taxes on int trade & transactions                   6.898490e+08
# Other taxes n.e.c.                                  2.720312e+08
# Social contributions                                7.920552e+07
# Social security contributions                       0.000000e+00
# Other social contributions                          7.920552e+07
# Grants                                              1.120637e+08
# Grants from foreign govts                           0.000000e+00
# Grants from int orgs                                1.120637e+08
# Grants from other gen govt                          0.000000e+00
# Grants from other gen govt: current                 0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00
# Other revenue                                       9.414735e+08
# Property income                                     8.190335e+08
# Sales of goods & services                           1.226129e+08
# Fines, penalties & forfeits                         0.000000e+00
# Other transfers                                     0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00
#
#                                                             2018          2019
# nan
# Revenue                                             6.203920e+09  6.109423e+09
# Taxes                                               4.928921e+09  4.765203e+09
# Taxes on income, profits, & capital gains           1.312358e+09  1.299462e+09
# Taxes on income, profits, & capital gains: indi...  4.410713e+08  4.368288e+08
# Taxes on income, profits, & capital gains: corp...  7.944815e+08  7.814853e+08
# Taxes on income, profits, & capital gains: other    7.680487e+07  8.114819e+07
# Taxes on payroll & workforce                        0.000000e+00  0.000000e+00
# Taxes on property                                   0.000000e+00  0.000000e+00
# Taxes on goods & services                           2.647355e+09  2.554757e+09
# General taxes on goods & services                   2.054566e+09  1.924376e+09
# Excise taxes                                        5.927890e+08  6.303809e+08
# Taxes on int trade & transactions                   7.298666e+08  6.702155e+08
# Other taxes n.e.c.                                  2.393414e+08  2.407683e+08
# Social contributions                                8.653762e+07  8.270039e+07
# Social security contributions                       0.000000e+00  0.000000e+00
# Other social contributions                          8.653762e+07  8.270039e+07
# Grants                                              1.558080e+08  2.271679e+08
# Grants from foreign govts                           0.000000e+00  0.000000e+00
# Grants from int orgs                                1.558080e+08  2.271679e+08
# Grants from other gen govt                          0.000000e+00  0.000000e+00
# Grants from other gen govt: current                 0.000000e+00  0.000000e+00
# Grants from other gen govt: capital                 0.000000e+00  0.000000e+00
# Other revenue                                       1.032654e+09  1.034351e+09
# Property income                                     8.388234e+08  9.035551e+08
# Sales of goods & services                           1.938304e+08  1.307964e+08
# Fines, penalties & forfeits                         0.000000e+00  0.000000e+00
# Other transfers                                     0.000000e+00  0.000000e+00
# NI & SGS: premiums, fees & claims                   0.000000e+00  0.000000e+00
# Madagascar
#                                                         2010          2011  \
# nan
# Revenue                                    1244478270.590338  1.331916e+09
# Taxes                                       860029222.316958  1.020982e+09
# Taxes on income, profits, & capital gains   236791230.420058  2.674015e+08
# Taxes on payroll & workforce                             0.0  0.000000e+00
# Taxes on property                                        0.0  0.000000e+00
# Taxes on goods & services                   494472310.360178  6.030294e+08
# General taxes on goods & services           388267994.716315  4.814951e+08
# Excise taxes                                 97093319.870156  1.081952e+08
# Taxes on int trade & transactions           127046352.358116  1.487143e+08
# Other taxes n.e.c.                            1719329.178606  1.836356e+06
# Social contributions                         82344276.671997  9.409760e+07
# Social security contributions                            0.0  0.000000e+00
# Other social contributions                   82344276.671997  9.409760e+07
# Grants                                      171421948.683354  1.955622e+08
# Grants from foreign govts                     7405672.366501  7.484718e+06
# Grants from int orgs                        164016276.316853  1.880775e+08
# Grants from other gen govt                               0.0  0.000000e+00
# Grants from other gen govt: current                      0.0  0.000000e+00
# Grants from other gen govt: capital                      0.0  0.000000e+00
# Other revenue                                130682822.91803  2.127488e+07
# Property income                             123997923.769532  1.389418e+07
# Sales of goods & services                     6650464.269163  7.352089e+06
# Fines, penalties & forfeits                     34434.879336  2.861008e+04
# Other transfers                                          0.0  0.000000e+00
# NI & SGS: premiums, fees & claims                        0.0  0.000000e+00
#
#                                                    2012          2013  \
# nan
# Revenue                                    1.203343e+09  1.338208e+09
# Taxes                                      9.871690e+08  1.107549e+09
# Taxes on income, profits, & capital gains  2.379109e+08  2.612916e+08
# Taxes on payroll & workforce               0.000000e+00  0.000000e+00
# Taxes on property                          0.000000e+00  0.000000e+00
# Taxes on goods & services                  6.068239e+08  7.058646e+08
# General taxes on goods & services          4.885125e+08  5.816672e+08
# Excise taxes                               1.087165e+08  1.140774e+08
# Taxes on int trade & transactions          1.409912e+08  1.377392e+08
# Other taxes n.e.c.                         1.443043e+06  2.653915e+06
# Social contributions                       3.694636e+07  5.811761e+07
# Social security contributions              0.000000e+00  0.000000e+00
# Other social contributions                 3.694636e+07  5.811761e+07
# Grants                                     1.220209e+08  1.361635e+08
# Grants from foreign govts                  5.939266e+06  1.855947e+07
# Grants from int orgs                       1.160816e+08  1.176040e+08
# Grants from other gen govt                 0.000000e+00  0.000000e+00
# Grants from other gen govt: current        0.000000e+00  0.000000e+00
# Grants from other gen govt: capital        0.000000e+00  0.000000e+00
# Other revenue                              5.720670e+07  3.637712e+07
# Property income                            1.853027e+07  2.241252e+07
# Sales of goods & services                  3.865680e+07  1.394179e+07
# Fines, penalties & forfeits                1.963355e+04  2.280565e+04
# Other transfers                            0.000000e+00  0.000000e+00
# NI & SGS: premiums, fees & claims          0.000000e+00  0.000000e+00
#
#                                                    2014          2015  \
# nan
# Revenue                                    1.382985e+09  1.187461e+09
# Taxes                                      1.037483e+09  9.598172e+08
# Taxes on income, profits, & capital gains  2.484815e+08  2.282918e+08
# Taxes on payroll & workforce               0.000000e+00  0.000000e+00
# Taxes on property                          0.000000e+00  0.000000e+00
# Taxes on goods & services                  6.449142e+08  5.836547e+08
# General taxes on goods & services          5.382383e+08  4.866166e+08
# Excise taxes                               9.627646e+07  8.673109e+07
# Taxes on int trade & transactions          1.430204e+08  1.470635e+08
# Other taxes n.e.c.                         1.066482e+06  8.072531e+05
# Social contributions                       5.373055e+07  4.551499e+07
# Social security contributions              0.000000e+00  0.000000e+00
# Other social contributions                 5.373055e+07  4.551499e+07
# Grants                                     2.409608e+08  1.370363e+08
# Grants from foreign govts                  9.188250e+06  2.084192e+06
# Grants from int orgs                       2.317726e+08  1.349521e+08
# Grants from other gen govt                 0.000000e+00  0.000000e+00
# Grants from other gen govt: current        0.000000e+00  0.000000e+00
# Grants from other gen govt: capital        0.000000e+00  0.000000e+00
# Other revenue                              5.081077e+07  4.509287e+07
# Property income                            1.795828e+07  1.862445e+07
# Sales of goods & services                  3.280661e+07  2.639849e+07
# Fines, penalties & forfeits                4.588638e+04  6.992849e+04
# Other transfers                            0.000000e+00  0.000000e+00
# NI & SGS: premiums, fees & claims          0.000000e+00  0.000000e+00
#
#                                                    2016          2017  \
# nan
# Revenue                                    1.565079e+09  1.788157e+09
# Taxes                                      1.109762e+09  1.338073e+09
# Taxes on income, profits, & capital gains  2.814953e+08  3.259041e+08
# Taxes on payroll & workforce               0.000000e+00  0.000000e+00
# Taxes on property                          0.000000e+00  0.000000e+00
# Taxes on goods & services                  6.521447e+08  8.031092e+08
# General taxes on goods & services          5.319827e+08  6.751102e+08
# Excise taxes                               1.093787e+08  1.251810e+08
# Taxes on int trade & transactions          1.717572e+08  2.044154e+08
# Other taxes n.e.c.                         4.365005e+06  4.644015e+06
# Social contributions                       4.411356e+07  5.388438e+07
# Social security contributions              0.000000e+00  0.000000e+00
# Other social contributions                 4.411356e+07  5.388438e+07
# Grants                                     3.586446e+08  3.369789e+08
# Grants from foreign govts                  3.380704e+07  5.162339e+07
# Grants from int orgs                       3.248376e+08  2.853555e+08
# Grants from other gen govt                 0.000000e+00  0.000000e+00
# Grants from other gen govt: current        0.000000e+00  0.000000e+00
# Grants from other gen govt: capital        0.000000e+00  0.000000e+00
# Other revenue                              5.255869e+07  5.922059e+07
# Property income                            2.995453e+07  3.456946e+07
# Sales of goods & services                  2.257542e+07  2.464578e+07
# Fines, penalties & forfeits                2.873453e+04  5.349801e+03
# Other transfers                            0.000000e+00  0.000000e+00
# NI & SGS: premiums, fees & claims          0.000000e+00  0.000000e+00
#
#                                                    2018          2019
# nan
# Revenue                                    1.959705e+09  2.276131e+09
# Taxes                                      1.426754e+09  1.633255e+09
# Taxes on income, profits, & capital gains  3.552139e+08  4.341451e+08
# Taxes on payroll & workforce               0.000000e+00  0.000000e+00
# Taxes on property                          0.000000e+00  0.000000e+00
# Taxes on goods & services                  8.331353e+08  9.208948e+08
# General taxes on goods & services          7.025920e+08  7.896842e+08
# Excise taxes                               1.277075e+08  1.279724e+08
# Taxes on int trade & transactions          2.321254e+08  2.706976e+08
# Other taxes n.e.c.                         6.278911e+06  7.517419e+06
# Social contributions                       9.841254e+07  9.284398e+07
# Social security contributions              0.000000e+00  0.000000e+00
# Other social contributions                 9.841254e+07  9.284398e+07
# Grants                                     3.722594e+08  4.821748e+08
# Grants from foreign govts                  6.308647e+07  1.571397e+08
# Grants from int orgs                       3.091729e+08  3.250350e+08
# Grants from other gen govt                 0.000000e+00  0.000000e+00
# Grants from other gen govt: current        0.000000e+00  0.000000e+00
# Grants from other gen govt: capital        0.000000e+00  0.000000e+00
# Other revenue                              6.227910e+07  6.785715e+07
# Property income                            3.256529e+07  3.559778e+07
# Sales of goods & services                  2.971371e+07  3.225846e+07
# Fines, penalties & forfeits                9.694025e+01  9.115909e+02
# Other transfers                            0.000000e+00  0.000000e+00
# NI & SGS: premiums, fees & claims          0.000000e+00  0.000000e+00

# %%
for key in master_table:
  print(key)
# Out:
# Senegal
# Côte d'Ivoire
# Burkina Faso
# Central African Republic
# Tanzania
# Democratic Republic of the Congo
# Rwanda
# Republic of Congo
# Sudan
# Togo
# Mali
# Malawi
# Mozambique
# Sierra Leone
# Burundi
# Cameroon
# Madagascar

# %% [markdown]
# Convert to Percentage (if unweighted)

# %%
if unweighted_or_aggregated == "unweighted":
  for key in master_table: #iterate through master_table
    total = master_table[key].loc[taxes_or_expenditure]
    master_table[key] = master_table[key] / total * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places

# master_table['Togo']

# %% [markdown]
# Calculate Yearly Averages

# %%
# data_by_year_table = {
#   2010: [],
#   2011: [],
#   2012: [],
#   2013: [],
#   2014: [],
#   2015: [],
#   2016: [],
#   2017: [],
#   2018: [],
#   2019: [],
# } #make table that stores data by year
data_by_year_table = {}
for year in years:
  data_by_year_table[year] = []

# master_averages_ls = [] #make master averages list as place to store averages

for key in master_table:
  years_available = master_table[key].columns
  for year in data_by_year_table:
    if year in years_available:
      data_by_year_table[year].append(master_table[key][year])

yearly_averages_ls = [] #make a list of the yearly averages
for year in data_by_year_table:
  merged_year_df = pd.concat(data_by_year_table[year], axis=1, join='outer')
  #SUM OR MEAN?
  if unweighted_or_aggregated == "aggregated":
    year_average_df = merged_year_df.sum(axis=1) #get the average of all the countries' averages
  elif unweighted_or_aggregated == "unweighted":
    year_average_df = merged_year_df.mean(axis=1) #get the average of all the countries' averages
  yearly_averages_ls.append(year_average_df)

 
# #Get average over decade
# #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
# for key in master_table:
#   per_category_average = master_table[key].mean(axis=1) #get the average of each category (ignoring np.NaN values) into a list
#   # per_category_average.drop('To other government units', inplace=True) #drop 'To other government units' since there's two rows named that and will error
#   master_averages_ls.append(per_category_average) #add each country average to to the master averages list



# merged_averages_df = pd.concat(master_averages_ls, axis=1, join='outer')
# average__of_averages_df = merged_averages_df.mean(axis=1) #get the average of all the countries' averages
# average__of_averages_df

for i in range(len(yearly_averages_ls)):
  print(f"YEAR: {2010+i}")
  print(yearly_averages_ls[i])
# Out:
# YEAR: 2010
# nan
# Revenue                                                    46135090696.262459
# Taxes                                                      24310248856.894337
# Taxes on income, profits, & capital gains                   6283109201.590809
# Taxes on income, profits, & capital gains: individuals      2493307325.573338
# Taxes on income, profits, & capital gains: corporations     2114773377.788073
# Taxes on income, profits, & capital gains: other             254810688.188532
# Taxes on payroll & workforce                                  58219502.201636
# Taxes on property                                             66431403.604901
# Taxes on goods & services                                  11103540077.400969
# General taxes on goods & services                           6304097265.801343
# Excise taxes                                                 2084328524.40197
# Taxes on int trade & transactions                           5521210711.698543
# Other taxes n.e.c.                                          1094933609.969802
# Social contributions                                         115940065.853829
# Social security contributions                                             0.0
# Other social contributions                                    82344276.671997
# Grants                                                     10845690500.723791
# Grants from foreign govts                                   6199945240.693333
# Grants from int orgs                                        2903007962.371664
# Grants from other gen govt                                                0.0
# Grants from other gen govt: current                                       0.0
# Grants from other gen govt: capital                                       0.0
# Other revenue                                              10859493193.910702
# Property income                                             1293907140.914444
# Sales of goods & services                                   3754469038.237717
# Fines, penalties & forfeits                                  429853672.220686
# Other transfers                                              1257900497.79643
# NI & SGS: premiums, fees & claims                                         0.0
# dtype: object
# YEAR: 2011
# nan
# Revenue                                                    4.280510e+10
# Taxes                                                      2.360707e+10
# Taxes on income, profits, & capital gains                  6.605725e+09
# Taxes on income, profits, & capital gains: individuals     2.582746e+09
# Taxes on income, profits, & capital gains: corporations    2.204819e+09
# Taxes on income, profits, & capital gains: other           2.405400e+08
# Taxes on payroll & workforce                               4.611203e+07
# Taxes on property                                          8.610887e+07
# Taxes on goods & services                                  1.129963e+10
# General taxes on goods & services                          6.760758e+09
# Excise taxes                                               2.235187e+09
# Taxes on int trade & transactions                          4.326685e+09
# Other taxes n.e.c.                                         1.054709e+09
# Social contributions                                       1.438035e+08
# Social security contributions                              0.000000e+00
# Other social contributions                                 9.409760e+07
# Grants                                                     6.561469e+09
# Grants from foreign govts                                  2.754384e+09
# Grants from int orgs                                       2.262169e+09
# Grants from other gen govt                                 0.000000e+00
# Grants from other gen govt: current                        0.000000e+00
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              1.248844e+10
# Property income                                            5.528690e+09
# Sales of goods & services                                  4.440531e+08
# Fines, penalties & forfeits                                1.319534e+07
# Other transfers                                            5.998272e+08
# NI & SGS: premiums, fees & claims                          0.000000e+00
# dtype: float64
# YEAR: 2012
# nan
# Revenue                                                    50097346501.666641
# Taxes                                                      32623301989.985737
# Taxes on income, profits, & capital gains                   9352421400.437292
# Taxes on income, profits, & capital gains: individuals      3434331352.147707
# Taxes on income, profits, & capital gains: corporations     3787619979.161077
# Taxes on income, profits, & capital gains: other             448893134.864518
# Taxes on payroll & workforce                                 139500802.505608
# Taxes on property                                             83224531.753843
# Taxes on goods & services                                  15564888921.063154
# General taxes on goods & services                           9220160697.010637
# Excise taxes                                                2780430551.952311
# Taxes on int trade & transactions                           6423447676.426266
# Other taxes n.e.c.                                           850740597.854343
# Social contributions                                         165642401.080344
# Social security contributions                                             0.0
# Other social contributions                                   105492865.246518
# Grants                                                      6709335057.542337
# Grants from foreign govts                                   2241831039.448984
# Grants from int orgs                                        2913345138.294433
# Grants from other gen govt                                                0.0
# Grants from other gen govt: current                                       0.0
# Grants from other gen govt: capital                                       0.0
# Other revenue                                              10594689808.381937
# Property income                                             7694711109.201408
# Sales of goods & services                                    662122901.036832
# Fines, penalties & forfeits                                    62011616.55265
# Other transfers                                              529726947.743916
# NI & SGS: premiums, fees & claims                                         0.0
# dtype: object
# YEAR: 2013
# nan
# Revenue                                                    5.652113e+10
# Taxes                                                      3.411930e+10
# Taxes on income, profits, & capital gains                  1.013199e+10
# Taxes on income, profits, & capital gains: individuals     3.510780e+09
# Taxes on income, profits, & capital gains: corporations    4.338691e+09
# Taxes on income, profits, & capital gains: other           5.618783e+08
# Taxes on payroll & workforce                               1.120832e+08
# Taxes on property                                          9.656777e+07
# Taxes on goods & services                                  1.617669e+10
# General taxes on goods & services                          9.179709e+09
# Excise taxes                                               2.802043e+09
# Taxes on int trade & transactions                          6.899207e+09
# Other taxes n.e.c.                                         7.027678e+08
# Social contributions                                       2.041334e+08
# Social security contributions                              0.000000e+00
# Other social contributions                                 1.330609e+08
# Grants                                                     8.737876e+09
# Grants from foreign govts                                  1.883720e+09
# Grants from int orgs                                       4.600796e+09
# Grants from other gen govt                                 0.000000e+00
# Grants from other gen govt: current                        0.000000e+00
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              1.047468e+10
# Property income                                            7.336706e+09
# Sales of goods & services                                  6.832326e+08
# Fines, penalties & forfeits                                4.926271e+07
# Other transfers                                            6.311179e+08
# NI & SGS: premiums, fees & claims                          0.000000e+00
# dtype: float64
# YEAR: 2014
# nan
# Revenue                                                    6.123966e+10
# Taxes                                                      4.202607e+10
# Taxes on income, profits, & capital gains                  1.289758e+10
# Taxes on income, profits, & capital gains: individuals     4.894307e+09
# Taxes on income, profits, & capital gains: corporations    5.814592e+09
# Taxes on income, profits, & capital gains: other           8.823826e+08
# Taxes on payroll & workforce                               1.681746e+08
# Taxes on property                                          1.877518e+08
# Taxes on goods & services                                  2.006331e+10
# General taxes on goods & services                          1.042961e+10
# Excise taxes                                               4.041378e+09
# Taxes on int trade & transactions                          7.930864e+09
# Other taxes n.e.c.                                         7.011029e+08
# Social contributions                                       2.264496e+08
# Social security contributions                              0.000000e+00
# Other social contributions                                 1.361458e+08
# Grants                                                     8.077911e+09
# Grants from foreign govts                                  1.716027e+09
# Grants from int orgs                                       4.349041e+09
# Grants from other gen govt                                 1.548607e+08
# Grants from other gen govt: current                        1.308606e+08
# Grants from other gen govt: capital                        2.400004e+07
# Other revenue                                              1.090943e+10
# Property income                                            6.694982e+09
# Sales of goods & services                                  1.312844e+09
# Fines, penalties & forfeits                                1.472320e+08
# Other transfers                                            3.657799e+08
# NI & SGS: premiums, fees & claims                          0.000000e+00
# dtype: float64
# YEAR: 2015
# nan
# Revenue                                                    5.477605e+10
# Taxes                                                      4.066892e+10
# Taxes on income, profits, & capital gains                  1.207960e+10
# Taxes on income, profits, & capital gains: individuals     4.973810e+09
# Taxes on income, profits, & capital gains: corporations    5.336205e+09
# Taxes on income, profits, & capital gains: other           6.286772e+08
# Taxes on payroll & workforce                               1.647032e+08
# Taxes on property                                          3.452471e+08
# Taxes on goods & services                                  2.052606e+10
# General taxes on goods & services                          1.091381e+10
# Excise taxes                                               3.799228e+09
# Taxes on int trade & transactions                          6.824728e+09
# Other taxes n.e.c.                                         6.365215e+08
# Social contributions                                       2.084936e+08
# Social security contributions                              0.000000e+00
# Other social contributions                                 1.207126e+08
# Grants                                                     6.878540e+09
# Grants from foreign govts                                  2.308586e+09
# Grants from int orgs                                       3.734052e+09
# Grants from other gen govt                                 7.940424e+07
# Grants from other gen govt: current                        7.940424e+07
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              7.020264e+09
# Property income                                            3.169577e+09
# Sales of goods & services                                  1.525435e+09
# Fines, penalties & forfeits                                1.329832e+08
# Other transfers                                            3.757139e+08
# NI & SGS: premiums, fees & claims                          0.000000e+00
# dtype: float64
# YEAR: 2016
# nan
# Revenue                                                    5.224991e+10
# Taxes                                                      4.157442e+10
# Taxes on income, profits, & capital gains                  1.166137e+10
# Taxes on income, profits, & capital gains: individuals     5.189793e+09
# Taxes on income, profits, & capital gains: corporations    4.883152e+09
# Taxes on income, profits, & capital gains: other           2.732164e+08
# Taxes on payroll & workforce                               1.936663e+08
# Taxes on property                                          3.728941e+08
# Taxes on goods & services                                  2.199662e+10
# General taxes on goods & services                          1.092653e+10
# Excise taxes                                               4.705538e+09
# Taxes on int trade & transactions                          6.579691e+09
# Other taxes n.e.c.                                         6.462306e+08
# Social contributions                                       1.722879e+08
# Social security contributions                              9.606765e+06
# Other social contributions                                 1.626811e+08
# Grants                                                     5.016430e+09
# Grants from foreign govts                                  1.210859e+09
# Grants from int orgs                                       3.385135e+09
# Grants from other gen govt                                 6.565260e+07
# Grants from other gen govt: current                        1.683400e+05
# Grants from other gen govt: capital                        6.548426e+07
# Other revenue                                              5.486770e+09
# Property income                                            2.443636e+09
# Sales of goods & services                                  1.155018e+09
# Fines, penalties & forfeits                                1.100768e+08
# Other transfers                                            2.898975e+08
# NI & SGS: premiums, fees & claims                          3.604420e+07
# dtype: float64
# YEAR: 2017
# nan
# Revenue                                                    4.682605e+10
# Taxes                                                      3.724190e+10
# Taxes on income, profits, & capital gains                  1.202702e+10
# Taxes on income, profits, & capital gains: individuals     5.249396e+09
# Taxes on income, profits, & capital gains: corporations    5.839080e+09
# Taxes on income, profits, & capital gains: other           6.126384e+08
# Taxes on payroll & workforce                               2.462559e+08
# Taxes on property                                          3.967533e+08
# Taxes on goods & services                                  1.789080e+10
# General taxes on goods & services                          1.261368e+10
# Excise taxes                                               4.490322e+09
# Taxes on int trade & transactions                          5.756105e+09
# Other taxes n.e.c.                                         7.776129e+08
# Social contributions                                       2.207454e+08
# Social security contributions                              7.550444e+06
# Other social contributions                                 2.131949e+08
# Grants                                                     4.425263e+09
# Grants from foreign govts                                  1.665078e+09
# Grants from int orgs                                       2.651885e+09
# Grants from other gen govt                                 5.711055e+07
# Grants from other gen govt: current                        5.711055e+07
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              4.938134e+09
# Property income                                            2.845732e+09
# Sales of goods & services                                  1.595125e+09
# Fines, penalties & forfeits                                9.581949e+07
# Other transfers                                            7.197199e+07
# NI & SGS: premiums, fees & claims                          3.276235e+08
# dtype: float64
# YEAR: 2018
# nan
# Revenue                                                    5.248089e+10
# Taxes                                                      4.007174e+10
# Taxes on income, profits, & capital gains                  1.342099e+10
# Taxes on income, profits, & capital gains: individuals     5.758463e+09
# Taxes on income, profits, & capital gains: corporations    6.632930e+09
# Taxes on income, profits, & capital gains: other           6.743873e+08
# Taxes on payroll & workforce                               2.221274e+08
# Taxes on property                                          4.639202e+08
# Taxes on goods & services                                  1.922311e+10
# General taxes on goods & services                          1.332928e+10
# Excise taxes                                               4.972107e+09
# Taxes on int trade & transactions                          5.919058e+09
# Other taxes n.e.c.                                         6.309035e+08
# Social contributions                                       3.066305e+08
# Social security contributions                              1.022197e+06
# Other social contributions                                 3.056083e+08
# Grants                                                     5.001128e+09
# Grants from foreign govts                                  1.094241e+09
# Grants from int orgs                                       3.906888e+09
# Grants from other gen govt                                 0.000000e+00
# Grants from other gen govt: current                        0.000000e+00
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              7.101396e+09
# Property income                                            4.593321e+09
# Sales of goods & services                                  1.624752e+09
# Fines, penalties & forfeits                                1.105364e+08
# Other transfers                                            6.053972e+08
# NI & SGS: premiums, fees & claims                          1.639403e+08
# dtype: float64
# YEAR: 2019
# nan
# Revenue                                                    4.671428e+10
# Taxes                                                      3.581488e+10
# Taxes on income, profits, & capital gains                  1.237113e+10
# Taxes on income, profits, & capital gains: individuals     4.674415e+09
# Taxes on income, profits, & capital gains: corporations    6.794162e+09
# Taxes on income, profits, & capital gains: other           4.684108e+08
# Taxes on payroll & workforce                               1.962101e+08
# Taxes on property                                          3.878672e+08
# Taxes on goods & services                                  1.667012e+10
# General taxes on goods & services                          1.208584e+10
# Excise taxes                                               3.525637e+09
# Taxes on int trade & transactions                          5.539750e+09
# Other taxes n.e.c.                                         6.497951e+08
# Social contributions                                       1.838717e+08
# Social security contributions                              4.484816e+06
# Other social contributions                                 1.793869e+08
# Grants                                                     4.745331e+09
# Grants from foreign govts                                  1.195481e+09
# Grants from int orgs                                       3.453369e+09
# Grants from other gen govt                                 0.000000e+00
# Grants from other gen govt: current                        0.000000e+00
# Grants from other gen govt: capital                        0.000000e+00
# Other revenue                                              5.970199e+09
# Property income                                            4.664462e+09
# Sales of goods & services                                  1.020297e+09
# Fines, penalties & forfeits                                1.508073e+08
# Other transfers                                            1.325412e+08
# NI & SGS: premiums, fees & claims                          2.091230e+06
# dtype: float64

# %% [markdown]
# Calculate Percentages (if aggregated)

# %%
if unweighted_or_aggregated == "aggregated":

  yearly_averages_percentage_ls = []

  year = 2010
  for year_average_df in yearly_averages_ls:


    total = year_average_df[taxes_or_expenditure]
    year_average_percentage_df = year_average_df / total * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places
    
    first_level = 0
    print(year)
    for category in first_level_ls:
      first_level += year_average_percentage_df[category]
    print(first_level)
    # print(year_average_percentage_df['Revenue'])
    year += 1
    
    yearly_averages_percentage_ls.append(year_average_percentage_df)

  yearly_averages_ls = yearly_averages_percentage_ls
  for i in range(len(yearly_averages_percentage_ls)):
    print(f"YEAR: {2010+i}")
    print(yearly_averages_percentage_ls[i])
# Out:
# 2010
# 189.7610052819344
# 2011
# 181.30495027887218
# 2012
# 153.54965990986204
# 2013
# 156.90822389140436
# 2014
# 145.71874944685314
# 2015
# 134.68815060670084
# 2016
# 125.67801862579306
# 2017
# 125.73483346597047
# 2018
# 130.9673469681708
# 2019
# 130.4326051357895
# YEAR: 2010
# nan
# Revenue                                                     189.7763
# Taxes                                                          100.0
# Taxes on income, profits, & capital gains                  25.845516
# Taxes on income, profits, & capital gains: individuals     10.256198
# Taxes on income, profits, & capital gains: corporations     8.699102
# Taxes on income, profits, & capital gains: other            1.048162
# Taxes on payroll & workforce                                0.239485
# Taxes on property                                           0.273265
# Taxes on goods & services                                  45.674317
# General taxes on goods & services                           25.93185
# Excise taxes                                                8.573867
# Taxes on int trade & transactions                          22.711453
# Other taxes n.e.c.                                             4.504
# Social contributions                                        0.476918
# Social security contributions                                    0.0
# Other social contributions                                  0.338722
# Grants                                                     44.613655
# Grants from foreign govts                                  25.503422
# Grants from int orgs                                       11.941498
# Grants from other gen govt                                       0.0
# Grants from other gen govt: current                              0.0
# Grants from other gen govt: capital                              0.0
# Other revenue                                              44.670432
# Property income                                             5.322476
# Sales of goods & services                                  15.443976
# Fines, penalties & forfeits                                 1.768199
# Other transfers                                             5.174363
# NI & SGS: premiums, fees & claims                                0.0
# dtype: object
# YEAR: 2011
# nan
# Revenue                                                    181.323226
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   27.981979
# Taxes on income, profits, & capital gains: individuals      10.940563
# Taxes on income, profits, & capital gains: corporations      9.339658
# Taxes on income, profits, & capital gains: other             1.018932
# Taxes on payroll & workforce                                 0.195331
# Taxes on property                                            0.364759
# Taxes on goods & services                                   47.865444
# General taxes on goods & services                           28.638699
# Excise taxes                                                 9.468294
# Taxes on int trade & transactions                           18.327919
# Other taxes n.e.c.                                           4.467766
# Social contributions                                         0.609154
# Social security contributions                                0.000000
# Other social contributions                                   0.398599
# Grants                                                      27.794507
# Grants from foreign govts                                   11.667623
# Grants from int orgs                                         9.582591
# Grants from other gen govt                                   0.000000
# Grants from other gen govt: current                          0.000000
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               52.901289
# Property income                                             23.419637
# Sales of goods & services                                    1.881017
# Fines, penalties & forfeits                                  0.055896
# Other transfers                                              2.540879
# NI & SGS: premiums, fees & claims                            0.000000
# dtype: float64
# YEAR: 2012
# nan
# Revenue                                                    153.563077
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   28.667918
# Taxes on income, profits, & capital gains: individuals      10.527234
# Taxes on income, profits, & capital gains: corporations     11.610167
# Taxes on income, profits, & capital gains: other             1.375989
# Taxes on payroll & workforce                                 0.427611
# Taxes on property                                            0.255108
# Taxes on goods & services                                   47.710955
# General taxes on goods & services                             28.2625
# Excise taxes                                                 8.522836
# Taxes on int trade & transactions                           19.689753
# Other taxes n.e.c.                                            2.60777
# Social contributions                                         0.507743
# Social security contributions                                     0.0
# Other social contributions                                   0.323367
# Grants                                                      20.566082
# Grants from foreign govts                                     6.87187
# Grants from int orgs                                         8.930258
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                               32.475835
# Property income                                             23.586549
# Sales of goods & services                                    2.029601
# Fines, penalties & forfeits                                  0.190084
# Other transfers                                              1.623769
# NI & SGS: premiums, fees & claims                                 0.0
# dtype: object
# YEAR: 2013
# nan
# Revenue                                                    165.657356
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   29.695766
# Taxes on income, profits, & capital gains: individuals      10.289718
# Taxes on income, profits, & capital gains: corporations     12.716237
# Taxes on income, profits, & capital gains: other             1.646805
# Taxes on payroll & workforce                                 0.328504
# Taxes on property                                            0.283030
# Taxes on goods & services                                   47.412130
# General taxes on goods & services                           26.904743
# Excise taxes                                                 8.212487
# Taxes on int trade & transactions                           20.220835
# Other taxes n.e.c.                                           2.059737
# Social contributions                                         0.598293
# Social security contributions                                0.000000
# Other social contributions                                   0.389987
# Grants                                                      25.609777
# Grants from foreign govts                                    5.520980
# Grants from int orgs                                        13.484438
# Grants from other gen govt                                   0.000000
# Grants from other gen govt: current                          0.000000
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               30.700154
# Property income                                             21.503098
# Sales of goods & services                                    2.002482
# Fines, penalties & forfeits                                  0.144384
# Other transfers                                              1.849739
# NI & SGS: premiums, fees & claims                            0.000000
# dtype: float64
# YEAR: 2014
# nan
# Revenue                                                    145.718273
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   30.689485
# Taxes on income, profits, & capital gains: individuals      11.645884
# Taxes on income, profits, & capital gains: corporations     13.835681
# Taxes on income, profits, & capital gains: other             2.099608
# Taxes on payroll & workforce                                 0.400167
# Taxes on property                                            0.446751
# Taxes on goods & services                                   47.740157
# General taxes on goods & services                           24.816998
# Excise taxes                                                 9.616360
# Taxes on int trade & transactions                           18.871299
# Other taxes n.e.c.                                           1.668257
# Social contributions                                         0.538831
# Social security contributions                                0.000000
# Other social contributions                                   0.323956
# Grants                                                      19.221192
# Grants from foreign govts                                    4.083243
# Grants from int orgs                                        10.348436
# Grants from other gen govt                                   0.368487
# Grants from other gen govt: current                          0.311380
# Grants from other gen govt: capital                          0.057108
# Other revenue                                               25.958726
# Property income                                             15.930547
# Sales of goods & services                                    3.123880
# Fines, penalties & forfeits                                  0.350335
# Other transfers                                              0.870364
# NI & SGS: premiums, fees & claims                            0.000000
# dtype: float64
# YEAR: 2015
# nan
# Revenue                                                    134.687737
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   29.702277
# Taxes on income, profits, & capital gains: individuals      12.230001
# Taxes on income, profits, & capital gains: corporations     13.121088
# Taxes on income, profits, & capital gains: other             1.545842
# Taxes on payroll & workforce                                 0.404985
# Taxes on property                                            0.848921
# Taxes on goods & services                                   50.471104
# General taxes on goods & services                           26.835749
# Excise taxes                                                 9.341846
# Taxes on int trade & transactions                           16.781186
# Other taxes n.e.c.                                           1.565130
# Social contributions                                         0.512661
# Social security contributions                                0.000000
# Other social contributions                                   0.296818
# Grants                                                      16.913503
# Grants from foreign govts                                    5.676536
# Grants from int orgs                                         9.181586
# Grants from other gen govt                                   0.195245
# Grants from other gen govt: current                          0.195245
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               17.261987
# Property income                                              7.793608
# Sales of goods & services                                    3.750861
# Fines, penalties & forfeits                                  0.326990
# Other transfers                                              0.923835
# NI & SGS: premiums, fees & claims                            0.000000
# dtype: float64
# YEAR: 2016
# nan
# Revenue                                                    125.678019
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   28.049393
# Taxes on income, profits, & capital gains: individuals      12.483140
# Taxes on income, profits, & capital gains: corporations     11.745567
# Taxes on income, profits, & capital gains: other             0.657174
# Taxes on payroll & workforce                                 0.465831
# Taxes on property                                            0.896932
# Taxes on goods & services                                   52.909034
# General taxes on goods & services                           26.281853
# Excise taxes                                                11.318348
# Taxes on int trade & transactions                           15.826296
# Other taxes n.e.c.                                           1.554395
# Social contributions                                         0.414408
# Social security contributions                                0.023107
# Other social contributions                                   0.391301
# Grants                                                      12.066144
# Grants from foreign govts                                    2.912510
# Grants from int orgs                                         8.142350
# Grants from other gen govt                                   0.157916
# Grants from other gen govt: current                          0.000405
# Grants from other gen govt: capital                          0.157511
# Other revenue                                               13.197466
# Property income                                              5.877738
# Sales of goods & services                                    2.778194
# Fines, penalties & forfeits                                  0.264771
# Other transfers                                              0.697298
# NI & SGS: premiums, fees & claims                            0.086698
# dtype: float64
# YEAR: 2017
# nan
# Revenue                                                    125.734833
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   32.294316
# Taxes on income, profits, & capital gains: individuals      14.095401
# Taxes on income, profits, & capital gains: corporations     15.678790
# Taxes on income, profits, & capital gains: other             1.645024
# Taxes on payroll & workforce                                 0.661233
# Taxes on property                                            1.065341
# Taxes on goods & services                                   48.039429
# General taxes on goods & services                           33.869584
# Excise taxes                                                12.057176
# Taxes on int trade & transactions                           15.455989
# Other taxes n.e.c.                                           2.088005
# Social contributions                                         0.592734
# Social security contributions                                0.020274
# Other social contributions                                   0.572460
# Grants                                                      11.882482
# Grants from foreign govts                                    4.470979
# Grants from int orgs                                         7.120702
# Grants from other gen govt                                   0.153350
# Grants from other gen govt: current                          0.153350
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               13.259617
# Property income                                              7.641211
# Sales of goods & services                                    4.283147
# Fines, penalties & forfeits                                  0.257289
# Other transfers                                              0.193255
# NI & SGS: premiums, fees & claims                            0.879717
# dtype: float64
# YEAR: 2018
# nan
# Revenue                                                    130.967330
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   33.492416
# Taxes on income, profits, & capital gains: individuals      14.370383
# Taxes on income, profits, & capital gains: corporations     16.552637
# Taxes on income, profits, & capital gains: other             1.682950
# Taxes on payroll & workforce                                 0.554324
# Taxes on property                                            1.157724
# Taxes on goods & services                                   47.971728
# General taxes on goods & services                           33.263551
# Excise taxes                                                12.408014
# Taxes on int trade & transactions                           14.771153
# Other taxes n.e.c.                                           1.574435
# Social contributions                                         0.765204
# Social security contributions                                0.002551
# Other social contributions                                   0.762653
# Grants                                                      12.480437
# Grants from foreign govts                                    2.730704
# Grants from int orgs                                         9.749733
# Grants from other gen govt                                   0.000000
# Grants from other gen govt: current                          0.000000
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               17.721706
# Property income                                             11.462743
# Sales of goods & services                                    4.054608
# Fines, penalties & forfeits                                  0.275846
# Other transfers                                              1.510783
# NI & SGS: premiums, fees & claims                            0.409117
# dtype: float64
# YEAR: 2019
# nan
# Revenue                                                    130.432605
# Taxes                                                      100.000000
# Taxes on income, profits, & capital gains                   34.541875
# Taxes on income, profits, & capital gains: individuals      13.051598
# Taxes on income, profits, & capital gains: corporations     18.970219
# Taxes on income, profits, & capital gains: other             1.307866
# Taxes on payroll & workforce                                 0.547845
# Taxes on property                                            1.082978
# Taxes on goods & services                                   46.545243
# General taxes on goods & services                           33.745313
# Excise taxes                                                 9.844056
# Taxes on int trade & transactions                           15.467732
# Other taxes n.e.c.                                           1.814316
# Social contributions                                         0.513395
# Social security contributions                                0.012522
# Other social contributions                                   0.500873
# Grants                                                      13.249608
# Grants from foreign govts                                    3.337944
# Grants from int orgs                                         9.642274
# Grants from other gen govt                                   0.000000
# Grants from other gen govt: current                          0.000000
# Grants from other gen govt: capital                          0.000000
# Other revenue                                               16.669603
# Property income                                             13.023809
# Sales of goods & services                                    2.848807
# Fines, penalties & forfeits                                  0.421074
# Other transfers                                              0.370073
# NI & SGS: premiums, fees & claims                            0.005839
# dtype: float64

# %% [markdown]
# Calculate Average Across Period

# %%
merged_percentages_df = pd.concat(yearly_averages_ls, axis=1, join='outer')
average_df = merged_percentages_df.mean(axis=1)
rounded_average_df = average_df.apply(lambda x: round(x, 2))

rounded_average_df = rounded_average_df.to_frame()

# %%
#check
first_level = 0
for category in first_level_ls:
  first_level += average_df[category]
print(first_level)

# second_level = 0
# for category in second_level_ls:
#   second_level += average_df[category]
# print(second_level)
# Out:
# 147.47435436113508

# %%
rounded_by_year_average_df = merged_percentages_df.round(2)
# rounded_by_year_average_df.iloc[:, 5:]
rounded_by_year_average_df.columns = [str(int(col) + 2010) for col in rounded_by_year_average_df.columns]

# %% [markdown]
# Plot over time

# %%
def graph(rows_to_plot):
    # sns.set(style="whitegrid")

    # Plotting
    plt.figure(figsize=(10, 6))
    for row in rows_to_plot:
        sns.lineplot(x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], marker='o', label=row)

    # Add labels and title
    plt.xlabel('Year', fontsize=12)
    if taxes_or_expenditure == "Taxes":
        plt.ylabel('Percentage of Tax Revenue', fontsize=12)
    elif taxes_or_expenditure == "Expenditure":
        plt.ylabel('Percentage of Expenditure', fontsize=12)

    # plt.title('Percentage of Tax Revenue Over Time')

    # Customize the legend
    plt.legend(title='Category', title_fontsize='12', fontsize='10', loc='upper right')

    # Customize the ticks and grid
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', linewidth=0.5)

    # Adjust y-axis limits to be 120% of the original range
    y_min, y_max = plt.ylim()
    y_range = y_max - y_min
    plt.ylim(y_min, y_max + 0.25 * y_range)

    # Show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Output

# %%
rounded_average_df
# Out:
#                                                          0
# nan
# Revenue                                             148.35
# Taxes                                               100.00
# Taxes on income, profits, & capital gains            30.10
# Taxes on income, profits, & capital gains: indi...   11.99
# Taxes on income, profits, & capital gains: corp...   13.23
# Taxes on income, profits, & capital gains: other      1.40
# Taxes on payroll & workforce                          0.42
# Taxes on property                                     0.67
# Taxes on goods & services                            48.23
# General taxes on goods & services                    28.86
# Excise taxes                                          9.94
# Taxes on int trade & transactions                    17.81
# Other taxes n.e.c.                                    2.39
# Social contributions                                  0.55
# Social security contributions                         0.01
# Other social contributions                            0.43
# Grants                                               20.44
# Grants from foreign govts                             7.28
# Grants from int orgs                                  9.81
# Grants from other gen govt                            0.09
# Grants from other gen govt: current                   0.07
# Grants from other gen govt: capital                   0.02
# Other revenue                                        26.48
# Property income                                      13.56
# Sales of goods & services                             4.22
# Fines, penalties & forfeits                           0.41
# Other transfers                                       1.58
# NI & SGS: premiums, fees & claims                     0.14

# %%
rounded_by_year_average_df
# Out:
#                                                          2010    2011  \
# nan
# Revenue                                              189.7763  181.32
# Taxes                                                   100.0  100.00
# Taxes on income, profits, & capital gains           25.845516   27.98
# Taxes on income, profits, & capital gains: indi...  10.256198   10.94
# Taxes on income, profits, & capital gains: corp...   8.699102    9.34
# Taxes on income, profits, & capital gains: other     1.048162    1.02
# Taxes on payroll & workforce                         0.239485    0.20
# Taxes on property                                    0.273265    0.36
# Taxes on goods & services                           45.674317   47.87
# General taxes on goods & services                    25.93185   28.64
# Excise taxes                                         8.573867    9.47
# Taxes on int trade & transactions                   22.711453   18.33
# Other taxes n.e.c.                                      4.504    4.47
# Social contributions                                 0.476918    0.61
# Social security contributions                             0.0    0.00
# Other social contributions                           0.338722    0.40
# Grants                                              44.613655   27.79
# Grants from foreign govts                           25.503422   11.67
# Grants from int orgs                                11.941498    9.58
# Grants from other gen govt                                0.0    0.00
# Grants from other gen govt: current                       0.0    0.00
# Grants from other gen govt: capital                       0.0    0.00
# Other revenue                                       44.670432   52.90
# Property income                                      5.322476   23.42
# Sales of goods & services                           15.443976    1.88
# Fines, penalties & forfeits                          1.768199    0.06
# Other transfers                                      5.174363    2.54
# NI & SGS: premiums, fees & claims                         0.0    0.00
#
#                                                           2012    2013  \
# nan
# Revenue                                             153.563077  165.66
# Taxes                                                    100.0  100.00
# Taxes on income, profits, & capital gains            28.667918   29.70
# Taxes on income, profits, & capital gains: indi...   10.527234   10.29
# Taxes on income, profits, & capital gains: corp...   11.610167   12.72
# Taxes on income, profits, & capital gains: other      1.375989    1.65
# Taxes on payroll & workforce                          0.427611    0.33
# Taxes on property                                     0.255108    0.28
# Taxes on goods & services                            47.710955   47.41
# General taxes on goods & services                      28.2625   26.90
# Excise taxes                                          8.522836    8.21
# Taxes on int trade & transactions                    19.689753   20.22
# Other taxes n.e.c.                                     2.60777    2.06
# Social contributions                                  0.507743    0.60
# Social security contributions                              0.0    0.00
# Other social contributions                            0.323367    0.39
# Grants                                               20.566082   25.61
# Grants from foreign govts                              6.87187    5.52
# Grants from int orgs                                  8.930258   13.48
# Grants from other gen govt                                 0.0    0.00
# Grants from other gen govt: current                        0.0    0.00
# Grants from other gen govt: capital                        0.0    0.00
# Other revenue                                        32.475835   30.70
# Property income                                      23.586549   21.50
# Sales of goods & services                             2.029601    2.00
# Fines, penalties & forfeits                           0.190084    0.14
# Other transfers                                       1.623769    1.85
# NI & SGS: premiums, fees & claims                          0.0    0.00
#
#                                                       2014    2015    2016  \
# nan
# Revenue                                             145.72  134.69  125.68
# Taxes                                               100.00  100.00  100.00
# Taxes on income, profits, & capital gains            30.69   29.70   28.05
# Taxes on income, profits, & capital gains: indi...   11.65   12.23   12.48
# Taxes on income, profits, & capital gains: corp...   13.84   13.12   11.75
# Taxes on income, profits, & capital gains: other      2.10    1.55    0.66
# Taxes on payroll & workforce                          0.40    0.40    0.47
# Taxes on property                                     0.45    0.85    0.90
# Taxes on goods & services                            47.74   50.47   52.91
# General taxes on goods & services                    24.82   26.84   26.28
# Excise taxes                                          9.62    9.34   11.32
# Taxes on int trade & transactions                    18.87   16.78   15.83
# Other taxes n.e.c.                                    1.67    1.57    1.55
# Social contributions                                  0.54    0.51    0.41
# Social security contributions                         0.00    0.00    0.02
# Other social contributions                            0.32    0.30    0.39
# Grants                                               19.22   16.91   12.07
# Grants from foreign govts                             4.08    5.68    2.91
# Grants from int orgs                                 10.35    9.18    8.14
# Grants from other gen govt                            0.37    0.20    0.16
# Grants from other gen govt: current                   0.31    0.20    0.00
# Grants from other gen govt: capital                   0.06    0.00    0.16
# Other revenue                                        25.96   17.26   13.20
# Property income                                      15.93    7.79    5.88
# Sales of goods & services                             3.12    3.75    2.78
# Fines, penalties & forfeits                           0.35    0.33    0.26
# Other transfers                                       0.87    0.92    0.70
# NI & SGS: premiums, fees & claims                     0.00    0.00    0.09
#
#                                                       2017    2018    2019
# nan
# Revenue                                             125.73  130.97  130.43
# Taxes                                               100.00  100.00  100.00
# Taxes on income, profits, & capital gains            32.29   33.49   34.54
# Taxes on income, profits, & capital gains: indi...   14.10   14.37   13.05
# Taxes on income, profits, & capital gains: corp...   15.68   16.55   18.97
# Taxes on income, profits, & capital gains: other      1.65    1.68    1.31
# Taxes on payroll & workforce                          0.66    0.55    0.55
# Taxes on property                                     1.07    1.16    1.08
# Taxes on goods & services                            48.04   47.97   46.55
# General taxes on goods & services                    33.87   33.26   33.75
# Excise taxes                                         12.06   12.41    9.84
# Taxes on int trade & transactions                    15.46   14.77   15.47
# Other taxes n.e.c.                                    2.09    1.57    1.81
# Social contributions                                  0.59    0.77    0.51
# Social security contributions                         0.02    0.00    0.01
# Other social contributions                            0.57    0.76    0.50
# Grants                                               11.88   12.48   13.25
# Grants from foreign govts                             4.47    2.73    3.34
# Grants from int orgs                                  7.12    9.75    9.64
# Grants from other gen govt                            0.15    0.00    0.00
# Grants from other gen govt: current                   0.15    0.00    0.00
# Grants from other gen govt: capital                   0.00    0.00    0.00
# Other revenue                                        13.26   17.72   16.67
# Property income                                       7.64   11.46   13.02
# Sales of goods & services                             4.28    4.05    2.85
# Fines, penalties & forfeits                           0.26    0.28    0.42
# Other transfers                                       0.19    1.51    0.37
# NI & SGS: premiums, fees & claims                     0.88    0.41    0.01

# %%
for graph_ls in graphs:
  graph(graph_ls)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Net/gross investment in nonfinancial assets'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[234], line 2
#       1 for graph_ls in graphs:
# ----> 2   graph(graph_ls)
#
# Cell In[231], line 7, in graph(rows_to_plot)
#       5 plt.figure(figsize=(10, 6))
#       6 for row in rows_to_plot:
# ----> 7     sns.lineplot(x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], marker='o', label=row)
#       9 # Add labels and title
#      10 plt.xlabel('Year', fontsize=12)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4295, in NDFrame.xs(self, key, axis, level, drop_level)
#    4293             new_index = index[loc]
#    4294 else:
# -> 4295     loc = index.get_loc(key)
#    4297     if isinstance(loc, np.ndarray):
#    4298         if loc.dtype == np.bool_:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Net/gross investment in nonfinancial assets'
