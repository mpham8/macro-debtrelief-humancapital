# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Currency Codes

# %%
country_currency_codes_table = {
    'Burundi': 'BIF',
    'Benin': 'XOF',
    'Burkina Faso': 'XOF',
    'Central African Republic': 'XAF',
    "Côte d'Ivoire": 'XOF',
    'Cameroon': 'XAF',
    'Democratic Republic of the Congo': 'CDF',
    'Republic of Congo': 'XAF',
    'Comoros': 'KMF',
    'Eritrea': 'ERN',
    'Ethiopia': 'ETB',
    'Ghana': 'GHS',
    'Guinea': 'GNF',
    'The Gambia': 'GMD',
    'Guinea-Bissau': 'XOF',
    'Liberia': 'LRD',
    'Madagascar': 'MGA',
    'Mali': 'XOF',
    'Mozambique': 'MZN',
    'Mauritania': 'MRU',
    'Malawi': 'MWK',
    'Niger': 'XOF',
    'Rwanda': 'RWF',
    'Sudan': 'SDG',
    'Senegal': 'XOF',
    'Sierra Leone': 'SLL',
    'Somalia': 'SOS',
    'Sao Tomee and Principe': 'STN',
    'Chad': 'XAF',
    'Togo': 'XOF',
    'Tanzania': 'TZS',
    'Uganda': 'UGX',
    'Zambia': 'ZMW'
}

# %% [markdown]
# Read Data

# %%
#read in stata dataset as dataframe "country_code_df"
country_code_df = pd.read_stata("codesffactors_Mar23_2019.dta") 
country_code_df.replace('--', np.nan, inplace=True) #replace all entries that are '--' with NaN data value

country_code_df.head()
# Out:
#    countryname       wbctry wbcode                   wbregion  \
# 0        Aruba        Aruba    ABW  Latin America & Caribbean
# 1  Afghanistan  Afghanistan    AFG                 South Asia
# 2       Angola       Angola    AGO         Sub-Saharan Africa
# 3     Anguilla          NaN    AIA  Latin America & Caribbean
# 4      Albania      Albania    ALB      Europe & Central Asia
#
#           wbigroup2017 wblcat2017  hipc  emu  cemac  waemu  imfcode  \
# 0          High income        NaN     0    0      0      0      NaN
# 1           Low income        IDA     1    0      0      0    512.0
# 2  Lower middle income       IBRD     0    0      0      0    614.0
# 3                  NaN        NaN     0    0      0      0    312.0
# 4  Upper middle income       IBRD     0    0      0      0    914.0
#
#    imfweocode imfweoiso   imfweoctry region
# 0       314.0       ABW        Aruba    LAC
# 1       512.0       AFG  Afghanistan    SAS
# 2       614.0       AGO       Angola    SSA
# 3         NaN       NaN          NaN    LAC
# 4       914.0       ALB      Albania    ECA

# %%
region_classification_ls = country_code_df['wbregion'].unique() #get a list of region classifications
income_classification_ls = country_code_df['wbigroup2017'].unique() #get a list of income classifications
income_classification_ls = [x for x in income_classification_ls if not pd.isna(x)] # remove '--' from income_classification_ls

print(f"The region classifications are: {', '.join(country for country in region_classification_ls)}")
print(f"The income classifications are: {', '.join(country for country in income_classification_ls)}")
# Out:
# The region classifications are: Latin America & Caribbean, South Asia, Sub-Saharan Africa, Europe & Central Asia, Middle East & North Africa, East Asia & Pacific, North America
# The income classifications are: High income, Low income, Lower middle income, Upper middle income

# %%
ssa_hipc_countries = country_code_df[(country_code_df['hipc'] == 1) & (country_code_df['wbregion'] == 'Sub-Saharan Africa')]
ssa_hipc_countries_ls = ssa_hipc_countries['imfweoctry'].to_list()

ssa_hipc_countries_ls
# Out:
# ['Burundi',
#  'Benin',
#  'Burkina Faso',
#  'Central African Republic',
#  "Côte d'Ivoire",
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Republic of Congo',
#  'Comoros',
#  'Eritrea',
#  'Ethiopia',
#  'Ghana',
#  'Guinea',
#  'The Gambia',
#  'Guinea-Bissau',
#  'Liberia',
#  'Madagascar',
#  'Mali',
#  'Mozambique',
#  'Mauritania',
#  'Malawi',
#  'Niger',
#  'Rwanda',
#  'Sudan',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'São Tomé and Príncipe',
#  'Chad',
#  'Togo',
#  'Tanzania',
#  'Uganda',
#  'Zambia']

# %% [markdown]
# Read in IMF's Government Finance Statistics

# %%
master_table = {}
folder_path = "revenue-data"

# Loop that goes through all files 'file_name' in the folder 'folder_path'
for file_name in os.listdir(folder_path):
  if file_name.endswith('.xlsx') and not file_name.startswith('~$'): #check to see if is spreadsheet .xlsx format
    raw_df = pd.read_excel(folder_path+ "/" + file_name) #read in .xlsx as dataframe
    master_table[file_name[:-5]] = raw_df #store dataframe as an entry in the master_table hash table

# master_table["Central African Republic"]
master_table["Benin"]
# Out:
#                                            Unnamed: 0  \
# 0                          Detailed Revenue Breakdown
# 1                                      Country: Benin
# 2                Sector: Budgetary central government
# 3                             Unit: Domestic currency
# 4                                     Scale: Billions
# 5                                                 NaN
# 6                                                 NaN
# 7                                             Revenue
# 8                                               Taxes
# 9           Taxes on income, profits, & capital gains
# 10  Taxes on income, profits, & capital gains: ind...
# 11  Taxes on income, profits, & capital gains: cor...
# 12   Taxes on income, profits, & capital gains: other
# 13                       Taxes on payroll & workforce
# 14                                  Taxes on property
# 15                          Taxes on goods & services
# 16                  General taxes on goods & services
# 17                                       Excise taxes
# 18                  Taxes on int trade & transactions
# 19                                 Other taxes n.e.c.
# 20                               Social contributions
# 21                      Social security contributions
# 22                         Other social contributions
# 23                                             Grants
# 24                          Grants from foreign govts
# 25                               Grants from int orgs
# 26                         Grants from other gen govt
# 27                Grants from other gen govt: current
# 28                Grants from other gen govt: capital
# 29                                      Other revenue
# 30                                    Property income
# 31                          Sales of goods & services
# 32                        Fines, penalties & forfeits
# 33                                    Other transfers
# 34                  NI & SGS: premiums, fees & claims
#
#                     Unnamed: 1   Unnamed: 2   Unnamed: 3  Unnamed: 4
# 0   Detailed Revenue Breakdown          NaN          NaN         NaN
# 1                          NaN          NaN          NaN         NaN
# 2                          NaN          NaN          NaN         NaN
# 3                          NaN          NaN          NaN         NaN
# 4                          NaN          NaN          NaN         NaN
# 5                          NaN          NaN          NaN         NaN
# 6                         2010  2011.000000  2012.000000      2013.0
# 7                   648.375468   676.747224   701.455221       803.0
# 8                   536.250675   546.563646   599.904265       696.0
# 9                   104.846262   114.433242   118.073622       134.3
# 10                    46.00102    51.920867    56.326766        60.3
# 11                   47.753394    53.004216    53.119428        63.5
# 12                   11.091848     9.508159     8.627427        10.5
# 13                    5.104337     5.305594     5.726621         6.0
# 14                    1.681998     1.663647     1.280306         1.8
# 15                  275.476543   282.885616   301.812744       349.9
# 16                  232.742208   240.434099   269.594113       308.8
# 17                   23.150171    21.162270     8.915147        23.3
# 18                  142.732772   133.038373   163.913078       194.3
# 19                    6.408763     9.237175     9.097894         9.7
# 20                   16.366616    18.602945    20.718088        22.8
# 21                   16.366616    18.602945    20.718088        22.8
# 22                           0     0.000000     0.000000         0.0
# 23                   52.312694    80.536882    46.590103        45.9
# 24                   48.114343    76.823270    43.429216        40.9
# 25                           0     0.000000     0.000000         0.0
# 26                     4.19835     3.713612     3.160887         5.0
# 27                     4.19835     3.713612     3.160887         5.0
# 28                           0     0.000000     0.000000         0.0
# 29                   43.445484    31.043751    34.242765        38.4
# 30                   12.896126    10.423631    11.574620         9.0
# 31                    4.242073     4.135871     5.151810         8.0
# 32                    1.156242     0.900713     0.878146         1.8
# 33                   25.151043    15.583535    16.638189         NaN
# 34                           0     0.000000     0.000000         NaN

# %% [markdown]
# Convert values to USD

# %%
#REMOVE "JUNK" ROWS AND CONVERT TO CORRECT SCALE (MILLION/BILLIONS)
for key in master_table: #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
  scale = master_table[key].iloc[4,0] #get if values have scale of billions or millions
  
  # Drop rows 0 to 5, reformatting indexes and column headers
  master_table[key] = master_table[key].drop([0, 1, 2, 3, 4, 5]) 
  master_table[key] = master_table[key].reset_index(drop=True) 
  master_table[key].columns = master_table[key].iloc[0]
  master_table[key] = master_table[key][1:]
  master_table[key] = master_table[key].set_index(master_table[key].columns[0])
  master_table[key].columns = [int(float(col)) for col in master_table[key].columns]
  # master_table[key] = master_table[key].fillna(0)

  if scale == "Scale: Billions":
    master_table[key] = master_table[key]* (10 ** 9) #multiple every value in dataframe by 1e9 if scale is billion
  elif scale == "Scale: Millions":
    master_table[key] = master_table[key]* (10 ** 6) #multiple every value in dataframe by 1e9 if scale is billion


#FILTER OUT YEAR COLUMNS ACCOUNTING DOESNT ADD UP
#first level: make sure 'Taxes', 'Social Contributions', 'Grants, 'Other Revenue' Sums to 'Revenue'
#second level: make sure 'Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.' sum to 'Taxes'
first_level_ls = ['Taxes', 'Social contributions', 'Grants', 'Other revenue']
second_level_ls = ['Taxes on income, profits, & capital gains', 'Taxes on payroll & workforce', 'Taxes on property', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.']
                  
for key in master_table:
  years_accounting_error_ls = []
  years_available = master_table[key].columns
  for year in years_available:
    country_year_df = master_table[key][year]
    revenue = 0 
    taxes = 0
    for category in first_level_ls:
      if category in country_year_df.index:
        revenue += country_year_df[category]
      # else: 
      #   print(category)
    for category in second_level_ls:
      if category in country_year_df.index:
        taxes += country_year_df[category]
    # if round(taxes, 0) != round(country_year_df['Taxes'], 0) or round(revenue, 0) != round(country_year_df['Revenue'], 0):
      
    
    margin = 0.001
    lower_bound_taxes = country_year_df['Taxes'] - country_year_df['Taxes']*margin
    upper_bound_taxes = country_year_df['Taxes'] + country_year_df['Taxes']*margin
    lower_bound_revenue = country_year_df['Revenue'] - country_year_df['Revenue']*margin
    upper_bound_revenue = country_year_df['Revenue'] + country_year_df['Revenue']*margin

    if taxes < lower_bound_taxes or taxes > upper_bound_taxes or revenue < lower_bound_revenue or revenue > upper_bound_revenue:
    
      print(f"{round(taxes, 0)}, {round(country_year_df['Taxes'], 0)}, {round(revenue, 0)}, {round(country_year_df['Revenue'], 0)}")

      years_accounting_error_ls.append(year)
  
  print(key)
  print(years_accounting_error_ls)
  master_table[key].drop(columns=years_accounting_error_ls, inplace=True)
 




#FILTER OUT COUNTRIES WITH LESS THAN 7 YEARS OF DATA
less_than_seven_years_data_countries = [] #create list to store countries with less than 7 years of historial data
for key in master_table: #iterate through master_table
  num_columns = master_table[key].shape[1] #count the number of columns (each column represents a year)
  if num_columns < 7: #if less than 7 columns/year, add to list to delete
    less_than_seven_years_data_countries.append(key)

for country in less_than_seven_years_data_countries:
  del master_table[country] #delete countries with less than 7 years from data table



# #CONVERT LOCAL CURRENCY DENOMINATED VALUES TO USD
# error_countries = []
# for key in master_table:
#   #get annual 2010-2019 USD to domestic currency exchange rate using yfinance library
#   currency = country_currency_codes_table[key] #retrieve currency symbol from 'country_currency_codes_table'
#   symbol = f"{currency}=X"
#   try:
#     data = yf.download(symbol, start="2010-01-01", end="2020-01-01", interval="1mo") #download monthly USD-Currency dataset from 2010-2020
#     yearly_data_df = data['Close'].resample('YE').mean() #get the annual average exchange rate outputted as datafram
#     yearly_data_table = yearly_data_df.to_dict() # Convert the yearly_data to a hash table with the date as the key
#     year_to_exchange_rate_dict = {key.year: value for key, value in yearly_data_table.items()} # Convert the keys to only the year part
#     print(year_to_exchange_rate_dict)

#     #convert DataFrame values to USD
#     for year in master_table[key].columns: #loop through columns in dataframe
#       year_int = int(year)  # Convert year to integer to match the dictionary keys
#       master_table[key][year] = master_table[key][year] / year_to_exchange_rate_dict[year_int] #divide each column's values by that year's exchange rate

#   except Exception as e: #if errored out
#     print(f"Could not fetch rate for {key} ({currency}): {e}")
#     error_countries.append(key) #add country to error list
#     pass
    
# for country in error_countries:
#   del master_table[country] #delete countries where currency conversion failed
 
# master_table["Central African Republic"]
# Out:
# Benin
# []
# Senegal
# []
# Côte d'Ivoire
# []
# Burkina Faso
# []
# Central African Republic
# []
# Somalia
# []
# Tanzania
# []
# Democratic Republic of the Congo
# []
# Rwanda
# []
# Republic of Congo
# []
# Sudan
# []
# 450175108347.0, 498921783147.0, 604225591780.0, 604225591780.0
# Togo
# [2016]
# Mali
# []
# Malawi
# []
# Sao Tomee and Principe
# []
# Mozambique
# []
# Sierra Leone
# []
# Guinea-Bissau
# []
# Burundi
# []
# Liberia
# []
# Cameroon
# []
# Madagascar
# []

# %% [markdown]
# Convert to Percent

# %%
for key in master_table: #iterate through master_table
  total_taxes = master_table[key].loc['Taxes']
  master_table[key] = master_table[key] / total_taxes * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places

# master_table["Central African Republic"]

# %% [markdown]
# Calculate Yearly Averages

# %%
data_by_year_table = {
  2010: [],
  2011: [],
  2012: [],
  2013: [],
  2014: [],
  2015: [],
  2016: [],
  2017: [],
  2018: [],
  2019: [],
} #make table that stores data by year

# master_averages_ls = [] #make master averages list as place to store averages

for key in master_table:
  years_available = master_table[key].columns
  for year in data_by_year_table:
    if year in years_available:
      data_by_year_table[year].append(master_table[key][year])

yearly_averages_ls = [] #make a list of the yearly averages
for year in data_by_year_table:
  merged_year_df = pd.concat(data_by_year_table[year], axis=1, join='outer')
  year_average_df = merged_year_df.mean(axis=1) #get the average of all the countries' averages
  yearly_averages_ls.append(year_average_df)

 
# #Get average over decade
# #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
# for key in master_table:
#   per_category_average = master_table[key].mean(axis=1) #get the average of each category (ignoring np.NaN values) into a list
#   # per_category_average.drop('To other government units', inplace=True) #drop 'To other government units' since there's two rows named that and will error
#   master_averages_ls.append(per_category_average) #add each country average to to the master averages list



# merged_averages_df = pd.concat(master_averages_ls, axis=1, join='outer')
# average__of_averages_df = merged_averages_df.mean(axis=1) #get the average of all the countries' averages
# average__of_averages_df

for i in range(len(yearly_averages_ls)):
  print(f"YEAR: {2010+i}")
  print(yearly_averages_ls[i])
# Out:
# YEAR: 2010
# nan
# Revenue                                                    215.069392
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   28.803666
# Taxes on income, profits, & capital gains: individuals      15.671895
# Taxes on income, profits, & capital gains: corporations     13.856587
# Taxes on income, profits, & capital gains: other             1.170054
# Taxes on payroll & workforce                                 0.269414
# Taxes on property                                            0.353129
# Taxes on goods & services                                   45.633966
# General taxes on goods & services                           32.458166
# Excise taxes                                                10.325278
# Taxes on int trade & transactions                           21.030405
# Other taxes n.e.c.                                           3.909421
# Social contributions                                         0.777482
# Social security contributions                                     0.0
# Other social contributions                                   0.638306
# Grants                                                      71.565836
# Grants from foreign govts                                    51.14379
# Grants from int orgs                                        31.716179
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                               42.697295
# Property income                                              7.069573
# Sales of goods & services                                   26.698882
# Fines, penalties & forfeits                                  1.603024
# Other transfers                                              6.184021
# NI & SGS: premiums, fees & claims                                 0.0
# dtype: object
# YEAR: 2011
# nan
# Revenue                                                    189.101864
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   29.764587
# Taxes on income, profits, & capital gains: individuals      17.129014
# Taxes on income, profits, & capital gains: corporations     13.469584
# Taxes on income, profits, & capital gains: other             1.190449
# Taxes on payroll & workforce                                 0.200117
# Taxes on property                                            0.350865
# Taxes on goods & services                                   46.116237
# General taxes on goods & services                           32.478514
# Excise taxes                                                 9.874727
# Taxes on int trade & transactions                           19.200761
# Other taxes n.e.c.                                           4.367366
# Social contributions                                         0.800447
# Social security contributions                                     0.0
# Other social contributions                                   0.658313
# Grants                                                      44.018153
# Grants from foreign govts                                   23.864874
# Grants from int orgs                                        27.634858
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                               44.239976
# Property income                                             29.633264
# Sales of goods & services                                    3.263609
# Fines, penalties & forfeits                                  0.080954
# Other transfers                                              2.918921
# NI & SGS: premiums, fees & claims                                 0.0
# dtype: object
# YEAR: 2012
# nan
# Revenue                                                    168.862513
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   30.821254
# Taxes on income, profits, & capital gains: individuals      16.894766
# Taxes on income, profits, & capital gains: corporations     15.217541
# Taxes on income, profits, & capital gains: other             1.152464
# Taxes on payroll & workforce                                 0.330716
# Taxes on property                                             0.32485
# Taxes on goods & services                                   45.684502
# General taxes on goods & services                           32.762353
# Excise taxes                                                 9.140419
# Taxes on int trade & transactions                            19.41381
# Other taxes n.e.c.                                           3.424625
# Social contributions                                         0.508118
# Social security contributions                                     0.0
# Other social contributions                                   0.380606
# Grants                                                      32.971879
# Grants from foreign govts                                   11.222324
# Grants from int orgs                                         22.94015
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                               35.318921
# Property income                                             31.289282
# Sales of goods & services                                    2.554244
# Fines, penalties & forfeits                                  0.194038
# Other transfers                                              2.568433
# NI & SGS: premiums, fees & claims                                 0.0
# dtype: object
# YEAR: 2013
# nan
# Revenue                                                    169.159658
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   31.527661
# Taxes on income, profits, & capital gains: individuals      16.627482
# Taxes on income, profits, & capital gains: corporations     17.001116
# Taxes on income, profits, & capital gains: other             1.281706
# Taxes on payroll & workforce                                 0.234035
# Taxes on property                                            0.292735
# Taxes on goods & services                                   45.223201
# General taxes on goods & services                           32.488225
# Excise taxes                                                 9.417439
# Taxes on int trade & transactions                           20.024426
# Other taxes n.e.c.                                           2.697937
# Social contributions                                         0.647323
# Social security contributions                                     0.0
# Other social contributions                                   0.551692
# Grants                                                       34.43652
# Grants from foreign govts                                    8.717608
# Grants from int orgs                                        30.614676
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                                34.11897
# Property income                                             28.543786
# Sales of goods & services                                    2.803083
# Fines, penalties & forfeits                                  0.208965
# Other transfers                                              2.565605
# NI & SGS: premiums, fees & claims                            0.023347
# dtype: object
# YEAR: 2014
# nan
# Revenue                                                    173.199843
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   32.051556
# Taxes on income, profits, & capital gains: individuals      16.614528
# Taxes on income, profits, & capital gains: corporations     16.181282
# Taxes on income, profits, & capital gains: other             1.809473
# Taxes on payroll & workforce                                 0.289171
# Taxes on property                                            0.434366
# Taxes on goods & services                                   46.544326
# General taxes on goods & services                            31.28295
# Excise taxes                                                11.241916
# Taxes on int trade & transactions                           18.672881
# Other taxes n.e.c.                                            2.00743
# Social contributions                                         0.536541
# Social security contributions                                     0.0
# Other social contributions                                   0.439781
# Grants                                                      46.513852
# Grants from foreign govts                                   21.445007
# Grants from int orgs                                        31.298595
# Grants from other gen govt                                   0.537525
# Grants from other gen govt: current                          0.483835
# Grants from other gen govt: capital                           0.05369
# Other revenue                                               26.179501
# Property income                                             20.657925
# Sales of goods & services                                    3.904903
# Fines, penalties & forfeits                                  0.524924
# Other transfers                                              1.228097
# NI & SGS: premiums, fees & claims                            0.004087
# dtype: object
# YEAR: 2015
# nan
# Revenue                                                    141.647323
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   32.659507
# Taxes on income, profits, & capital gains: individuals      18.368109
# Taxes on income, profits, & capital gains: corporations     15.912523
# Taxes on income, profits, & capital gains: other             1.347681
# Taxes on payroll & workforce                                 0.330507
# Taxes on property                                             0.59001
# Taxes on goods & services                                   46.534824
# General taxes on goods & services                           32.284512
# Excise taxes                                                10.603729
# Taxes on int trade & transactions                           18.190337
# Other taxes n.e.c.                                            1.69456
# Social contributions                                          0.54926
# Social security contributions                                     0.0
# Other social contributions                                   0.417514
# Grants                                                      25.889281
# Grants from foreign govts                                    7.283533
# Grants from int orgs                                        20.421182
# Grants from other gen govt                                   0.270135
# Grants from other gen govt: current                          0.270135
# Grants from other gen govt: capital                               0.0
# Other revenue                                               15.239537
# Property income                                              9.119078
# Sales of goods & services                                     4.30228
# Fines, penalties & forfeits                                  0.513344
# Other transfers                                              1.300781
# NI & SGS: premiums, fees & claims                            0.045266
# dtype: object
# YEAR: 2016
# nan
# Revenue                                                    141.564034
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   33.732146
# Taxes on income, profits, & capital gains: individuals      21.049189
# Taxes on income, profits, & capital gains: corporations     15.248484
# Taxes on income, profits, & capital gains: other             0.671707
# Taxes on payroll & workforce                                 0.312483
# Taxes on property                                            0.594458
# Taxes on goods & services                                   47.483522
# General taxes on goods & services                           31.297787
# Excise taxes                                                12.191379
# Taxes on int trade & transactions                           16.011447
# Other taxes n.e.c.                                           1.865943
# Social contributions                                         0.504428
# Social security contributions                                0.024747
# Other social contributions                                   0.479682
# Grants                                                      28.105409
# Grants from foreign govts                                    8.063032
# Grants from int orgs                                        23.144723
# Grants from other gen govt                                    0.07444
# Grants from other gen govt: current                          0.000488
# Grants from other gen govt: capital                          0.073952
# Other revenue                                               12.983868
# Property income                                               8.10683
# Sales of goods & services                                    3.489962
# Fines, penalties & forfeits                                  0.418273
# Other transfers                                              0.881559
# NI & SGS: premiums, fees & claims                              0.0851
# dtype: object
# YEAR: 2017
# nan
# Revenue                                                    140.323477
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   34.244257
# Taxes on income, profits, & capital gains: individuals      17.705364
# Taxes on income, profits, & capital gains: corporations     16.242692
# Taxes on income, profits, & capital gains: other             0.955402
# Taxes on payroll & workforce                                 0.538622
# Taxes on property                                            0.604641
# Taxes on goods & services                                   46.544435
# General taxes on goods & services                           33.347912
# Excise taxes                                                11.379199
# Taxes on int trade & transactions                           16.016147
# Other taxes n.e.c.                                           2.051899
# Social contributions                                         0.550786
# Social security contributions                                0.015858
# Other social contributions                                   0.534928
# Grants                                                      25.281026
# Grants from foreign govts                                    6.121216
# Grants from int orgs                                         20.36754
# Grants from other gen govt                                   0.100433
# Grants from other gen govt: current                          0.100433
# Grants from other gen govt: capital                               0.0
# Other revenue                                               14.524065
# Property income                                              8.766092
# Sales of goods & services                                     5.04707
# Fines, penalties & forfeits                                  0.443291
# Other transfers                                              0.462072
# NI & SGS: premiums, fees & claims                            0.579003
# dtype: object
# YEAR: 2018
# nan
# Revenue                                                    149.771127
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                   35.443594
# Taxes on income, profits, & capital gains: individuals      18.525305
# Taxes on income, profits, & capital gains: corporations     16.566303
# Taxes on income, profits, & capital gains: other             1.105339
# Taxes on payroll & workforce                                 0.556408
# Taxes on property                                            0.668705
# Taxes on goods & services                                   45.346745
# General taxes on goods & services                            32.87768
# Excise taxes                                                10.628989
# Taxes on int trade & transactions                           16.408969
# Other taxes n.e.c.                                           1.575579
# Social contributions                                         0.829637
# Social security contributions                                0.002123
# Other social contributions                                   0.827514
# Grants                                                      22.425848
# Grants from foreign govts                                    5.761578
# Grants from int orgs                                        16.664271
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                               26.567505
# Property income                                             22.260777
# Sales of goods & services                                    3.936448
# Fines, penalties & forfeits                                  0.360026
# Other transfers                                               1.35342
# NI & SGS: premiums, fees & claims                            0.277748
# dtype: object
# YEAR: 2019
# nan
# Revenue                                                    150.320366
# Taxes                                                           100.0
# Taxes on income, profits, & capital gains                     34.2864
# Taxes on income, profits, & capital gains: individuals      15.372066
# Taxes on income, profits, & capital gains: corporations     18.324059
# Taxes on income, profits, & capital gains: other             1.182953
# Taxes on payroll & workforce                                 0.548473
# Taxes on property                                            0.639873
# Taxes on goods & services                                   48.342298
# General taxes on goods & services                            34.71113
# Excise taxes                                                10.939843
# Taxes on int trade & transactions                           14.858641
# Other taxes n.e.c.                                           1.324297
# Social contributions                                         0.586094
# Social security contributions                                0.008249
# Other social contributions                                   0.577845
# Grants                                                      23.324546
# Grants from foreign govts                                    3.488458
# Grants from int orgs                                        20.881529
# Grants from other gen govt                                        0.0
# Grants from other gen govt: current                               0.0
# Grants from other gen govt: capital                               0.0
# Other revenue                                                26.45159
# Property income                                             21.840398
# Sales of goods & services                                    3.827408
# Fines, penalties & forfeits                                  0.549425
# Other transfers                                              0.218691
# NI & SGS: premiums, fees & claims                            0.015669
# dtype: object

# %% [markdown]
# Calculate Percentages

# %%
# yearly_averages_percentage_ls = []
# for year_average_df in yearly_averages_ls:
#   total_taxes = year_average_df['Taxes']
#   year_average_percentage_df = year_average_df / total_taxes * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places
#   yearly_averages_percentage_ls.append(year_average_percentage_df)

# for i in range(len(yearly_averages_percentage_ls)):
#   print(f"YEAR: {2010+i}")
#   print(yearly_averages_percentage_ls[i])

# %% [markdown]
# Calculate Average Across Period

# %%
merged_percentages_df = pd.concat(yearly_averages_ls, axis=1, join='outer')
average_df = merged_percentages_df.mean(axis=1)
rounded_average_df = average_df.apply(lambda x: round(x, 2))

rounded_average_df = rounded_average_df.to_frame()
rounded_average_df
# Out:
#                                                          0
# nan
# Revenue                                             163.90
# Taxes                                               100.00
# Taxes on income, profits, & capital gains            32.33
# Taxes on income, profits, & capital gains: indi...   17.40
# Taxes on income, profits, & capital gains: corp...   15.80
# Taxes on income, profits, & capital gains: other      1.19
# Taxes on payroll & workforce                          0.36
# Taxes on property                                     0.49
# Taxes on goods & services                            46.35
# General taxes on goods & services                    32.60
# Excise taxes                                         10.57
# Taxes on int trade & transactions                    17.98
# Other taxes n.e.c.                                    2.49
# Social contributions                                  0.63
# Social security contributions                         0.01
# Other social contributions                            0.55
# Grants                                               35.45
# Grants from foreign govts                            14.71
# Grants from int orgs                                 24.57
# Grants from other gen govt                            0.10
# Grants from other gen govt: current                   0.09
# Grants from other gen govt: capital                   0.01
# Other revenue                                        27.83
# Property income                                      18.73
# Sales of goods & services                             5.98
# Fines, penalties & forfeits                           0.49
# Other transfers                                       1.97
# NI & SGS: premiums, fees & claims                     0.10

# %%
#check
first_level = 0
for category in first_level_ls:
  first_level += average_df[category]
print(first_level)

second_level = 0
for category in second_level_ls:
  second_level += average_df[category]
print(second_level)
# Out:
# 163.9143694096308
# 99.9999139852881

# %%
rounded_by_year_average_df = merged_percentages_df.round(2)
rounded_by_year_average_df
# Out:
#                                                              0           1  \
# nan
# Revenue                                             215.069392  189.101864
# Taxes                                                    100.0       100.0
# Taxes on income, profits, & capital gains            28.803666   29.764587
# Taxes on income, profits, & capital gains: indi...   15.671895   17.129014
# Taxes on income, profits, & capital gains: corp...   13.856587   13.469584
# Taxes on income, profits, & capital gains: other      1.170054    1.190449
# Taxes on payroll & workforce                          0.269414    0.200117
# Taxes on property                                     0.353129    0.350865
# Taxes on goods & services                            45.633966   46.116237
# General taxes on goods & services                    32.458166   32.478514
# Excise taxes                                         10.325278    9.874727
# Taxes on int trade & transactions                    21.030405   19.200761
# Other taxes n.e.c.                                    3.909421    4.367366
# Social contributions                                  0.777482    0.800447
# Social security contributions                              0.0         0.0
# Other social contributions                            0.638306    0.658313
# Grants                                               71.565836   44.018153
# Grants from foreign govts                             51.14379   23.864874
# Grants from int orgs                                 31.716179   27.634858
# Grants from other gen govt                                 0.0         0.0
# Grants from other gen govt: current                        0.0         0.0
# Grants from other gen govt: capital                        0.0         0.0
# Other revenue                                        42.697295   44.239976
# Property income                                       7.069573   29.633264
# Sales of goods & services                            26.698882    3.263609
# Fines, penalties & forfeits                           1.603024    0.080954
# Other transfers                                       6.184021    2.918921
# NI & SGS: premiums, fees & claims                          0.0         0.0
#
#                                                              2           3  \
# nan
# Revenue                                             168.862513  169.159658
# Taxes                                                    100.0       100.0
# Taxes on income, profits, & capital gains            30.821254   31.527661
# Taxes on income, profits, & capital gains: indi...   16.894766   16.627482
# Taxes on income, profits, & capital gains: corp...   15.217541   17.001116
# Taxes on income, profits, & capital gains: other      1.152464    1.281706
# Taxes on payroll & workforce                          0.330716    0.234035
# Taxes on property                                      0.32485    0.292735
# Taxes on goods & services                            45.684502   45.223201
# General taxes on goods & services                    32.762353   32.488225
# Excise taxes                                          9.140419    9.417439
# Taxes on int trade & transactions                     19.41381   20.024426
# Other taxes n.e.c.                                    3.424625    2.697937
# Social contributions                                  0.508118    0.647323
# Social security contributions                              0.0         0.0
# Other social contributions                            0.380606    0.551692
# Grants                                               32.971879    34.43652
# Grants from foreign govts                            11.222324    8.717608
# Grants from int orgs                                  22.94015   30.614676
# Grants from other gen govt                                 0.0         0.0
# Grants from other gen govt: current                        0.0         0.0
# Grants from other gen govt: capital                        0.0         0.0
# Other revenue                                        35.318921    34.11897
# Property income                                      31.289282   28.543786
# Sales of goods & services                             2.554244    2.803083
# Fines, penalties & forfeits                           0.194038    0.208965
# Other transfers                                       2.568433    2.565605
# NI & SGS: premiums, fees & claims                          0.0    0.023347
#
#                                                              4           5  \
# nan
# Revenue                                             173.199843  141.647323
# Taxes                                                    100.0       100.0
# Taxes on income, profits, & capital gains            32.051556   32.659507
# Taxes on income, profits, & capital gains: indi...   16.614528   18.368109
# Taxes on income, profits, & capital gains: corp...   16.181282   15.912523
# Taxes on income, profits, & capital gains: other      1.809473    1.347681
# Taxes on payroll & workforce                          0.289171    0.330507
# Taxes on property                                     0.434366     0.59001
# Taxes on goods & services                            46.544326   46.534824
# General taxes on goods & services                     31.28295   32.284512
# Excise taxes                                         11.241916   10.603729
# Taxes on int trade & transactions                    18.672881   18.190337
# Other taxes n.e.c.                                     2.00743     1.69456
# Social contributions                                  0.536541     0.54926
# Social security contributions                              0.0         0.0
# Other social contributions                            0.439781    0.417514
# Grants                                               46.513852   25.889281
# Grants from foreign govts                            21.445007    7.283533
# Grants from int orgs                                 31.298595   20.421182
# Grants from other gen govt                            0.537525    0.270135
# Grants from other gen govt: current                   0.483835    0.270135
# Grants from other gen govt: capital                    0.05369         0.0
# Other revenue                                        26.179501   15.239537
# Property income                                      20.657925    9.119078
# Sales of goods & services                             3.904903     4.30228
# Fines, penalties & forfeits                           0.524924    0.513344
# Other transfers                                       1.228097    1.300781
# NI & SGS: premiums, fees & claims                     0.004087    0.045266
#
#                                                              6           7  \
# nan
# Revenue                                             141.564034  140.323477
# Taxes                                                    100.0       100.0
# Taxes on income, profits, & capital gains            33.732146   34.244257
# Taxes on income, profits, & capital gains: indi...   21.049189   17.705364
# Taxes on income, profits, & capital gains: corp...   15.248484   16.242692
# Taxes on income, profits, & capital gains: other      0.671707    0.955402
# Taxes on payroll & workforce                          0.312483    0.538622
# Taxes on property                                     0.594458    0.604641
# Taxes on goods & services                            47.483522   46.544435
# General taxes on goods & services                    31.297787   33.347912
# Excise taxes                                         12.191379   11.379199
# Taxes on int trade & transactions                    16.011447   16.016147
# Other taxes n.e.c.                                    1.865943    2.051899
# Social contributions                                  0.504428    0.550786
# Social security contributions                         0.024747    0.015858
# Other social contributions                            0.479682    0.534928
# Grants                                               28.105409   25.281026
# Grants from foreign govts                             8.063032    6.121216
# Grants from int orgs                                 23.144723    20.36754
# Grants from other gen govt                             0.07444    0.100433
# Grants from other gen govt: current                   0.000488    0.100433
# Grants from other gen govt: capital                   0.073952         0.0
# Other revenue                                        12.983868   14.524065
# Property income                                        8.10683    8.766092
# Sales of goods & services                             3.489962     5.04707
# Fines, penalties & forfeits                           0.418273    0.443291
# Other transfers                                       0.881559    0.462072
# NI & SGS: premiums, fees & claims                       0.0851    0.579003
#
#                                                              8           9
# nan
# Revenue                                             149.771127  150.320366
# Taxes                                                    100.0       100.0
# Taxes on income, profits, & capital gains            35.443594     34.2864
# Taxes on income, profits, & capital gains: indi...   18.525305   15.372066
# Taxes on income, profits, & capital gains: corp...   16.566303   18.324059
# Taxes on income, profits, & capital gains: other      1.105339    1.182953
# Taxes on payroll & workforce                          0.556408    0.548473
# Taxes on property                                     0.668705    0.639873
# Taxes on goods & services                            45.346745   48.342298
# General taxes on goods & services                     32.87768    34.71113
# Excise taxes                                         10.628989   10.939843
# Taxes on int trade & transactions                    16.408969   14.858641
# Other taxes n.e.c.                                    1.575579    1.324297
# Social contributions                                  0.829637    0.586094
# Social security contributions                         0.002123    0.008249
# Other social contributions                            0.827514    0.577845
# Grants                                               22.425848   23.324546
# Grants from foreign govts                             5.761578    3.488458
# Grants from int orgs                                 16.664271   20.881529
# Grants from other gen govt                                 0.0         0.0
# Grants from other gen govt: current                        0.0         0.0
# Grants from other gen govt: capital                        0.0         0.0
# Other revenue                                        26.567505    26.45159
# Property income                                      22.260777   21.840398
# Sales of goods & services                             3.936448    3.827408
# Fines, penalties & forfeits                           0.360026    0.549425
# Other transfers                                        1.35342    0.218691
# NI & SGS: premiums, fees & claims                     0.277748    0.015669

# %% [markdown]
# Graph over time

# %%
rounded_by_year_average_df.columns = [str(int(col) + 2010) for col in rounded_by_year_average_df.columns]

def graph(rows_to_plot):
    # sns.set(style="whitegrid")

    # Plotting
    plt.figure(figsize=(10, 6))
    for row in rows_to_plot:
        sns.lineplot(x=rounded_by_year_average_df.columns, y=rounded_by_year_average_df.loc[row], marker='o', label=row)

    # Add labels and title
    plt.xlabel('Year', fontsize=12)
    plt.ylabel('Percentage of Tax Revenue', fontsize=12)
    # plt.title('Percentage of Tax Revenue Over Time')

    # Customize the legend
    plt.legend(title='Category', title_fontsize='12', fontsize='10', loc='upper right')

    # Customize the ticks and grid
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True, linestyle='--', linewidth=0.5)

    # Adjust y-axis limits to be 120% of the original range
    y_min, y_max = plt.ylim()
    y_range = y_max - y_min
    plt.ylim(y_min, y_max + 0.25 * y_range)

    # Show the plot
    plt.tight_layout()
    plt.show()

# %%
graph(['Revenue', 'Grants', 'Other revenue'])
graph(['Taxes on income, profits, & capital gains', 'Taxes on goods & services', 'Taxes on int trade & transactions', 'Other taxes n.e.c.'])
graph(['Property income', 'Sales of goods & services', 'Other transfers'])
graph(['Taxes on income, profits, & capital gains: individuals', 'Taxes on income, profits, & capital gains: corporations', 'General taxes on goods & services', 'Excise taxes'])
