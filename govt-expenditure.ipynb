# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import yfinance as yf

# %% [markdown]
# Currency Codes

# %%
country_currency_codes_table = {
    'Burundi': 'BIF',
    'Benin': 'XOF',
    'Burkina Faso': 'XOF',
    'Central African Republic': 'XAF',
    "Côte d'Ivoire": 'XOF',
    'Cameroon': 'XAF',
    'Democratic Republic of the Congo': 'CDF',
    'Republic of Congo': 'XAF',
    'Comoros': 'KMF',
    'Eritrea': 'ERN',
    'Ethiopia': 'ETB',
    'Ghana': 'GHS',
    'Guinea': 'GNF',
    'The Gambia': 'GMD',
    'Guinea-Bissau': 'XOF',
    'Liberia': 'LRD',
    'Madagascar': 'MGA',
    'Mali': 'XOF',
    'Mozambique': 'MZN',
    'Mauritania': 'MRU',
    'Malawi': 'MWK',
    'Niger': 'XOF',
    'Rwanda': 'RWF',
    'Sudan': 'SDG',
    'Senegal': 'XOF',
    'Sierra Leone': 'SLL',
    'Somalia': 'SOS',
    'Sao Tomee and Principe': 'STN',
    'Chad': 'XAF',
    'Togo': 'XOF',
    'Tanzania': 'TZS',
    'Uganda': 'UGX',
    'Zambia': 'ZMW'
}

# %% [markdown]
# Read Data

# %%
#read in stata dataset as dataframe "country_code_df"
country_code_df = pd.read_stata("codesffactors_Mar23_2019.dta") 
country_code_df.replace('--', np.nan, inplace=True) #replace all entries that are '--' with NaN data value

country_code_df.head()
# Out:
#    countryname       wbctry wbcode                   wbregion  \
# 0        Aruba        Aruba    ABW  Latin America & Caribbean
# 1  Afghanistan  Afghanistan    AFG                 South Asia
# 2       Angola       Angola    AGO         Sub-Saharan Africa
# 3     Anguilla          NaN    AIA  Latin America & Caribbean
# 4      Albania      Albania    ALB      Europe & Central Asia
#
#           wbigroup2017 wblcat2017  hipc  emu  cemac  waemu  imfcode  \
# 0          High income        NaN     0    0      0      0      NaN
# 1           Low income        IDA     1    0      0      0    512.0
# 2  Lower middle income       IBRD     0    0      0      0    614.0
# 3                  NaN        NaN     0    0      0      0    312.0
# 4  Upper middle income       IBRD     0    0      0      0    914.0
#
#    imfweocode imfweoiso   imfweoctry region
# 0       314.0       ABW        Aruba    LAC
# 1       512.0       AFG  Afghanistan    SAS
# 2       614.0       AGO       Angola    SSA
# 3         NaN       NaN          NaN    LAC
# 4       914.0       ALB      Albania    ECA

# %%
region_classification_ls = country_code_df['wbregion'].unique() #get a list of region classifications
income_classification_ls = country_code_df['wbigroup2017'].unique() #get a list of income classifications
income_classification_ls = [x for x in income_classification_ls if not pd.isna(x)] # remove '--' from income_classification_ls

print(f"The region classifications are: {', '.join(country for country in region_classification_ls)}")
print(f"The income classifications are: {', '.join(country for country in income_classification_ls)}")
# Out:
# The region classifications are: Latin America & Caribbean, South Asia, Sub-Saharan Africa, Europe & Central Asia, Middle East & North Africa, East Asia & Pacific, North America
# The income classifications are: High income, Low income, Lower middle income, Upper middle income

# %%
ssa_hipc_countries = country_code_df[(country_code_df['hipc'] == 1) & (country_code_df['wbregion'] == 'Sub-Saharan Africa')]
ssa_hipc_countries_ls = ssa_hipc_countries['imfweoctry'].to_list()

ssa_hipc_countries_ls
# Out:
# ['Burundi',
#  'Benin',
#  'Burkina Faso',
#  'Central African Republic',
#  "Côte d'Ivoire",
#  'Cameroon',
#  'Democratic Republic of the Congo',
#  'Republic of Congo',
#  'Comoros',
#  'Eritrea',
#  'Ethiopia',
#  'Ghana',
#  'Guinea',
#  'The Gambia',
#  'Guinea-Bissau',
#  'Liberia',
#  'Madagascar',
#  'Mali',
#  'Mozambique',
#  'Mauritania',
#  'Malawi',
#  'Niger',
#  'Rwanda',
#  'Sudan',
#  'Senegal',
#  'Sierra Leone',
#  'Somalia',
#  'São Tomé and Príncipe',
#  'Chad',
#  'Togo',
#  'Tanzania',
#  'Uganda',
#  'Zambia']

# %% [markdown]
# Read in IMF's Government Finance Statistics

# %%
master_table = {}
folder_path = "expenditure-data"

# Loop that goes through all files 'file_name' in the folder 'folder_path'
for file_name in os.listdir(folder_path):
  if file_name.endswith('.xlsx') and not file_name.startswith('~$'): #check to see if is spreadsheet .xlsx format
    raw_df = pd.read_excel(folder_path+ "/" + file_name) #read in .xlsx as dataframe
    master_table[file_name[:-5]] = raw_df #store dataframe as an entry in the master_table hash table

# master_table["Central African Republic"]
master_table["Benin"]
# Out:
#                                   Unnamed: 0   Unnamed: 1   Unnamed: 2  \
# 0                 Detailed Expense Breakdown          NaN          NaN
# 1                             Country: Benin          NaN          NaN
# 2       Sector: Budgetary central government          NaN          NaN
# 3                    Unit: Domestic currency          NaN          NaN
# 4                            Scale: Billions          NaN          NaN
# 5                                        NaN          NaN          NaN
# 6                                        NaN  2010.000000  2011.000000
# 7                                    Expense   459.011490   457.660567
# 8                  Compensation of employees   235.600075   242.117067
# 9                         Wages and salaries   235.600075   242.117067
# 10           Employers' social contributions     0.000000     0.000000
# 11                 Use of goods and services    71.197566    68.703453
# 12                          Interest expense    17.734935    14.973871
# 13                           To nonresidents     8.106149     7.831106
# 14  To residents other than government units     9.628786     7.142766
# 15                 To other government units     0.000000     0.000000
# 16                                 Subsidies    20.525565    33.553247
# 17                    To public corporations    20.525565    33.553247
# 18                    To private enterprises     0.000000     0.000000
# 19                          To other sectors     0.000000     0.000000
# 20                                    Grants   101.794146    86.975987
# 21                    To foreign governments     0.000000     0.000000
# 22            To international organizations     6.166268     5.812560
# 23                 To other government units    95.627878    81.163427
# 24                                   Current    95.627878    81.163427
# 25                                   Capital     0.000000     0.000000
# 26                           Social benefits     0.775000     0.987000
# 27                  Social security benefits     0.000000     0.000000
# 28                Social assistance benefits     0.000000     0.000000
# 29        Employment-related social benefits     0.775000     0.987000
# 30                             Other expense    11.384204    10.349942
# 31      Property expense other than interest     0.000000     0.000000
# 32                Expense on other transfers    11.384204    10.349942
#
#      Unnamed: 3  Unnamed: 4
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           NaN         NaN
# 6   2012.000000      2013.0
# 7    534.669798       577.5
# 8    267.900275       296.2
# 9    267.900275       296.2
# 10     0.000000         0.0
# 11    94.436470       106.1
# 12    23.143175        19.9
# 13    10.604660         9.8
# 14    12.538515        10.1
# 15     0.000000         0.0
# 16    55.091217        49.5
# 17    55.091217        49.5
# 18     0.000000         0.0
# 19     0.000000         0.0
# 20    80.503177        91.1
# 21     0.000000         0.0
# 22     6.894267         8.2
# 23    73.608910        82.9
# 24    73.608910        82.9
# 25     0.000000         0.0
# 26     0.783000         0.9
# 27     0.000000         0.0
# 28     0.000000         0.0
# 29     0.783000         0.9
# 30    12.812484        13.7
# 31     0.000000         0.0
# 32    12.812484        13.7

# %% [markdown]
# Convert values to USD

# %%
#REMOVE "JUNK" ROWS AND CONVERT TO CORRECT SCALE (MILLION/BILLIONS)
for key in master_table: #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
  scale = master_table[key].iloc[4,0] #get if values have scale of billions or millions
  
  # Drop rows 0 to 5, reformatting indexes and column headers
  master_table[key] = master_table[key].drop([0, 1, 2, 3, 4, 5]) 
  master_table[key] = master_table[key].reset_index(drop=True) 
  master_table[key].columns = master_table[key].iloc[0]
  master_table[key] = master_table[key][1:]
  master_table[key] = master_table[key].set_index(master_table[key].columns[0])
  master_table[key].columns = [int(float(col)) for col in master_table[key].columns]
  # master_table[key] = master_table[key].fillna(0)

  if scale == "Scale: Billions":
    master_table[key] = master_table[key]* (10 ** 9) #multiple every value in dataframe by 1e9 if scale is billion
  elif scale == "Scale: Millions":
    master_table[key] = master_table[key]* (10 ** 6) #multiple every value in dataframe by 1e9 if scale is billion


#FILTER OUT COUNTRIES WITH LESS THAN 7 YEARS OF DATA
less_than_seven_years_data_countries = [] #create list to store countries with less than 7 years of historial data
for key in master_table: #iterate through master_table
  num_columns = master_table[key].shape[1] #count the number of columns (each column represents a year)
  if num_columns < 7: #if less than 7 columns/year, add to list to delete
    less_than_seven_years_data_countries.append(key)

for country in less_than_seven_years_data_countries:
  del master_table[country] #delete countries with less than 7 years from data table



#CONVERT LOCAL CURRENCY DENOMINATED VALUES TO USD
error_countries = []
for key in master_table:
  #get annual 2010-2019 USD to domestic currency exchange rate using yfinance library
  currency = country_currency_codes_table[key] #retrieve currency symbol from 'country_currency_codes_table'
  symbol = f"{currency}=X"
  try:
    data = yf.download(symbol, start="2010-01-01", end="2020-01-01", interval="1mo") #download monthly USD-Currency dataset from 2010-2020
    yearly_data_df = data['Close'].resample('YE').mean() #get the annual average exchange rate outputted as datafram
    yearly_data_table = yearly_data_df.to_dict() # Convert the yearly_data to a hash table with the date as the key
    year_to_exchange_rate_dict = {key.year: value for key, value in yearly_data_table.items()} # Convert the keys to only the year part
    print(year_to_exchange_rate_dict)

    #convert DataFrame values to USD
    for year in master_table[key].columns: #loop through columns in dataframe
      year_int = int(year)  # Convert year to integer to match the dictionary keys
      master_table[key][year] = master_table[key][year] / year_to_exchange_rate_dict[year_int] #divide each column's values by that year's exchange rate

  except Exception as e: #if errored out
    print(f"Could not fetch rate for {key} ({currency}): {e}")
    error_countries.append(key) #add country to error list
    pass
    
for country in error_countries:
  del master_table[country] #delete countries where currency conversion failed
 
master_table["Central African Republic"]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Employers' social contributions           3.742620e+06  4.315085e+06
# Use of goods and services                 2.056766e+08  1.637742e+08
# Interest expense                          1.950690e+07  1.516111e+07
# To nonresidents                           5.700481e+06  5.881727e+06
# To residents other than government units  1.380642e+07  9.279386e+06
# To other government units                 0.000000e+00  0.000000e+00
# Subsidies                                          NaN           NaN
# To public corporations                             NaN           NaN
# To private enterprises                    0.000000e+00  0.000000e+00
# To other sectors                                   NaN           NaN
# Grants                                    0.000000e+00  0.000000e+00
# To foreign governments                    0.000000e+00  0.000000e+00
# To international organizations            0.000000e+00  0.000000e+00
# To other government units                 0.000000e+00  0.000000e+00
# Current                                   0.000000e+00  0.000000e+00
# Capital                                   0.000000e+00  0.000000e+00
# Social benefits                           0.000000e+00  0.000000e+00
# Social security benefits                  0.000000e+00  0.000000e+00
# Social assistance benefits                0.000000e+00  0.000000e+00
# Employment-related social benefits        0.000000e+00  0.000000e+00
# Other expense                             8.203459e+05  6.513373e+06
# Property expense other than interest      0.000000e+00  0.000000e+00
# Expense on other transfers                8.203459e+05  6.513373e+06
#
#                                                   2012          2014  \
# nan
# Expense                                   2.093398e+08  1.555653e+08
# Compensation of employees                 1.022113e+08  1.081127e+08
# Wages and salaries                        9.782711e+07  1.034500e+08
# Employers' social contributions           4.384219e+06  4.662738e+06
# Use of goods and services                 4.988226e+07  1.276029e+07
# Interest expense                          1.182258e+07  4.361513e+06
# To nonresidents                           4.716965e+06  4.086546e+06
# To residents other than government units  7.105619e+06  2.749664e+05
# To other government units                 0.000000e+00  0.000000e+00
# Subsidies                                          NaN  0.000000e+00
# To public corporations                             NaN  0.000000e+00
# To private enterprises                    0.000000e+00  0.000000e+00
# To other sectors                                   NaN  0.000000e+00
# Grants                                    0.000000e+00  0.000000e+00
# To foreign governments                    0.000000e+00  0.000000e+00
# To international organizations            0.000000e+00  0.000000e+00
# To other government units                 0.000000e+00  0.000000e+00
# Current                                   0.000000e+00  0.000000e+00
# Capital                                   0.000000e+00  0.000000e+00
# Social benefits                           0.000000e+00  0.000000e+00
# Social security benefits                  0.000000e+00  0.000000e+00
# Social assistance benefits                0.000000e+00  0.000000e+00
# Employment-related social benefits        0.000000e+00  0.000000e+00
# Other expense                                      NaN  3.033082e+07
# Property expense other than interest      0.000000e+00  0.000000e+00
# Expense on other transfers                         NaN  3.033082e+07
#
#                                                   2015          2016  \
# nan
# Expense                                   1.569674e+08  1.642455e+08
# Compensation of employees                 9.534378e+07  8.279333e+07
# Wages and salaries                        9.108528e+07  7.970268e+07
# Employers' social contributions           4.258503e+06  3.090653e+06
# Use of goods and services                 2.562712e+07  3.698782e+07
# Interest expense                          7.902999e+06  1.945396e+06
# To nonresidents                           5.627230e+05  1.826497e+06
# To residents other than government units  7.340276e+06  1.188991e+05
# To other government units                 0.000000e+00  0.000000e+00
# Subsidies                                 0.000000e+00  0.000000e+00
# To public corporations                    0.000000e+00  0.000000e+00
# To private enterprises                    0.000000e+00  0.000000e+00
# To other sectors                          0.000000e+00  0.000000e+00
# Grants                                    0.000000e+00  0.000000e+00
# To foreign governments                    0.000000e+00  0.000000e+00
# To international organizations            0.000000e+00  0.000000e+00
# To other government units                 0.000000e+00  0.000000e+00
# Current                                   0.000000e+00  0.000000e+00
# Capital                                   0.000000e+00  0.000000e+00
# Social benefits                           0.000000e+00  0.000000e+00
# Social security benefits                  0.000000e+00  0.000000e+00
# Social assistance benefits                0.000000e+00  0.000000e+00
# Employment-related social benefits        0.000000e+00  0.000000e+00
# Other expense                             2.809354e+07  4.251894e+07
# Property expense other than interest      0.000000e+00  0.000000e+00
# Expense on other transfers                2.809354e+07  4.251894e+07
#
#                                                   2017          2018  \
# nan
# Expense                                   1.805644e+08  2.245356e+08
# Compensation of employees                 8.647410e+07  1.102782e+08
# Wages and salaries                        8.255782e+07  1.058746e+08
# Employers' social contributions           3.916279e+06  4.403609e+06
# Use of goods and services                 4.797987e+07  5.479749e+07
# Interest expense                          3.813279e+06  5.036432e+06
# To nonresidents                           3.616130e+06  4.775731e+06
# To residents other than government units  1.971491e+05  2.607007e+05
# To other government units                 0.000000e+00  0.000000e+00
# Subsidies                                 0.000000e+00  0.000000e+00
# To public corporations                    0.000000e+00  0.000000e+00
# To private enterprises                    0.000000e+00  0.000000e+00
# To other sectors                          0.000000e+00  0.000000e+00
# Grants                                    0.000000e+00  0.000000e+00
# To foreign governments                    0.000000e+00  0.000000e+00
# To international organizations            0.000000e+00  0.000000e+00
# To other government units                 0.000000e+00  0.000000e+00
# Current                                   0.000000e+00  0.000000e+00
# Capital                                   0.000000e+00  0.000000e+00
# Social benefits                           0.000000e+00  0.000000e+00
# Social security benefits                  0.000000e+00  0.000000e+00
# Social assistance benefits                0.000000e+00  0.000000e+00
# Employment-related social benefits        0.000000e+00  0.000000e+00
# Other expense                             4.229713e+07  5.442352e+07
# Property expense other than interest      0.000000e+00  0.000000e+00
# Expense on other transfers                4.229713e+07  5.442352e+07
#
#                                                   2019
# nan
# Expense                                   2.204805e+08
# Compensation of employees                 1.108752e+08
# Wages and salaries                        9.729955e+07
# Employers' social contributions           1.357561e+07
# Use of goods and services                 6.199103e+07
# Interest expense                          1.104797e+07
# To nonresidents                           2.798638e+06
# To residents other than government units  0.000000e+00
# To other government units                 8.249336e+06
# Subsidies                                 0.000000e+00
# To public corporations                    0.000000e+00
# To private enterprises                    0.000000e+00
# To other sectors                          0.000000e+00
# Grants                                    0.000000e+00
# To foreign governments                    0.000000e+00
# To international organizations            0.000000e+00
# To other government units                 0.000000e+00
# Current                                   0.000000e+00
# Capital                                   0.000000e+00
# Social benefits                           0.000000e+00
# Social security benefits                  0.000000e+00
# Social assistance benefits                0.000000e+00
# Employment-related social benefits        0.000000e+00
# Other expense                             3.656637e+07
# Property expense other than interest      0.000000e+00
# Expense on other transfers                3.656637e+07

# %% [markdown]
# Calculate Yearly Averages

# %%
data_by_year_table = {
  2010: [],
  2011: [],
  2012: [],
  2013: [],
  2014: [],
  2015: [],
  2016: [],
  2017: [],
  2018: [],
  2019: [],
} #make table that stores data by year

# master_averages_ls = [] #make master averages list as place to store averages

for key in master_table:
  years_available = master_table[key].columns
  for year in data_by_year_table:
    if year in years_available:
      data = master_table[key][year]
      data.drop('To other government units', inplace=True)
      data_by_year_table[year].append(data)


yearly_averages_ls = [] #make a list of the yearly averages
for year in data_by_year_table:
  merged_year_df = pd.concat(data_by_year_table[year], axis=1, join='outer')
  
  #Sum or mean
  year_average_df = merged_year_df.mean(axis=1) #get the average of all the countries' averages
  yearly_averages_ls.append(year_average_df)

 
# #Get average over decade
# #loop through table (where key is the country name) (master_table[key] is the dataframe stored in the master_table indexed by key)
# for key in master_table:
#   per_category_average = master_table[key].mean(axis=1) #get the average of each category (ignoring np.NaN values) into a list
#   # per_category_average.drop('To other government units', inplace=True) #drop 'To other government units' since there's two rows named that and will error
#   master_averages_ls.append(per_category_average) #add each country average to to the master averages list



# merged_averages_df = pd.concat(master_averages_ls, axis=1, join='outer')
# average__of_averages_df = merged_averages_df.mean(axis=1) #get the average of all the countries' averages
# average__of_averages_df

for i in range(len(yearly_averages_ls)):
  print(f"YEAR: {2010+i}")
  print(yearly_averages_ls[i])
# Out:
# YEAR: 2010
# nan
# Expense                                     1.740526e+10
# Compensation of employees                   6.048701e+09
# Use of goods and services                   3.273226e+09
# Interest expense                            1.666563e+09
# To nonresidents                             5.742074e+08
# To residents other than government units    1.007686e+09
# Subsidies                                   2.747131e+09
# To public corporations                      2.178702e+09
# To private enterprises                      2.204240e+08
# To other sectors                            0.000000e+00
# Grants                                      2.286396e+09
# To foreign governments                      0.000000e+00
# To international organizations              1.503035e+07
# Current                                     1.611622e+09
# Capital                                     6.597437e+08
# Social benefits                             5.172461e+08
# Social security benefits                    2.220780e+08
# Social assistance benefits                  2.921370e+08
# Employment-related social benefits          3.031180e+06
# Other expense                               8.245991e+08
# Property expense other than interest        0.000000e+00
# Expense on other transfers                  8.245991e+08
# Wages and salaries                          3.772190e+09
# Employers' social contributions             1.307529e+08
# dtype: float64
# YEAR: 2011
# nan
# Expense                                     1.724005e+10
# Compensation of employees                   6.060055e+09
# Use of goods and services                   3.056755e+09
# Interest expense                            1.746697e+09
# To nonresidents                             5.578514e+08
# To residents other than government units    1.106081e+09
# Subsidies                                   2.108759e+09
# To public corporations                      1.626167e+09
# To private enterprises                      9.256934e+07
# To other sectors                            0.000000e+00
# Grants                                      2.772774e+09
# To foreign governments                      0.000000e+00
# To international organizations              2.178106e+07
# Current                                     1.738181e+09
# Capital                                     1.012812e+09
# Social benefits                             7.183709e+08
# Social security benefits                    2.928872e+08
# Social assistance benefits                  4.135505e+08
# Employment-related social benefits          1.193317e+07
# Other expense                               7.260877e+08
# Property expense other than interest        0.000000e+00
# Expense on other transfers                  7.260877e+08
# Wages and salaries                          3.633632e+09
# Employers' social contributions             2.527364e+08
# dtype: float64
# YEAR: 2012
# nan
# Expense                                     2.532110e+10
# Compensation of employees                   8.492969e+09
# Use of goods and services                   4.105214e+09
# Interest expense                            2.165953e+09
# To private enterprises                      2.743509e+08
# To other sectors                            7.760248e+07
# Grants                                      9.599680e+09
# To foreign governments                      0.000000e+00
# To international organizations              5.703701e+07
# Current                                     6.666081e+09
# Capital                                     2.876562e+09
# Social benefits                             3.733392e+08
# Social security benefits                    0.000000e+00
# Social assistance benefits                  1.888702e+08
# Employment-related social benefits          1.844691e+08
# Other expense                               2.773323e+09
# Property expense other than interest        0.000000e+00
# Expense on other transfers                  2.773323e+09
# Wages and salaries                          8.481920e+09
# Employers' social contributions             7.283437e+08
# dtype: float64

# %% [markdown]
# Calculate Percentages

# %%
yearly_averages_percentage_ls = []
for year_average_df in yearly_averages_ls:
  total_taxes = year_average_df['Expense']
  year_average_percentage_df = year_average_df / total_taxes * 100 #take all values as a fraction of total expenditure, then convert decimal to percent, then round to two decimal places

  yearly_averages_percentage_ls.append(year_average_percentage_df)


for i in range(len(yearly_averages_percentage_ls)):
  print(f"YEAR: {2010+i}")
  print(yearly_averages_percentage_ls[i])
# Out:
# YEAR: 2010
# nan
# Expense                                     100.000000
# Compensation of employees                    34.752145
# Use of goods and services                    18.805961
# Interest expense                              9.575054
# To nonresidents                               3.299045
# To residents other than government units      5.789548
# Subsidies                                    15.783339
# To public corporations                       12.517493
# To private enterprises                        1.266422
# To other sectors                              0.000000
# Grants                                       13.136235
# To foreign governments                        0.000000
# To international organizations                0.086355
# Current                                       9.259395
# Capital                                       3.790485
# Social benefits                               2.971781
# Social security benefits                      1.275924
# Social assistance benefits                    1.678441
# Employment-related social benefits            0.017415
# Other expense                                 4.737643
# Property expense other than interest          0.000000
# Expense on other transfers                    4.737643
# Wages and salaries                           21.672701
# Employers' social contributions               0.751226
# dtype: float64
# YEAR: 2011
# nan
# Expense                                     100.000000
# Compensation of employees                    35.151041
# Use of goods and services                    17.730552
# Interest expense                             10.131629
# To nonresidents                               3.235789
# To residents other than government units      6.415767
# Subsidies                                    12.231751
# To public corporations                        9.432499
# To private enterprises                        0.536944
# To other sectors                              0.000000
# Grants                                       16.083332
# To foreign governments                        0.000000
# To international organizations                0.126340
# Current                                      10.082231
# Capital                                       5.874763
# Social benefits                               4.166874
# Social security benefits                      1.698877
# Social assistance benefits                    2.398779
# Employment-related social benefits            0.069218
# Other expense                                 4.211635
# Property expense other than interest          0.000000
# Expense on other transfers                    4.211635
# Wages and salaries                           21.076695
# Employers' social contributions               1.465984
# dtype: float64
# YEAR: 2012
# nan
# Expense                                     100.000000
# Compensation of employees                    33.541071
# Use of goods and services                    16.212620
# Interest expense                              8.553943
# To nonresidents                               2.842963
# To residents other than government units      5.332945
# Subsidies                                     4.845287
# To public corporations                        1.300012
# To private enterprises                        0.053743
# To other sectors                              1.661518
# Grants                                       19.999877
# To foreign governments                        0.000000
# To international organizations                0.154598
# Current                                      12.455677
# Capital                                       7.389601
# Social benefits                               0.078686
# Social security benefits                      0.000000
# Social assistance benefits                    0.002693
# Employment-related social benefits            0.075993
# Other expense                                16.589158
# Property expense other than interest          0.000000
# Expense on other transfers                   16.589158
# To nonresidents                               3.585669
# To residents other than government units      9.442587
# Subsidies                                     3.603975
# To public corporations                        2.126977
# To private enterprises                        0.766219
# To other sectors                              0.710778
# Grants                                       26.626448
# To foreign governments                        0.000000
# To international organizations                0.375741
# Current                                      17.543660
# Capital                                       8.707047
# Social benefits                               0.849923
# Social security benefits                      0.000000
# Social assistance benefits                    0.487825
# Employment-related social benefits            0.362098
# Other expense                                10.882912
# Property expense other than interest          0.000000
# Expense on other transfers                   10.882912
# Wages and salaries                           20.697707
# Employers' social contributions               2.156461
# dtype: float64
# YEAR: 2018
# nan
# Expense                                     100.000000
# Compensation of employees                    29.862722
# Use of goods and services                    16.487278
# Interest expense                             13.045935
# To nonresidents                               3.759884
# To residents other than government units      2.035042
# Subsidies                                     3.941937
# To public corporations                        2.007679
# To private enterprises                        0.641323
# To other sectors                              1.292936
# Grants                                       25.680371
# To foreign governments                        0.000000
# To international organizations                0.129905
# Current                                      17.166318
# Capital                                       8.384148
# Social benefits                               1.066445
# Social security benefits                      0.000000
# Social assistance benefits                    0.545332
# Employment-related social benefits            0.521113
# Other expense                                 9.915311
# Property expense other than interest          0.000000
# Expense on other transfers                    9.906551
# Wages and salaries                           20.702269
# Employers' social contributions               1.894668
# dtype: float64
# YEAR: 2019
# nan
# Expense                                     100.000000
# Compensation of employees                    32.372882
# Use of goods and services                    15.576547
# Interest expense                             14.477268
# To nonresidents                               4.449200
# To residents other than government units      2.289550
# Subsidies                                     2.851269
# To public corporations                        1.392614
# To private enterprises                        0.747353
# To other sectors                              0.211395
# Grants                                       26.150280
# To foreign governments                        0.000000
# To international organizations                0.155373
# Current                                      18.158927
# Capital                                       7.835980
# Social benefits                               1.017005
# Social security benefits                      0.000000
# Social assistance benefits                    0.514497
# Employment-related social benefits            0.502508
# Other expense                                 7.554749
# Property expense other than interest          0.000000
# Expense on other transfers                    7.554749
# Wages and salaries                           23.105415
# Employers' social contributions               1.984065
# dtype: float64

# %% [markdown]
# Calculate Average Across Period

# %%
merged_percentages_df = pd.concat(yearly_averages_percentage_ls, axis=1, join='outer')
average_df = merged_percentages_df.mean(axis=1)
rounded_average_df = average_df.apply(lambda x: round(x, 2))

rounded_average_df = rounded_average_df.to_frame()
rounded_average_df
# Out:
#                                                0
# nan
# Expense                                   100.00
# Compensation of employees                  32.98
# Use of goods and services                  17.21
# Interest expense                           11.56
# To nonresidents                             3.21
# To residents other than government units    5.13
# Subsidies                                   5.56
# To public corporations                      3.49
# To private enterprises                      0.58
# To other sectors                            0.62
# Grants                                     22.13
# To foreign governments                      0.00
# To international organizations              0.19
# Current                                    14.64
# Capital                                     7.29
# Social benefits                             1.14
# Social security benefits                    0.30
# Social assistance benefits                  0.59
# Employment-related social benefits          0.25
# Other expense                               9.35
# Property expense other than interest        0.00
# Expense on other transfers                  9.34
# Wages and salaries                         18.14
# Employers' social contributions             1.75

# %%
#one method filter for countries with 7+ years of data, aggregate in way that preserves identities
#unweighted - convert to share and take average (ratios period by period and then average)
